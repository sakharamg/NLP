# %%
import numpy as np
import itertools
import matplotlib
import nltk
import random
import math
import matplotlib.pyplot as plt
import statistics
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from nltk.tree import Tree
from nltk.corpus import semcor
from gensim.models import KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Getting the brown corpus
print("Downloading files from NLTK please wait...")
nltk.download('all', quiet=True)
print("NLTK files downloaded!")



# Task: Tag words with synset ID
# Three types of tags in semcor
# 1) No tag
# 2) Tagged with a lemma of synset: A lemma is a data structure which contains synset along with its synset_id, hypernymy, hyponymy,... 
# 3) Tagged with lemma but the synset ID doesn't exist in wordnet
#    One such example is the 7th sentence in the semcor corpus
#    The grand jury commented on a number of other topics, among them the Atlanta and Fulton County purchasing departments which it said are 
#    well operated and follow generally accepted practices which inure to the best interest of both governments.
#                                       ^______^  "accepted" is tagged as "accepted.s.00" lemma and this doesn't have a synsetID in wordnet
#    All the three cases are handled by the code

# Each sentence has a pair of phrase and (representation of)synset
# Each Phrase has one or more words(e.g. "primary election" in first sentence of corpora)
# Each synset is respresented as a Tree e.g. for "primary election"
# Lemma('primary.n.01.primary_election')
#                 /\
#                /  \
#               /    \
#         primary   election
# This example will be used later to explain code
print("Preprocessing the semcor corpus...")
synCorpus=[]
current_index=0
for taggedSents in semcor.tagged_sents(tag='sem'): # for each sentence fetch the (phrase,synsetTree)
    synCorpus.append([])                           # create a list designating current sentence which will contain (phrase,synsetID)
    for phrase in taggedSents:
        if type(phrase)==list:                     # The phrase with no tag is a list in semcor [Note: CASE 1]
            #if its a list fetch the word and set -1 as synset ID which indicates no synset TAG
            # synCorpus[current_index].append((phrase[0],-1))  # a tuple is formed
            pass
        else: # if synset is a Tree [Note Case 2 and 3]
            # Here when theres a synset not in wordnet, theres no synset id[Case 3], to handle this
            # except block is used
            # The try except will get the synset ID and in case no synsetID -2 is given to such a case
            try: 
                # handle Case 2
                if phrase.label().name() == 'strong':
                    print(taggedSents)
                synCorpus[current_index].append((phrase.label().name(),phrase.label().synset().name())) 
            except:
                # handle Case 3
                #synTag_for_corpus=-2 # -2 indicates no synset tags for the specific POS but available for some POS
                pass
    current_index+=1 # Keeps tract of the sentence index
no_sents=current_index #Saved total number of sentences
# The reason for storing as tuples is because the brown corpus stored it in a same way and this way we have to make minimal changed to HMM-Viterbi POS tag code if any :)
print("Semcor preprocessing finished")
# Out:
# Downloading files from NLTK please wait...
# NLTK files downloaded!
# Preprocessing the semcor corpus...
# [Tree(Lemma('georgia.n.01.Georgia'), ['Georgia']), Tree(Lemma('republican.n.01.Republican'), ['Republicans']), ['are'], Tree(Lemma('receive.v.02.get'), ['getting']), Tree(Lemma('potent.s.02.strong'), ['strong']), Tree(Lemma('boost.n.01.encouragement'), ['encouragement']), ['to'], Tree(Lemma('enroll.v.01.enter'), ['enter']), ['a'], Tree(Lemma('campaigner.n.01.candidate'), ['candidate']), ['in'], ['the'], ['1962'], Tree(Lemma('governor's_race.n.01.governor's_race'), ['governor', "'s", 'race']), [','], ['a'], Tree('top.s.00', ['top']), Tree(Lemma('official.n.01.official'), ['official']), Tree(Lemma('state.v.01.say'), ['said']), Tree(Lemma('wednesday.n.01.Wednesday'), ['Wednesday']), ['.']]
# [Tree(Lemma('person.n.01.person'), [Tree('NE', ['Whitey', 'Herzog'])]), [','], Tree(Lemma('perform.v.02.perform'), ['performing']), ['in'], Tree(Lemma('right_field.n.01.right'), ['right']), ['as'], ['the'], Tree(Lemma('group.n.01.group'), [Tree('NE', ['Orioles'])]), Tree(Lemma('field.v.02.field'), ['fielded']), Tree(Lemma('possibly.r.01.possibly'), ['possibly']), ['their'], Tree(Lemma('strong.a.01.strong'), ['strongest']), Tree(Lemma('team.n.01.team'), ['team']), ['of'], ['the'], Tree(Lemma('spring.n.01.spring'), ['spring']), [','], Tree(Lemma('cultivate.v.02.work'), ['worked']), Tree(Lemma('person.n.01.person'), [Tree('NE', ['Keegan'])]), ['for'], ['a'], Tree(Lemma('base_on_balls.n.01.base_on_balls'), ['base', 'on', 'balls']), ['.']]
# [Tree(Lemma('person.n.01.person'), [Tree('NE', ['Chico', 'Ruiz'])]), Tree(Lemma('make.v.01.make'), ['made']), ['a'], Tree(Lemma('dramatic.s.02.spectacular'), ['spectacular']), Tree(Lemma('maneuver.n.03.play'), ['play']), ['on'], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Alusik'])]), ["'s"], Tree(Lemma('grounder.n.01.grounder'), ['grounder']), ['in'], ['the'], Tree(Lemma('hole.n.04.hole'), ['hole']), ['in'], ['the'], Tree(Lemma('fourth.s.01.fourth'), ['fourth']), ['and'], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Wert'])]), Tree(Lemma('come_up.v.01.come_up'), ['came', 'up']), ['with'], Tree(Lemma('some.a.01.some'), ['some']), Tree(Lemma('good.a.01.good'), ['good']), Tree(Lemma('stop.n.02.stop'), ['stops']), ['and'], Tree(Lemma('show.v.01.show'), ['showed']), ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('arm.n.01.arm'), ['arm']), ['at'], Tree(Lemma('third_base.n.01.third_base'), ['third', 'base']), ['.']]
# [Tree(Lemma('person.n.01.person'), [Tree('NE', ['Skorich'])]), [','], Tree(Lemma('however.r.01.however'), ['however']), [','], Tree(Lemma('be.v.01.be'), ['is']), ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('advocate.n.01.advocate'), ['advocate']), ['of'], ['a'], Tree(Lemma('balanced.a.01.balanced'), ['balanced']), Tree(Lemma('attack.n.02.attack'), ['attack']), ['-'], Tree('split.s.00', ['split']), ['between'], Tree(Lemma('run.n.05.running'), ['running']), ['and'], Tree(Lemma('pass.n.03.passing'), ['passing']), ['.']]
# [['His'], Tree(Lemma('desire.n.01.desire'), ['desires']), Tree(Lemma('be.v.01.be'), ['are']), Tree(Lemma('so.r.01.so'), ['so']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['that'], ['he'], Tree(Lemma('want.v.02.need'), ['needs']), Tree('constant.s.00', ['constant']), Tree(Lemma('reassurance.n.01.reassurance'), ['reassurance']), ['of'], ['his'], Tree(Lemma('mother.n.01.mother'), ['mother']), ["'s"], Tree(Lemma('love.n.01.love'), ['love']), ['for'], ['him'], ['and'], ['what'], ['she'], Tree(Lemma('ask.v.04.expect'), ['expects']), ['of'], ['him'], [','], ['in', 'order'], ['to'], Tree(Lemma('overcome.v.02.overcome'), ['overcome']), ['them'], ['.']]
# [['As'], ['she'], Tree(Lemma('derive.v.02.gain'), ['gained']), Tree(Lemma('composure.n.01.composure'), ['composure']), ['during'], ['the'], Tree(Lemma('second.s.01.second'), ['second']), Tree(Lemma('act.n.03.act'), ['act']), [','], ['her'], Tree('technical.a.00', ['technical']), Tree(Lemma('resourcefulness.n.01.resourcefulness'), ['resourcefulness']), Tree(Lemma('emerge.v.01.emerge'), ['emerged']), Tree(Lemma('strong.a.01.strong'), ['stronger']), [','], ['though'], ['she'], ['had'], Tree(Lemma('already.r.01.already'), ['already']), Tree(Lemma('uncover.v.01.reveal'), ['revealed']), ['a'], Tree(Lemma('trill.n.01.trill'), ['trill']), Tree(Lemma('about.r.07.almost'), ['almost']), Tree(Lemma('unprecedented.a.01.unprecedented'), ['unprecedented']), ['in'], Tree(Lemma('year.n.01.year'), ['years']), ['of'], Tree(Lemma('performance.n.01.performance'), ['performances']), ['of'], ['``'], Tree('NE', ['Lucia']), ["''"], ['.']]
# [Tree(Lemma('anyhow.r.01.in_any_case'), ['In', 'any', 'case']), [','], ['I'], ['have'], Tree(Lemma('always.r.01.always'), ['always']), ['been'], Tree(Lemma('treat.v.01.treat'), ['treated']), ['with'], ['the'], Tree(Lemma('extreme.s.01.utmost'), ['utmost']), Tree(Lemma('courtesy.n.01.courtesy'), ['courtesy']), ['by'], Tree(Lemma('englishman.n.01.Englishman'), ['Englishmen']), [','], Tree(Lemma('even.r.01.even'), ['even']), ['in'], Tree(Lemma('location.n.01.location'), [Tree('NE', ['Devonshire'])]), ['and'], Tree(Lemma('location.n.01.location'), [Tree('NE', ['Cornwall'])]), [','], ['where'], Tree(Lemma('anti.a.01.anti'), ['anti']), Tree(Lemma('catholic.a.01.Catholic'), ['Catholic']), Tree(Lemma('spirit.n.02.feeling'), ['feeling']), ['has'], Tree(Lemma('purportedly.r.01.supposedly'), ['supposedly']), Tree(Lemma('exist.v.01.exist'), ['existed']), ['the'], Tree(Lemma('strong.a.01.strong'), ['strongest']), ['and'], Tree(Lemma('long.a.01.long'), ['longest']), ['.']]
# [['There'], Tree(Lemma('be.v.05.be'), ['were']), Tree(Lemma('many.a.01.many'), ['many']), Tree(Lemma('letter.n.01.letter'), ['letters']), ['of'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('protest.n.01.protest'), ['protest']), ['against'], ['the'], Tree(Lemma('portrait.n.02.portrait'), ['portrait']), ['of'], ['the'], Tree(Lemma('anglican.a.01.Anglican'), ['Anglican']), Tree(Lemma('clergyman.n.01.clergyman'), ['clergyman']), [','], ['who'], ['was'], Tree(Lemma('indeed.r.01.indeed'), ['indeed']), Tree(Lemma('portray.v.01.portray'), ['portrayed']), ['as'], ['a'], Tree(Lemma('man.n.01.man'), ['man']), Tree(Lemma('not.r.01.not'), ['not']), Tree(Lemma('particularly.r.01.particularly'), ['particularly']), Tree(Lemma('concerned.a.01.concerned'), ['concerned']), ['with'], Tree('religious.a.00', ['religious']), Tree(Lemma('topic.n.02.matter'), ['matters']), ['and'], ['without'], Tree(Lemma('actually.r.01.really'), ['really']), Tree(Lemma('a_lot.r.01.very_much'), ['very', 'much']), ['to'], Tree(Lemma('make.v.01.do'), ['do']), ['as'], Tree(Lemma('clergyman.n.01.clergyman'), ['clergyman']), ['.']]
# [Tree(Lemma('remove.v.01.remove'), ['Remove']), ['about'], Tree(Lemma('one-half.n.01.half'), ['half']), ['the'], Tree(Lemma('branch.n.02.branch'), ['branches']), ['from'], Tree('each.s.01', ['each']), Tree(Lemma('plant.n.02.plant'), ['plant']), [','], Tree(Lemma('leave.v.04.leave'), ['leaving']), Tree(Lemma('entirely.r.02.only'), ['only']), ['the'], Tree(Lemma('strong.a.01.strong'), ['strongest']), ['with'], ['the'], Tree('largest.s.00', ['largest']), Tree(Lemma('bud.n.02.bud'), ['buds']), ['.']]
# [['An'], Tree(Lemma('area.n.01.area'), ['area']), Tree('sheltered.s.00', ['sheltered']), ['from'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('wind.n.01.wind'), ['winds']), ['may'], Tree(Lemma('be.v.01.be'), ['be']), Tree('highly.r.00', ['highly']), Tree(Lemma('desirable.a.01.desirable'), ['desirable']), ['for'], Tree(Lemma('diversion.n.01.recreation'), ['recreation']), Tree(Lemma('use.n.01.use'), ['use']), ['.']]
# [['These'], Tree(Lemma('be.v.02.be'), ['are']), Tree(Lemma('beginning.n.01.beginning'), ['beginnings']), [','], ['but'], Tree(Lemma('correctly.r.01.correctly'), ['correctly']), Tree(Lemma('learn.v.01.learn'), ['learned']), ['they'], Tree(Lemma('prepare.v.05.prepare'), ['prepare']), ['for'], Tree('satisfying.s.00', ['satisfying']), ['and'], Tree(Lemma('exciting.a.01.exciting'), ['exciting']), Tree(Lemma('stunt.n.01.stunt'), ['stunts']), ['that'], ['can'], ['be'], Tree(Lemma('perform.v.01.perform'), ['performed']), ['by'], ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), [','], Tree(Lemma('flexible.s.04.flexible'), ['flexible']), Tree(Lemma('body.n.01.body'), ['body']), ['('], ['we'], ['are'], Tree(Lemma('not.r.01.not'), ['not']), Tree(Lemma('talk.v.01.talk'), ['talking']), ['of'], Tree(Lemma('bizarre.s.01.eccentric'), ['eccentric']), Tree(Lemma('extreme.n.01.extreme'), ['extremes']), [')'], ['.']]
# [['This'], Tree(Lemma('kind.n.01.kind'), ['kind']), ['of'], Tree(Lemma('irresponsibility.n.01.irresponsibility'), ['irresponsibility']), ['toward'], ['their'], Tree(Lemma('student.n.01.student'), ['students']), ['can'], Tree(Lemma('barely.r.01.scarcely'), ['scarcely']), Tree(Lemma('build_up.v.02.build'), ['build']), ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('professional.a.03.professional'), ['professional']), Tree(Lemma('attitude.n.01.attitude'), ['attitude']), ['in'], ['the'], Tree(Lemma('future.s.03.future'), ['future']), Tree(Lemma('interior_designer.n.01.designer'), ['designer']), ['.']]
# [['The'], Tree(Lemma('last.a.02.last'), ['last']), Tree(Lemma('two.s.01.two'), ['two']), Tree(Lemma('writer.n.01.writer'), ['writers']), Tree(Lemma('insert.v.01.introduce'), ['introduce']), Tree(Lemma('strong.s.02.strong'), ['strong']), Tree(Lemma('political.a.02.political'), ['political']), Tree(Lemma('bias.n.01.bias'), ['bias']), ['into'], ['their'], Tree(Lemma('work.n.02.work'), ['works']), [','], ['and'], Tree(Lemma('not.r.01.not'), ['not']), ['unlike'], ['the'], Tree(Lemma('union.n.01.union'), ['union']), Tree(Lemma('leadership.n.02.leaders'), ['leaders']), ['that'], ['we'], ['will'], Tree(Lemma('discourse.v.01.discuss'), ['discuss']), Tree(Lemma('soon.r.01.soon'), ['soon']), [','], Tree(Lemma('see.v.05.see'), ['see']), Tree(Lemma('folklore.n.01.folklore'), ['folklore']), ['as'], ['a'], Tree(Lemma('reservoir.n.01.reservoir'), ['reservoir']), ['of'], Tree(Lemma('protest.n.01.protest'), ['protest']), ['by'], ['a'], Tree('downtrodden.s.00', ['downtrodden']), ['and'], Tree(Lemma('publicly.r.01.publicly'), ['publically']), Tree(Lemma('silenced.a.01.silenced'), ['silenced']), Tree(Lemma('multitude.n.03.mass'), ['mass']), ['.']]
# [['For'], ['a'], Tree(Lemma('moment.n.02.moment'), ['moment']), ['or'], Tree(Lemma('two.s.01.two'), ['two']), [','], ['both'], Tree(Lemma('scene.n.04.scene'), ['scenes']), Tree(Lemma('be.v.01.be'), ['are']), Tree(Lemma('present.a.02.present'), ['present']), Tree(Lemma('simultaneously.r.01.simultaneously'), ['simultaneously']), [','], Tree(Lemma('one.s.01.one'), ['one']), Tree(Lemma('turn.v.07.grow'), ['growing']), Tree(Lemma('weak.a.01.weak'), ['weaker']), [','], Tree(Lemma('one.s.01.one'), ['one']), Tree(Lemma('turn.v.07.grow'), ['growing']), Tree(Lemma('strong.s.02.strong'), ['stronger']), ['.']]
# [['The'], Tree(Lemma('american.a.01.American'), ['American']), Tree(Lemma('liberal.n.01.liberal'), ['liberal']), ['may'], [','], ['in'], ['the'], Tree(Lemma('world.n.03.world'), ['world']), ['of'], Tree(Lemma('today.n.01.today'), ['to-day']), [','], Tree(Lemma('have.v.01.have'), ['have']), ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('case.n.09.case'), ['case']), [';'], ['but'], ['he'], Tree(Lemma('present.v.02.present'), ['presents']), ['it'], Tree(Lemma('publicly.r.01.publicly'), ['publicly']), Tree(Lemma('so.r.01.so'), ['so']), Tree(Lemma('enmesh.v.01.enmesh'), ['enmeshed']), ['in'], Tree(Lemma('hypocrisy.n.01.hypocrisy'), ['hypocrisy']), ['that'], ['it'], Tree(Lemma('be.v.01.be'), ['is']), Tree(Lemma('not.r.01.not'), ['not']), ['an'], Tree(Lemma('dependable.s.02.honest'), ['honest']), Tree(Lemma('one.s.01.one'), ['one']), ['.']]
# [Tree(Lemma('report.n.03.account'), ['Accounts']), ['have'], ['been'], Tree(Lemma('publish.v.02.publish'), ['published']), ['of'], Tree(Lemma('northern.a.01.northern'), ['Northern']), Tree(Lemma('liberal.n.01.liberal'), ['liberals']), ['in'], ['the'], Tree(Lemma('south.n.01.South'), ['South']), ['up', 'against'], Tree(Lemma('segregator.n.01.segregationist'), ['segregationist']), Tree(Lemma('bias.n.01.prejudice'), ['prejudice']), [','], Tree(Lemma('particularly.r.01.especially'), ['especially']), ['in'], Tree(Lemma('state-supported.s.01.state-supported'), ['state-supported']), Tree(Lemma('university.n.02.university'), ['universities']), ['where'], Tree(Lemma('pressure.n.02.pressure'), ['pressure']), ['may'], Tree(Lemma('be.v.01.be'), ['be']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['to'], Tree(Lemma('continue.v.03.uphold'), ['uphold']), ['the'], Tree(Lemma('majority.n.01.majority'), ['majority']), Tree(Lemma('opinion.n.01.view'), ['view']), ['.']]
# [['The'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('impression.n.01.feeling'), ['feeling']), ['is'], Tree(Lemma('surely.r.01.certainly'), ['certainly']), ['there'], [';'], ['but'], ['there'], Tree(Lemma('exist.v.01.be'), ['is']), ['a'], Tree(Lemma('leaven.n.02.leavening'), ['leavening']), ['of'], Tree(Lemma('liberalism.n.01.liberalism'), ['liberalism']), ['among'], Tree(Lemma('college.n.01.college'), ['college']), Tree(Lemma('alumnus.n.01.graduate'), ['graduates']), ['throughout'], ['the'], Tree(Lemma('south.n.01.South'), ['South']), [','], Tree(Lemma('particularly.r.01.especially'), ['especially']), ['among'], ['those'], ['who'], Tree(Lemma('study.v.02.study'), ['studied']), ['in'], ['the'], Tree(Lemma('north.n.01.North'), ['North']), ['.']]
# [['**f'], Tree(Lemma('look.v.02.appear'), ['appeared']), ['to'], Tree(Lemma('be.v.01.be'), ['be']), Tree(Lemma('well.r.01.well'), ['well']), Tree(Lemma('suitable.s.01.suited'), ['suited']), ['for'], ['the'], Tree(Lemma('survey.n.01.study'), ['study']), ['of'], ['these'], Tree(Lemma('matter.n.01.matter'), ['matters']), [','], ['since'], ['it'], Tree(Lemma('be.v.01.be'), ['is']), ['a'], Tree(Lemma('normal.a.01.normal'), ['normal']), Tree(Lemma('paramagnet.n.01.paramagnet'), ['paramagnet']), [','], ['with'], Tree(Lemma('three.s.01.three'), ['three']), Tree(Lemma('odd.s.05.unpaired'), ['unpaired']), Tree(Lemma('electron.n.01.electron'), ['electrons']), ['on'], ['the'], Tree(Lemma('chromium.n.01.chromium'), ['chromium']), [','], ['its'], Tree(Lemma('crystal.n.01.crystal'), ['crystal']), Tree(Lemma('structure.n.02.structure'), ['structure']), Tree(Lemma('be.v.01.be'), ['is']), Tree(Lemma('very.r.01.very'), ['very']), Tree(Lemma('simple.a.01.simple'), ['simple']), [','], ['and'], ['the'], Tree(Lemma('unknown.a.01.unknown'), ['unknown']), Tree(Lemma('position.n.01.position'), ['position']), ['of'], ['the'], Tree(Lemma('hydrogen.n.01.hydrogen'), ['hydrogen']), ['in'], ['the'], Tree(Lemma('strong.a.01.strong'), ['strong']), ['**f'], Tree(Lemma('chemical_bond.n.01.bond'), ['bond']), Tree(Lemma('supply.v.01.provide'), ['provides']), Tree(Lemma('structural.a.01.structural'), ['structural']), Tree(Lemma('interest.n.01.interest'), ['interest']), ['.']]
# [['The'], Tree(Lemma('insoluble.a.01.insoluble'), ['insoluble']), Tree(Lemma('material.n.01.material'), ['material']), Tree(Lemma('result.v.01.result'), ['resulting']), ['from'], Tree(Lemma('dialysis.n.01.dialysis'), ['dialysis']), ['against'], Tree(Lemma('starting_buffer.n.01.starting_buffer'), ['starting', 'buffer']), Tree(Lemma('always.r.01.always'), ['always']), Tree(Lemma('show.v.01.show'), ['showed']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('action.n.02.activity'), ['activity']), ['.']]
# [['It'], ['has'], ['been'], Tree('show.v.00', ['shown']), ['that'], Tree(Lemma('thyroglobulin.n.01.thyroglobulin'), ['thyroglobulin']), Tree(Lemma('bind.v.03.bind'), ['binds']), Tree(Lemma('thyroxine.n.01.thyroxine'), ['thyroxine']), [','], ['but'], ['the'], Tree(Lemma('binding.n.01.binding'), ['binding']), ['does'], Tree(Lemma('not.r.01.not'), ['not']), Tree(Lemma('look.v.02.appear'), ['appear']), ['to'], Tree(Lemma('be.v.01.be'), ['be']), Tree(Lemma('particularly.r.01.particularly'), ['particularly']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['.']]
# [Tree('at_first.r.00', ['At', 'first']), ['the'], Tree(Lemma('patient.n.01.patient'), ['patient']), Tree(Lemma('feel.v.04.feel'), ['felt']), Tree(Lemma('strong.a.01.strong'), ['stronger']), [','], ['and'], ['the'], Tree(Lemma('hemoglobin.n.01.hemoglobin'), ['hemoglobin']), Tree(Lemma('rise.v.02.rise'), ['rose']), ['to'], ['13.8'], Tree(Lemma('gram.n.01.gm'), ['gm.']), [','], ['but'], ['on'], Tree(Lemma('october.n.01.Oct'), ['Oct.']), ['20'], [','], ['1958'], [','], ['he'], Tree(Lemma('complain.v.01.complain'), ['complained']), ['of'], ['``'], Tree(Lemma('collapse.v.01.cave_in'), ['caving', 'in']), ["''"], ['in'], ['his'], Tree(Lemma('knee.n.01.knee'), ['knees']), ['.']]
# [['We'], Tree(Lemma('comment.v.01.point_out'), ['pointed', 'out']), ['that'], Tree(Lemma('emotional.a.01.emotional'), ['emotional']), Tree(Lemma('excitation.n.03.excitement'), ['excitement']), ['may'], Tree(Lemma('leave.v.07.lead'), ['lead']), ['to'], Tree(Lemma('psychosomatic_disorder.n.01.psychosomatic_disorder'), ['psychosomatic', 'disorders']), ['and'], Tree(Lemma('neurotic.a.01.neurotic'), ['neurotic']), Tree(Lemma('symptom.n.01.symptom'), ['symptoms']), [','], Tree(Lemma('particularly.r.01.particularly'), ['particularly']), ['in'], Tree(Lemma('certain.s.01.certain'), ['certain']), Tree(Lemma('type.n.01.type'), ['types']), ['of'], Tree(Lemma('personality.n.01.personality'), ['personality']), [','], ['but'], ['it'], ['is'], Tree(Lemma('besides.r.02.also'), ['also']), Tree(Lemma('known.a.01.known'), ['known']), ['that'], ['the'], Tree(Lemma('reliving.n.01.reliving'), ['reliving']), ['of'], ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('emotion.n.01.emotion'), ['emotion']), ['('], ['``'], Tree(Lemma('catharsis.n.01.abreaction'), ['abreaction']), ["''"], [')'], ['may'], Tree(Lemma('bring_around.v.02.cure'), ['cure']), ['a'], Tree(Lemma('battle.n.01.battle'), ['battle']), Tree(Lemma('neurosis.n.01.neurosis'), ['neurosis']), ['.']]
# [['Since'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('nociceptive.s.01.nociceptive'), ['nociceptive']), Tree(Lemma('stimulation.n.02.stimulus'), ['stimuli']), Tree(Lemma('produce.v.03.produce'), ['produce']), ['an'], Tree(Lemma('experimental.a.01.experimental'), ['experimental']), Tree(Lemma('neurosis.n.01.neurosis'), ['neurosis']), ['during'], ['which'], ['the'], Tree(Lemma('animal.n.01.animal'), ['animals']), Tree(Lemma('fail.v.01.fail'), ['fail']), ['to'], Tree(Lemma('eat.v.01.eat'), ['eat']), ['in'], ['the'], Tree(Lemma('experimental.a.01.experimental'), ['experimental']), Tree(Lemma('situation.n.01.situation'), ['situation']), [','], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Wolpe'])]), Tree(Lemma('think.v.02.think'), ['thought']), ['that'], ['he'], ['could'], Tree(Lemma('use.v.01.utilize'), ['utilize']), ['the'], Tree(Lemma('eating.n.01.feeding'), ['feeding']), Tree(Lemma('pain.n.03.pain'), ['pain']), Tree('antagonism.n.00', ['antagonism']), ['to'], Tree(Lemma('suppress.v.01.inhibit'), ['inhibit']), ['the'], Tree(Lemma('neurotic.a.01.neurotic'), ['neurotic']), Tree(Lemma('symptom.n.01.symptom'), ['symptoms']), ['through'], Tree(Lemma('eating.n.01.feeding'), ['feeding']), ['.']]
# [['By'], Tree(Lemma('wear.v.06.hold_out'), ['holding', 'out']), Tree(Lemma('prospect.n.01.prospect'), ['prospects']), ['for'], Tree(Lemma('external.s.03.external'), ['external']), Tree(Lemma('capital.n.01.capital'), ['capital']), Tree(Lemma('aid.n.02.assistance'), ['assistance']), [','], ['the'], Tree(Lemma('united_states_government.n.01.United_States'), ['United', 'States']), ['can'], Tree(Lemma('supply.v.01.provide'), ['provide']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('incentive.n.01.incentive'), ['incentives']), ['to'], Tree(Lemma('steel_oneself_against.v.01.prepare_for'), ['prepare', 'for']), ['the'], Tree(Lemma('concerted.s.01.concerted'), ['concerted']), Tree(Lemma('economic.a.01.economic'), ['economic']), Tree(Lemma('drive.n.01.drive'), ['drive']), Tree(Lemma('necessary.a.01.necessary'), ['necessary']), ['to'], Tree(Lemma('achieve.v.01.achieve'), ['achieve']), Tree(Lemma('self-sufficient.s.01.self-sustaining'), ['self-sustaining']), Tree(Lemma('growth.n.02.growth'), ['growth']), ['.']]
# [['As'], ['he'], Tree(Lemma('comment.v.01.point_out'), ['points', 'out']), [','], ['a'], Tree('religious.a.00', ['religious']), Tree(Lemma('group.n.01.group'), ['group']), ['cannot'], Tree(Lemma('exist.v.01.exist'), ['exist']), ['without'], ['a'], Tree(Lemma('corporate.s.03.collective'), ['collective']), Tree(Lemma('creed.n.01.credo'), ['credo']), [','], ['and'], ['the'], Tree(Lemma('more.r.01.more'), ['more']), Tree(Lemma('across-the-board.s.01.extensive'), ['extensive']), ['the'], Tree(Lemma('creed.n.01.credo'), ['credo']), [','], ['the'], Tree(Lemma('more.r.01.more'), ['more']), Tree(Lemma('incorporate.s.01.unified'), ['unified']), ['and'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('be.v.01.be'), ['is']), ['the'], Tree(Lemma('group.n.01.group'), ['group']), ['.']]
# [['As'], ['the'], Tree(Lemma('more.a.01.more'), ['more']), Tree(Lemma('conservative.a.01.conservative'), ['conservative']), Tree(Lemma('group.n.01.group'), ['group']), ['with'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('backing.n.01.backing'), ['backing']), ['from'], Tree(Lemma('affluent.s.01.wealthy'), ['wealthy']), Tree(Lemma('businessmen.n.01.businessmen'), ['businessmen']), [','], ['the'], Tree(Lemma('group.n.01.group'), [Tree('NE', ['U.M.C.I.A.'])]), ['was'], Tree(Lemma('by_and_large.r.01.generally'), ['generally']), Tree(Lemma('prefer.v.03.favor'), ['favored']), ['against'], ['the'], Tree(Lemma('more.a.01.more'), ['more']), Tree(Lemma('progressive.s.02.progressive'), ['progressive']), [','], Tree(Lemma('labor.n.01.labor'), ['labor']), Tree(Lemma('based.s.01.based'), ['based']), Tree(Lemma('group.n.01.group'), [Tree('NE', ['U.N.F.P.'])]), ['The'], Tree(Lemma('new.a.01.new'), ['newer']), Tree(Lemma('party.n.01.party'), ['party']), Tree(Lemma('campaign.v.01.campaign'), ['campaigned']), Tree(Lemma('heavily.r.01.heavily'), ['heavily']), [','], ['while'], ['the'], Tree(Lemma('old.a.02.old'), ['older']), [','], Tree(Lemma('more.a.01.more'), ['more']), Tree(Lemma('confident.a.01.confident'), ['confident']), Tree(Lemma('party.n.01.party'), ['party']), Tree(Lemma('expect.v.01.expect'), ['expected']), ['the'], Tree(Lemma('moroccan.a.01.Moroccan'), ['Moroccan']), Tree(Lemma('merchant.n.01.merchant'), ['merchants']), ['and'], Tree(Lemma('small_businessman.n.01.small_businessman'), ['small', 'businessmen']), ['to'], Tree(Lemma('back.v.01.support'), ['support']), ['them'], ['as'], ['they'], ['had'], Tree(Lemma('make.v.01.do'), ['done']), ['for'], Tree(Lemma('many.a.01.many'), ['many']), Tree(Lemma('year.n.01.year'), ['years']), ['.']]
# [['The'], Tree(Lemma('austere.s.01.severe'), ['severe']), ['yet'], Tree(Lemma('harmonious.s.02.harmonious'), ['harmonious']), Tree(Lemma('vase.n.01.vase'), ['vases']), ['of'], ['the'], Tree('previous.s.01', ['previous']), Tree(Lemma('fifty.s.01.fifty'), ['fifty']), Tree(Lemma('year.n.01.year'), ['years']), [','], ['the'], Tree(Lemma('strong.a.01.strong'), ['Strong']), Tree(Lemma('geometric.s.01.geometric'), ['Geometric']), Tree(Lemma('manner.n.01.style'), ['style']), ['of'], ['the'], Tree(Lemma('late.a.01.late'), ['late']), Tree(Lemma('ninth.s.01.ninth'), ['ninth']), Tree(Lemma('century.n.01.century'), ['century']), [','], Tree(Lemma('expose.v.03.display'), ['display']), ['as'], Tree(Lemma('firm.s.03.firm'), ['firm']), ['a'], Tree(Lemma('command.n.06.mastery'), ['mastery']), ['of'], ['the'], Tree(Lemma('principle.n.01.principle'), ['principles']), Tree(Lemma('implicit_in.s.01.underlying'), ['underlying']), Tree(Lemma('geometric.s.01.geometric'), ['Geometric']), Tree(Lemma('pottery.n.01.pottery'), ['pottery']), [';'], ['but'], Tree(Lemma('artist.n.01.artist'), ['artists']), Tree(Lemma('now.r.01.now'), ['now']), Tree(Lemma('be.v.01.be'), ['were']), Tree(Lemma('ready.a.01.ready'), ['ready']), ['to'], Tree(Lemma('polish.v.02.refine'), ['refine']), ['and'], Tree(Lemma('elaborate.v.01.elaborate'), ['elaborate']), ['their'], Tree(Lemma('inheritance.n.01.inheritance'), ['inheritance']), ['.']]
# [['The'], Tree(Lemma('appeal.n.02.appeal'), ['appeal']), ['of'], ['the'], Tree(Lemma('suburb.n.01.suburb'), ['suburb']), Tree(Lemma('be.v.01.be'), ['is']), Tree(Lemma('particularly.r.01.particularly'), ['particularly']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['for'], Tree(Lemma('heavy.a.03.heavy'), ['heavy']), Tree(Lemma('industry.n.02.industry'), ['industry']), [','], ['which'], ['must'], Tree(Lemma('move.v.02.move'), ['move']), Tree(Lemma('bulky.s.01.bulky'), ['bulky']), Tree(Lemma('object.n.01.object'), ['objects']), ['along'], ['a'], Tree(Lemma('drawn-out.s.01.lengthy'), ['lengthy']), Tree(Lemma('production_line.n.01.assembly_line'), ['assembly', 'line']), ['and'], Tree(Lemma('want.v.02.want'), ['wants']), Tree(Lemma('adequate.s.02.enough'), ['enough']), Tree(Lemma('acreage.n.01.land_area'), ['land', 'area']), ['to'], Tree(Lemma('do.v.03.do'), ['do']), ['the'], Tree(Lemma('entire.s.01.entire'), ['entire']), Tree(Lemma('job.n.02.job'), ['job']), ['on'], Tree(Lemma('one.s.01.one'), ['one']), Tree(Lemma('floor.n.02.floor'), ['floor']), ['.']]
# [['The'], Tree(Lemma('doctor.n.01.doctor'), ['doctors']), ['had'], Tree(Lemma('indicate.v.05.suggest'), ['suggested']), Tree(Lemma('person.n.01.person'), [Tree('NE', ['Scotty'])]), Tree(Lemma('stay.v.01.remain'), ['remain']), Tree(Lemma('about.r.07.most'), ['most']), ['of'], Tree('every.s.02', ['every']), Tree(Lemma('afternoon.n.01.afternoon'), ['afternoon']), ['in'], Tree(Lemma('bed.n.01.bed'), ['bed']), ['until'], ['he'], Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('strong.a.01.strong'), ['stronger']), ['.']]
# [['He'], ["'ll"], Tree(Lemma('be.v.01.be'), ['be']), Tree(Lemma('strong.a.01.strong'), ['stronger']), Tree(Lemma('soon.r.01.soon'), ['soon']), ["''"], ['.']]
# [['He'], Tree(Lemma('state.v.01.say'), ['said']), Tree(Lemma('fussily.r.01.fussily'), ['fussily']), [','], ['``'], Tree(Lemma('merely.r.01.just'), ['Just']), Tree(Lemma('keep.v.01.keep'), ['keep']), ['the'], Tree(Lemma('cap.n.02.cap'), ['cap']), ['on'], ['those'], Tree(Lemma('strong.s.02.strong'), ['strong']), Tree(Lemma('emotion.n.01.emotion'), ['emotions']), ["''"], ['.']]
# [['We'], ["'ll"], Tree(Lemma('expect.v.03.wait'), ['wait']), ['till'], ['you'], ["'re"], Tree(Lemma('strong.a.01.strong'), ['stronger']), ['and'], Tree(Lemma('then.r.01.then'), ['then']), Tree(Lemma('discourse.v.01.talk_about'), ['talk', 'about']), ['it'], ["''"], ['.']]
# [['He'], Tree(Lemma('look.v.01.look'), ['looked']), ['at'], ['the'], Tree(Lemma('lined.s.02.lined'), ['lined']), Tree(Lemma('face.n.01.face'), ['face']), ['with'], Tree(Lemma('obscure.s.01.vague'), ['vague']), Tree(Lemma('interest.n.01.interest'), ['interest']), [';'], ['he'], Tree(Lemma('find.v.05.feel'), ['felt']), ['he'], ['was'], Tree(Lemma('note.v.03.note'), ['noting']), ['it'], [','], ['as'], ['if'], ['it'], Tree(Lemma('be.v.01.be'), ['were']), ['something'], ['he'], ['might'], Tree(Lemma('think_about.v.01.think_about'), ['think', 'about']), ['when'], ['he'], Tree(Lemma('turn.v.07.grow'), ['grew']), Tree(Lemma('strong.a.01.strong'), ['stronger']), ['.']]
# [['When'], Tree(Lemma('dad.n.01.papa'), ['Papa']), ["'s"], Tree(Lemma('slender.s.01.slender'), ['slender']), Tree(Lemma('finger.n.01.finger'), ['fingers']), Tree(Lemma('remove.v.01.remove'), ['removed']), ['the'], Tree(Lemma('spectacles.n.01.spectacles'), ['spectacles']), [','], ['there'], Tree(Lemma('exist.v.01.be'), ['were']), Tree(Lemma('red.s.01.red'), ['red']), Tree(Lemma('indentation.n.01.indentation'), ['indentations']), ['on'], ['the'], Tree(Lemma('bridge.n.04.bridge'), ['bridge']), ['of'], ['the'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('nose.n.01.nose'), ['nose']), ['.']]
# [Tree(Lemma('faraway.s.01.far-off'), ['Far', 'off']), [','], ['in'], ['the'], Tree('dusk.n.00', ['dusk']), [','], ['he'], Tree(Lemma('hear.v.01.hear'), ['heard']), Tree(Lemma('voice.n.02.voice'), ['voices']), Tree(Lemma('sing.v.02.sing'), ['singing']), [','], Tree(Lemma('dull.s.03.muffled'), ['muffled']), ['but'], Tree(Lemma('strong.a.01.strong'), ['strong']), ['.']]
# [['He'], Tree(Lemma('spend.v.01.spend'), ['spent']), Tree(Lemma('concentrated.s.03.concentrated'), ['concentrated']), Tree(Lemma('week.n.01.week'), ['weeks']), Tree(Lemma('put.v.01.put'), ['putting']), ['his'], Tree(Lemma('two.s.01.two'), ['two']), Tree(Lemma('figure.n.04.figure'), ['figures']), Tree(Lemma('together.r.02.together'), ['together']), [':'], ['a'], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Mary'])]), ['who'], ['would'], Tree(Lemma('be.v.01.be'), ['be']), Tree(Lemma('young.a.01.young'), ['young']), ['and'], Tree(Lemma('sensitive.a.02.sensitive'), ['sensitive']), [','], ['yet'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('enough.r.01.enough'), ['enough']), ['to'], Tree('hold.v.1;2', ['hold']), ['her'], Tree(Lemma('son.n.01.son'), ['son']), ['on'], ['her'], Tree(Lemma('lap.n.01.lap'), ['lap']), [';'], ['and'], ['a'], Tree(Lemma('jesus.n.01.Jesus'), ['Jesus']), ['who'], [','], ['though'], Tree(Lemma('thin.a.02.lean'), ['lean']), [','], Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('even.r.01.even'), ['even']), ['in'], Tree(Lemma('death.n.03.death'), ['death']), ['-'], ['a'], Tree(Lemma('look.n.03.look'), ['look']), ['he'], Tree(Lemma('remember.v.01.remember'), ['remembered']), Tree(Lemma('well.r.01.well'), ['well']), ['from'], ['his'], Tree(Lemma('experience.n.02.experience'), ['experience']), ['in'], ['the'], Tree(Lemma('morgue.n.01.dead_room'), ['dead', 'room']), ['of'], Tree(Lemma('group.n.01.group'), [Tree('NE', ['Santo', 'Spirito'])]), ['.']]
# [['He'], Tree(Lemma('spend.v.01.spend'), ['spent']), Tree(Lemma('concentrated.s.03.concentrated'), ['concentrated']), Tree(Lemma('week.n.01.week'), ['weeks']), Tree(Lemma('put.v.01.put'), ['putting']), ['his'], Tree(Lemma('two.s.01.two'), ['two']), Tree(Lemma('figure.n.04.figure'), ['figures']), Tree(Lemma('together.r.02.together'), ['together']), [':'], ['a'], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Mary'])]), ['who'], ['would'], Tree(Lemma('be.v.01.be'), ['be']), Tree(Lemma('young.a.01.young'), ['young']), ['and'], Tree(Lemma('sensitive.a.02.sensitive'), ['sensitive']), [','], ['yet'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('enough.r.01.enough'), ['enough']), ['to'], Tree('hold.v.1;2', ['hold']), ['her'], Tree(Lemma('son.n.01.son'), ['son']), ['on'], ['her'], Tree(Lemma('lap.n.01.lap'), ['lap']), [';'], ['and'], ['a'], Tree(Lemma('jesus.n.01.Jesus'), ['Jesus']), ['who'], [','], ['though'], Tree(Lemma('thin.a.02.lean'), ['lean']), [','], Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('even.r.01.even'), ['even']), ['in'], Tree(Lemma('death.n.03.death'), ['death']), ['-'], ['a'], Tree(Lemma('look.n.03.look'), ['look']), ['he'], Tree(Lemma('remember.v.01.remember'), ['remembered']), Tree(Lemma('well.r.01.well'), ['well']), ['from'], ['his'], Tree(Lemma('experience.n.02.experience'), ['experience']), ['in'], ['the'], Tree(Lemma('morgue.n.01.dead_room'), ['dead', 'room']), ['of'], Tree(Lemma('group.n.01.group'), [Tree('NE', ['Santo', 'Spirito'])]), ['.']]
# [['I'], Tree(Lemma('write.v.05.write'), ['wrote']), ['her'], ['that'], ['I'], ["'d"], Tree(Lemma('meet_up_with.v.01.meet_up_with'), ['met', 'up', 'with']), Tree(Lemma('person.n.01.person'), [Tree('NE', ['Eileen'])]), ['and'], ['that'], Tree(Lemma('old.a.02.old'), ['old']), Tree(Lemma('attachment.n.04.bond'), ['bonds']), ['had'], Tree(Lemma('prove.v.01.prove'), ['proved']), Tree(Lemma('excessively.r.01.too'), ['too']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['and'], Tree(Lemma('ask.v.02.ask'), ['asked']), ['her'], ['to'], Tree(Lemma('transport.v.04.send'), ['send']), ['my'], Tree(Lemma('apparel.n.01.clothes'), ['clothes']), Tree(Lemma('down.r.01.down'), ['down']), ['by'], Tree(Lemma('express.r.01.express'), ['express']), ['.']]
# [['It'], Tree(Lemma('persevere.v.01.hang_in'), ['hung', 'in']), ['all'], ['her'], Tree(Lemma('day.n.04.day'), ['day']), Tree(Lemma('apparel.n.01.clothes'), ['clothes']), [','], Tree(Lemma('odoriferous.s.03.sweet'), ['sweet']), ['and'], Tree(Lemma('strong.s.02.strong'), ['strong']), [';'], Tree(Lemma('sometimes.r.01.sometimes'), ['sometimes']), ['when'], ['he'], ['was'], Tree(Lemma('press.v.04.press'), ['pressing']), [','], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Winston'])]), Tree(Lemma('raise.v.02.raise'), ['raised']), ['her'], Tree(Lemma('dress.n.01.dress'), ['dresses']), ['to'], ['his'], Tree(Lemma('face.n.01.face'), ['face']), ['.']]
# [['His'], Tree(Lemma('face.n.01.face'), ['face']), Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('rubicund.s.01.ruddy'), ['ruddy']), ['and'], Tree(Lemma('heavy.a.01.heavy'), ['heavy']), ['and'], Tree(Lemma('seamless.s.02.unlined'), ['unlined']), [','], ['and'], ['when'], ['he'], Tree(Lemma('laugh.v.01.laugh'), ['laughed']), ['he'], Tree(Lemma('show.v.04.show'), ['showed']), ['his'], Tree(Lemma('tooth.n.01.tooth'), ['teeth']), [','], ['which'], Tree(Lemma('be.v.01.be'), ['were']), Tree(Lemma('large.a.01.big'), ['big']), ['and'], Tree(Lemma('white.a.01.white'), ['white']), ['and'], Tree(Lemma('strong.a.01.strong'), ['strong']), ['and'], Tree(Lemma('unquestionably.r.01.unquestionably'), ['unquestionably']), Tree(Lemma('homegrown.s.01.homegrown'), ['home-grown']), ['.']]
# [['He'], Tree(Lemma('feel.v.06.feel'), ['felt']), ['a'], Tree(Lemma('puppyish.s.01.puppyish'), ['puppyish']), Tree(Lemma('motivation.n.01.need'), ['need']), ['for'], Tree(Lemma('company.n.03.company'), ['company']), ['as'], Tree(Lemma('strong.a.01.strong'), ['strong']), ['as'], ['his'], Tree('earlier.s.00', ['earlier']), Tree(Lemma('necessity.n.01.necessity'), ['necessity']), ['for'], Tree(Lemma('lull.n.02.quiet'), ['quiet']), ['.']]
# [Tree(Lemma('again.r.01.again'), ['Again']), [','], ['a'], Tree(Lemma('force.n.02.force'), ['force']), Tree(Lemma('excessively.r.01.too'), ['too']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['for'], Tree(Lemma('unfrozen.a.01.unfrozen'), ['unfrozen']), Tree(Lemma('body.n.01.body'), ['bodies']), ['to'], Tree(Lemma('weather.v.01.endure'), ['endure']), ['would'], ['be'], Tree(Lemma('use.v.01.apply'), ['applied']), ['.']]
# [['That'], ['he'], Tree(Lemma('master.v.01.master'), ['mastered']), ['every'], Tree(Lemma('aspect.n.01.aspect'), ['aspect']), ['of'], ['his'], Tree(Lemma('medium.n.01.medium'), ['medium']), ['according', 'to'], ['his'], Tree(Lemma('own.s.01.own'), ['own']), Tree(Lemma('great.s.03.great'), ['great']), Tree(Lemma('endowment.n.01.talent'), ['talents']), ['and'], Tree(Lemma('contemporary.s.01.contemporary'), ['contemporary']), Tree(Lemma('judgment.n.01.judgment'), ['judgments']), [','], Tree(Lemma('constitute.v.01.be'), ['is']), ['a'], Tree(Lemma('estimable.s.02.good'), ['good']), ['and'], Tree('solid.s.00', ['solid']), Tree(Lemma('symbol.n.01.symbol'), ['symbol']), ['of'], ['his'], Tree(Lemma('people.n.01.people'), ['people']), ['under'], ['the'], Tree(Lemma('enormous.s.01.tremendous'), ['tremendous']), Tree(Lemma('pressure.n.02.pressure'), ['pressures']), ['of'], Tree(Lemma('laud.v.01.proclaim'), ['proclaiming']), ['and'], Tree(Lemma('rehearse.v.01.practise'), ['practising']), ['the'], Tree(Lemma('asperity.n.01.rigor'), ['rigors']), ['of'], ['a'], Tree(Lemma('new.a.01.new'), ['new']), Tree(Lemma('culture.n.01.culture'), ['culture']), [';'], ['and'], Tree(Lemma('possibly.r.01.perhaps'), ['perhaps']), ['of'], Tree(Lemma('even.r.01.even'), ['even']), Tree(Lemma('greater.a.01.greater'), ['greater']), Tree(Lemma('significance.n.01.significance'), ['significance']), ['-'], ['his'], Tree(Lemma('music.n.01.music'), ['music']), Tree(Lemma('be.v.01.be'), ['is']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('twentieth.s.01.20th'), ['20', 'th']), Tree(Lemma('century.n.01.century'), ['Century']), Tree(Lemma('evidence.n.01.evidence'), ['evidence']), ['of'], ['the'], Tree(Lemma('effectiveness.n.01.effectiveness'), ['effectiveness']), ['of'], Tree(Lemma('development.n.02.evolution'), ['Evolution']), [','], Tree(Lemma('based.s.01.based'), ['based']), ['on'], ['a'], Tree(Lemma('across-the-board.s.01.broad'), ['broad']), Tree(Lemma('traditionalism.n.02.traditionalism'), ['Traditionalism']), ['for'], ['the'], Tree(Lemma('creative.a.01.creative'), ['creative']), Tree(Lemma('art.n.01.art'), ['art']), ['of'], Tree(Lemma('music.n.01.music'), ['music']), ['.']]
# [Tree(Lemma('person.n.01.person'), [Tree('NE', ['Han'])]), ["'s"], Tree(Lemma('student.n.01.student'), ['student']), Tree(Lemma('day.n.02.day'), ['days']), Tree(Lemma('be.v.05.be'), ['were']), ['at', 'a'], Tree(Lemma('time.n.03.time'), ['time']), ['when'], Tree(Lemma('europe.n.01.Europe'), ['Europe']), Tree(Lemma('be.v.01.be'), ['was']), ['in'], ['a'], Tree(Lemma('new.a.01.new'), ['new']), Tree('intellectual.a.00', ['intellectual']), Tree(Lemma('agitation.n.02.ferment'), ['ferment']), Tree(Lemma('postdate.v.01.follow'), ['following']), ['the'], Tree(Lemma('revolution.n.02.revolution'), ['revolutions']), ['in'], Tree(Lemma('united_states.n.01.America'), ['America']), ['and'], ['in'], Tree(Lemma('france.n.01.France'), ['France']), [','], Tree(Lemma('germany.n.01.Germany'), ['Germany']), ['and'], Tree(Lemma('italy.n.01.Italy'), ['Italy']), ['were'], Tree(Lemma('ascend.v.08.rise'), ['rising']), ['from'], Tree(Lemma('dissentious.s.01.divisive'), ['divisive']), Tree(Lemma('nationalism.n.02.nationalism'), ['nationalisms']), ['and'], ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('wave.n.04.wave'), ['wave']), ['of'], Tree('intellectual.a.00', ['intellectual']), Tree(Lemma('awareness.n.01.awareness'), ['awareness']), ['was'], Tree(Lemma('brush.v.04.sweep'), ['sweeping']), ['the'], Tree(Lemma('continent.n.02.Continent'), ['Continent']), ['.']]
# [['His'], Tree(Lemma('friend.n.01.friend'), ['friends']), Tree(Lemma('be.v.01.be'), ['were']), Tree(Lemma('numerous.s.01.numerous'), ['numerous']), ['and'], ['their'], Tree(Lemma('affiliation.n.01.tie'), ['ties']), ['to'], ['him'], Tree(Lemma('be.v.01.be'), ['were']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['.']]
# [Tree(Lemma('together.r.05.together'), ['Together']), ['they'], Tree(Lemma('besides.r.02.also'), ['also']), Tree(Lemma('develop.v.01.develop'), ['developed']), ['a'], Tree(Lemma('fresh.s.04.new'), ['new']), Tree(Lemma('kind.n.01.form'), ['form']), ['of'], Tree(Lemma('voltaic_cell.n.01.voltaic_cell'), ['voltaic', 'cell']), ['in'], ['which'], ['the'], Tree(Lemma('wooden.s.01.wooden'), ['wooden']), Tree(Lemma('gutter.n.01.trough'), ['trough']), ['was'], Tree(Lemma('replace.v.01.replace'), ['replaced']), ['by'], ['one'], ['of'], Tree(Lemma('copper.n.01.copper'), ['copper']), [','], Tree(Lemma('thereby.r.01.thereby'), ['thereby']), Tree(Lemma('produce.v.02.produce'), ['producing']), Tree(Lemma('strong.a.01.strong'), ['stronger']), Tree(Lemma('current.n.01.current'), ['currents']), ['.']]
# [['The'], Tree('resulting.s.00', ['resulting']), Tree(Lemma('magnetic.a.01.magnetic'), ['magnetic']), Tree(Lemma('consequence.n.01.effect'), ['effect']), Tree(Lemma('prove.v.01.prove'), ['proved']), Tree(Lemma('strong.a.01.strong'), ['stronger']), ['than'], ['when'], ['the'], Tree(Lemma('discharge.n.01.discharge'), ['discharge']), ['was'], Tree(Lemma('make.v.03.make'), ['made']), Tree(Lemma('lengthways.r.01.lengthwise'), ['lengthwise']), ['.']]
# [Tree('one.s.00', ['One']), Tree('such.s.00', ['such']), Tree(Lemma('wife.n.01.wife'), ['wife']), [','], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Dr.', 'Linden'])]), Tree(Lemma('state.v.01.say'), ['says']), [','], Tree(Lemma('become.v.01.become'), ['became']), Tree(Lemma('disgusted.s.01.disgusted'), ['disgusted']), ['with'], ['her'], Tree(Lemma('weak.a.01.weak'), ['weak']), Tree(Lemma('husband.n.01.husband'), ['husband']), ['and'], Tree(Lemma('flurry.v.01.flurry'), ['flurried']), ['through'], ['a'], Tree(Lemma('series.n.01.series'), ['series']), ['of'], Tree(Lemma('adulterous.s.01.extramarital'), ['extramarital']), Tree(Lemma('affair.n.02.affair'), ['affairs']), ['in'], ['the'], Tree(Lemma('hope.n.01.hope'), ['hope']), ['of'], Tree(Lemma('find.v.01.find'), ['finding']), ['a'], Tree(Lemma('strong.a.01.strong'), ['stronger']), Tree(Lemma('man.n.01.man'), ['man']), ['.']]
# [['The'], Tree(Lemma('tune.n.01.strain'), ['strains']), ['of'], Tree(Lemma('neutralism.n.01.neutralism'), ['neutralism']), ['are'], Tree('run.v.14;17', ['running']), Tree(Lemma('strong.a.01.strong'), ['strong']), [','], Tree(Lemma('notably.r.01.notably'), ['notably']), ['in'], Tree(Lemma('england.n.01.England'), ['England']), [','], ['and'], Tree(Lemma('even.r.01.even'), ['even']), ['in'], Tree(Lemma('germany.n.01.Germany'), ['Germany']), ['.']]
# [Tree(Lemma('besides.r.02.also'), ['Also']), [','], ['since'], ['the'], Tree(Lemma('man.n.01.man'), ['man']), Tree(Lemma('interrogate.v.02.question'), ['questioned']), Tree(Lemma('feel.v.01.feel'), ['feels']), ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('compulsion.n.01.compulsion'), ['compulsion']), ['to'], Tree(Lemma('answer.v.01.answer'), ['answer']), ['('], ['and'], Tree(Lemma('thereby.r.01.thereby'), ['thereby']), Tree(Lemma('debar.v.02.avoid'), ['avoid']), ['the'], Tree(Lemma('consequence.n.01.consequence'), ['consequences']), ['of'], ['being'], Tree(Lemma('think.v.01.think'), ['thought']), Tree(Lemma('curious.s.01.queer'), ['queer']), [')'], ['the'], Tree(Lemma('question.n.03.question'), ['question']), ['has'], Tree(Lemma('assume.v.03.assume'), ['assumed']), ['some'], Tree(Lemma('measurable.a.01.measurable'), ['measurable']), Tree(Lemma('property.n.02.property'), ['properties']), ['of'], ['a'], Tree(Lemma('command.n.01.command'), ['command']), ['.']]
# [Tree(Lemma('then.r.03.then'), ['Then']), Tree(Lemma('suddenly.r.01.suddenly'), ['suddenly']), ['we'], Tree(Lemma('find.v.13.find'), ['found']), ['ourselves'], ['in'], ['the'], Tree(Lemma('center.n.01.middle'), ['middle']), ['of'], ['another'], Tree(Lemma('fight.n.02.fight'), ['fight']), [','], ['an'], Tree(Lemma('irrational.a.01.irrational'), ['irrational']), [','], ['an'], Tree(Lemma('indecent.s.01.indecent'), ['indecent']), [','], ['an'], Tree(Lemma('undeclared.a.01.undeclared'), ['undeclared']), ['and'], Tree(Lemma('base.s.04.immoral'), ['immoral']), Tree(Lemma('war.n.01.war'), ['war']), ['with'], ['our'], Tree(Lemma('potent.s.02.strong'), ['strongest']), ['('], ['and'], ['some'], ['had'], Tree(Lemma('think.v.01.think'), ['thought']), Tree('noble.s.00', ['noblest']), [')'], Tree(Lemma('ally.n.01.ally'), ['ally']), ['.']]
# [Tree(Lemma('woman.n.01.woman'), ['Women']), ['themselves'], ['have'], Tree(Lemma('come.v.04.come'), ['come']), ['to'], Tree(Lemma('think_of.v.03.look_upon'), ['look', 'upon']), Tree(Lemma('matter.n.01.matter'), ['matters']), ['in'], ['the'], Tree(Lemma('same.a.02.same'), ['same']), Tree(Lemma('light.n.03.light'), ['light']), ['as'], ['the'], Tree(Lemma('outside.s.03.outside'), ['outside']), Tree(Lemma('world.n.03.world'), ['world']), [','], ['and'], Tree(Lemma('barely.r.01.scarcely'), ['scarcely']), Tree(Lemma('find.v.05.find'), ['find']), ['any'], Tree(Lemma('wrong.n.01.wrong'), ['wrong']), ['in'], Tree(Lemma('submit.v.06.submit'), ['submitting']), ['to'], ['the'], Tree(Lemma('importunity.n.01.importunity'), ['importunities']), ['of'], ['a'], Tree(Lemma('potent.s.02.strong'), ['stronger']), Tree(Lemma('volition.n.01.will'), ['will']), [','], ['even'], ['when'], ['their'], Tree(Lemma('affection.n.01.affection'), ['affections']), ['are'], Tree(Lemma('withhold.v.01.withhold'), ['withheld']), ['.']]
# [['Though'], ['they'], ['would'], Tree(Lemma('produce.v.01.produce'), ['produce']), Tree(Lemma('some.a.01.some'), ['some']), Tree(Lemma('very.r.01.very'), ['very']), Tree(Lemma('memorable.s.01.memorable'), ['memorable']), ['and'], Tree(Lemma('durable.s.01.lasting'), ['lasting']), Tree(Lemma('song.n.01.song'), ['songs']), [','], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Arlen'])]), ['and'], Tree(Lemma('person.n.01.person'), [Tree('NE', ['Mercer'])]), ['were'], Tree(Lemma('not.r.01.not'), ['not']), Tree(Lemma('give.v.03.give'), ['given']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('material.n.02.material'), ['material']), ['to'], Tree(Lemma('work.v.05.work_on'), ['work', 'on']), ['.']]
# [['With'], ['her'], Tree(Lemma('son.n.01.son'), ['son']), Tree(Lemma('attest.v.01.evidence'), ['evidencing']), Tree(Lemma('so.r.01.so'), ['so']), Tree(Lemma('strong.s.02.strong'), ['strong']), ['a'], Tree(Lemma('musical.a.02.musical'), ['musical']), Tree(Lemma('bent.n.01.bent'), ['bent']), ['his'], Tree(Lemma('mother.n.01.mother'), ['mother']), ['could'], ['do'], ['little'], Tree('else.r.00', ['else']), ['but'], Tree(Lemma('get.v.03.get'), ['get']), ['him'], Tree(Lemma('get_down.v.07.start'), ['started']), ['on'], ['the'], Tree(Lemma('study.n.02.study'), ['study']), ['of'], Tree(Lemma('music.n.01.music'), ['music']), ['-'], ['though'], ['she'], Tree(Lemma('wait.v.02.wait'), ['waited']), ['until'], ['he'], Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('ten.s.01.ten'), ['ten']), ['-'], Tree('begin.v.00', ['beginning']), ['with'], ['the'], Tree(Lemma('piano.n.01.piano'), ['piano']), ['and'], Tree(Lemma('follow.v.10.follow'), ['following']), ['that'], ['with'], ['the'], Tree(Lemma('cornet.n.01.trumpet'), ['trumpet']), ['.']]
# [['This'], Tree(Lemma('involve.v.05.involve'), ['involves']), ['the'], Tree(Lemma('application.n.03.application'), ['application']), ['of'], ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('magnetic_field.n.01.magnetic_field'), ['magnetic', 'field']), ['to'], ['the'], Tree(Lemma('free_radical.n.01.radical'), ['radical']), Tree(Lemma('vaporization.n.02.vapor'), ['vapor']), [','], ['which'], Tree(Lemma('shift.v.02.shift'), ['shifts']), ['the'], Tree(Lemma('low_frequency.n.01.low_frequency'), ['low-frequency']), Tree(Lemma('spectrum.n.01.spectrum'), ['spectra']), ['to'], ['a'], Tree(Lemma('handily.r.01.conveniently'), ['conveniently']), Tree(Lemma('high.a.01.high'), ['high']), Tree(Lemma('microwave.n.01.microwave'), ['microwave']), Tree(Lemma('scope.n.01.range'), ['range']), [','], ['where'], ['they'], ['may'], ['be'], Tree(Lemma('quantify.v.02.measure'), ['measured']), ['with'], Tree(Lemma('optimum.s.01.optimum'), ['optimum']), Tree(Lemma('sensitivity.n.02.sensitivity'), ['sensitivity']), ['.']]
# [Tree(Lemma('result.n.03.result'), ['Results']), ['of', 'this'], Tree(Lemma('experiment.n.02.experiment'), ['experiment']), Tree(Lemma('include.v.01.include'), ['include']), ['the'], Tree(Lemma('frequency.n.01.frequency'), ['frequencies']), ['of'], ['the'], Tree(Lemma('two.s.01.two'), ['two']), Tree(Lemma('strong.s.02.strong'), ['strong']), Tree(Lemma('spectral.a.01.spectral'), ['spectral']), Tree(Lemma('line.n.06.line'), ['lines']), ['by'], ['which'], ['OH'], ['may'], ['be'], Tree(Lemma('identify.v.01.identify'), ['identified']), ['in'], Tree(Lemma('interstellar.a.01.interstellar'), ['interstellar']), Tree(Lemma('gas.n.01.gas'), ['gas']), [';'], ['the'], Tree(Lemma('frequency.n.01.frequency'), ['frequencies']), Tree(Lemma('be.v.02.be'), ['are']), ['1665.32'], ['and'], ['1667.36'], ['*'], ['*'], ['f'], [','], ['with'], ['an'], Tree(Lemma('uncertainty.n.01.uncertainty'), ['uncertainty']), ['of'], ['0.10'], ['*'], ['*'], ['f'], ['.']]
# [['``'], ['The'], Tree(Lemma('logic.n.03.logic'), ['logic']), ['of'], Tree(Lemma('create.v.02.create'), ['creating']), ['a'], Tree(Lemma('strong.a.01.strong'), ['strong']), [','], Tree(Lemma('balanced.a.01.balanced'), ['balanced']), [','], Tree(Lemma('competitive.s.02.competitive'), ['competitive']), Tree(Lemma('two.s.01.two'), ['two']), Tree(Lemma('system.n.02.system'), ['system']), Tree(Lemma('railway.n.01.railroad'), ['railroad']), Tree(Lemma('service.n.01.service'), ['service']), ['in'], ['the'], Tree(Lemma('east.n.03.East'), ['East']), Tree(Lemma('exist.v.01.be'), ['is']), Tree(Lemma('so.r.01.so'), ['so']), Tree('obvious.a.0;1', ['obvious']), ['that'], Tree(Lemma('group.n.01.group'), [Tree('NE', ['B.', '+', 'O.'])]), ['was'], Tree(Lemma('publicly.r.01.publicly'), ['publicly']), Tree(Lemma('give.v.18.commit'), ['committed']), ['to'], ['the'], Tree(Lemma('approach.n.01.approach'), ['approach']), Tree(Lemma('sketch.v.02.outline'), ['outlined']), Tree(Lemma('here.r.02.here'), ['here']), ['.']]
# [Tree(Lemma('possibly.r.01.possibly'), ['Possibly']), ['their'], Tree(Lemma('compulsiveness.n.01.compulsivity'), ['compulsivity']), Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('not.r.01.not'), ['not']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('enough.r.01.enough'), ['enough']), ['to'], Tree(Lemma('induce.v.02.cause'), ['cause']), ['them'], ['to'], Tree(Lemma('construct.v.01.build'), ['build']), ['their'], Tree(Lemma('own.s.01.own'), ['own']), Tree(Lemma('structure.n.03.structure'), ['structure']), ['.']]
# [Tree(Lemma('doubt.n.01.doubt'), ['Doubt']), ['on'], ['this'], Tree(Lemma('detail.n.01.point'), ['point']), Tree(Lemma('be.v.01.be'), ['is']), Tree(Lemma('strong.a.01.strong'), ['strongest']), ['before'], ['/'], ['l'], ['/'], ['and'], ['/'], ['/'], ['or'], ['/'], ['r'], ['/'], ['.']]
# [['He'], Tree(Lemma('open.v.01.open'), ['opened']), ['the'], Tree(Lemma('inner.a.02.inner'), ['inner']), Tree(Lemma('door.n.01.door'), ['door']), [';'], ['the'], Tree(Lemma('cooking.n.01.cooking'), ['cooking']), Tree(Lemma('olfactory_property.n.01.odor'), ['odors']), Tree(Lemma('be.v.01.be'), ['were']), Tree(Lemma('strong.s.02.strong'), ['stronger']), ['-'], Tree(Lemma('everywhere.r.01.all_over'), ['all', 'over']), ['the'], Tree(Lemma('city.n.01.city'), ['city']), [','], ['at'], ['this'], Tree(Lemma('hour.n.02.hour'), ['hour']), [','], Tree(Lemma('housewife.n.01.housewife'), ['housewives']), ['would'], ['be'], Tree(Lemma('fuss.v.01.fuss'), ['fussing']), ['over'], Tree(Lemma('stove.n.01.stove'), ['stoves']), ['.']]
# [['The'], Tree(Lemma('cast-off.s.01.discarded'), ['discarded']), Tree(Lemma('document.n.01.papers'), ['papers']), ['inside'], Tree(Lemma('be.v.01.be'), ['were']), Tree(Lemma('sodden.s.01.sodden'), ['sodden']), [','], ['there'], Tree(Lemma('exist.v.01.be'), ['was']), ['a'], Tree(Lemma('flicker.n.01.glint'), ['glint']), ['of'], Tree(Lemma('liquid.a.01.liquid'), ['liquid']), ['at'], ['the'], Tree(Lemma('bottom.n.01.bottom'), ['bottom']), [','], ['and'], ['the'], Tree(Lemma('smell.n.01.smell'), ['smell']), ['of'], Tree(Lemma('whiskey.n.01.whisky'), ['whisky']), Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('strong.s.02.strong'), ['strong']), ['and'], Tree(Lemma('distinct.a.02.distinct'), ['distinct']), ['.']]
# [['He'], ['could'], Tree('move.v.3;1', ['move']), Tree(Lemma('very.r.01.very'), ['very']), Tree(Lemma('quickly.r.01.quickly'), ['quickly']), [','], ['she'], Tree(Lemma('know.v.01.know'), ['knew']), ['('], ['although'], ['he'], Tree(Lemma('rarely.r.01.seldom'), ['seldom']), Tree(Lemma('find.v.01.find'), ['found']), Tree(Lemma('occasion.n.03.occasion'), ['occasion']), ['to'], Tree(Lemma('perform.v.01.do'), ['do']), Tree(Lemma('so.r.03.so'), ['so']), [')'], [','], ['but'], ['he'], Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('more.r.01.more'), ['more']), Tree(Lemma('stringy.s.01.wiry'), ['wiry']), ['than'], Tree(Lemma('truly.r.01.truly'), ['truly']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['.']]
# [['He'], Tree(Lemma('immediately.r.01.immediately'), ['immediately']), Tree(Lemma('ride.v.01.ride'), ['rode']), Tree(Lemma('along.r.01.on'), ['on']), ['to'], Tree(Lemma('cheyenne.n.01.Cheyenne'), ['Cheyenne']), [','], Tree(Lemma('hold.v.03.throw'), ['threw']), ['a'], Tree(Lemma('ten.s.01.ten'), ['ten']), Tree(Lemma('day.n.01.day'), ['day']), Tree(Lemma('drink.n.02.drinking'), ['drinking']), Tree(Lemma('spree.n.01.spree'), ['spree']), ['and'], Tree(Lemma('drop.v.06.drop'), ['dropped']), ['some'], Tree(Lemma('very.r.01.very'), ['very']), Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('hint.n.01.hint'), ['hints']), ['among'], Tree(Lemma('friend.n.01.friend'), ['friends']), ['.']]
# [Tree(Lemma('haying.n.02.haying_time'), ['Haying', 'time']), Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('near.r.01.close'), ['close']), Tree(Lemma('at_hand.s.02.at_hand'), ['at', 'hand']), [','], ['and'], ['they'], Tree(Lemma('want.v.02.need'), ['needed']), ['some'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('branch.n.02.branch'), ['branches']), ['to'], Tree(Lemma('repair.v.01.repair'), ['repair']), ['a'], Tree(Lemma('hay.n.01.hay'), ['hay']), Tree(Lemma('rack.n.01.rack'), ['rack']), ['.']]
# [Tree(Lemma('horse.n.01.horse'), ['Horse']), Tree(Lemma('olfactory_property.n.01.smell'), ['smell']), Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('very.r.01.very'), ['very']), Tree(Lemma('strong.s.02.strong'), ['strong']), [','], ['and'], ['he'], ['could'], Tree(Lemma('hear.v.01.hear'), ['hear']), ['the'], Tree(Lemma('crunch.n.01.crunch'), ['crunch']), ['of'], Tree(Lemma('grain.n.02.grain'), ['grain']), ['being'], Tree(Lemma('crunch.v.02.grind'), ['ground']), ['between'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('jaw.n.01.jaw'), ['jaws']), ['.']]
# [Tree(Lemma('horse.n.01.horse'), ['Horse']), Tree(Lemma('olfactory_property.n.01.smell'), ['smell']), Tree(Lemma('be.v.01.be'), ['was']), Tree(Lemma('very.r.01.very'), ['very']), Tree(Lemma('strong.s.02.strong'), ['strong']), [','], ['and'], ['he'], ['could'], Tree(Lemma('hear.v.01.hear'), ['hear']), ['the'], Tree(Lemma('crunch.n.01.crunch'), ['crunch']), ['of'], Tree(Lemma('grain.n.02.grain'), ['grain']), ['being'], Tree(Lemma('crunch.v.02.grind'), ['ground']), ['between'], Tree(Lemma('strong.a.01.strong'), ['strong']), Tree(Lemma('jaw.n.01.jaw'), ['jaws']), ['.']]
# [Tree(Lemma('japanese.a.01.Japanese'), ['Japanese']), Tree(Lemma('aircraft.n.01.aircraft'), ['aircraft']), Tree(Lemma('be.v.01.be'), ['were']), Tree(Lemma('strong.a.01.strong'), ['strong']), ['on'], Tree(Lemma('maneuverability.n.01.maneuverability'), ['maneuverability']), [','], Tree(Lemma('american.a.01.American'), ['American']), ['on'], Tree(Lemma('speed.n.01.speed'), ['speed']), ['and'], Tree(Lemma('firepower.n.01.firepower'), ['firepower']), ['.']]
# Semcor preprocessing finished

# %%
stop_words = stopwords.words('english')

# %%
# !wget -c \https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz\
# Out:
# --2021-09-07 08:42:10--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.85.253
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.85.253|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.

# %%
model_w2v = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz',
binary=True)

# %%
model_w2v["blue"]
# Out:
# array([ 0.0390625 ,  0.08642578,  0.22363281,  0.11865234, -0.08642578,
#        -0.25      ,  0.00558472, -0.24511719,  0.05981445,  0.03027344,
#         0.11083984,  0.10009766, -0.00842285, -0.02404785, -0.328125  ,
#        -0.12597656, -0.20507812,  0.28710938, -0.22265625, -0.24902344,
#        -0.05639648,  0.16796875, -0.11572266, -0.39453125, -0.15332031,
#         0.07568359, -0.10986328,  0.09423828,  0.14941406, -0.13378906,
#         0.0703125 ,  0.11181641,  0.16992188, -0.02868652,  0.07128906,
#        -0.03955078,  0.125     ,  0.09765625, -0.20605469,  0.05737305,
#         0.16894531, -0.0625    , -0.02050781, -0.21289062,  0.23242188,
#         0.02099609, -0.06591797, -0.14941406,  0.10986328,  0.14160156,
#        -0.10791016,  0.171875  ,  0.14941406,  0.02685547,  0.10302734,
#        -0.05224609, -0.02392578, -0.09716797, -0.11962891, -0.12597656,
#        -0.28710938,  0.11914062, -0.03881836, -0.01000977,  0.11962891,
#         0.046875  , -0.31445312,  0.13085938, -0.0025177 ,  0.25195312,
#         0.234375  ,  0.19238281,  0.03112793, -0.13183594, -0.08398438,
#        -0.08300781,  0.24414062,  0.12597656, -0.15625   ,  0.41015625,
#         0.32226562, -0.1953125 , -0.05053711, -0.21191406,  0.03027344,
#        -0.05102539, -0.20507812, -0.1328125 ,  0.10839844, -0.0859375 ,
#        -0.1171875 ,  0.13769531, -0.03393555,  0.16503906, -0.01696777,
#         0.18066406,  0.08496094,  0.12255859,  0.06884766,  0.27929688,
#         0.01147461, -0.11328125,  0.19238281, -0.00631714, -0.09814453,
#        -0.13574219,  0.49609375, -0.00369263, -0.10498047, -0.04541016,
#         0.03198242,  0.0213623 , -0.08740234,  0.18847656,  0.16308594,
#         0.14550781, -0.06298828,  0.12060547,  0.00640869,  0.09375   ,
#         0.13085938, -0.20507812, -0.02624512, -0.15429688,  0.14648438,
#         0.05981445, -0.01196289,  0.05883789,  0.21777344,  0.21875   ,
#        -0.05810547,  0.10644531,  0.0456543 ,  0.16308594, -0.02954102,
#         0.09228516, -0.1640625 ,  0.03039551,  0.08984375,  0.05883789,
#         0.14550781, -0.02087402,  0.00982666,  0.06738281,  0.12402344,
#         0.16796875,  0.03710938, -0.04223633,  0.00369263, -0.13964844,
#         0.17089844,  0.07519531, -0.2265625 ,  0.08691406,  0.14355469,
#        -0.05639648, -0.06738281, -0.04125977, -0.16308594,  0.11425781,
#        -0.234375  ,  0.01318359,  0.359375  ,  0.04101562, -0.02185059,
#        -0.078125  ,  0.10986328, -0.14257812, -0.12353516,  0.07861328,
#        -0.03015137,  0.0625    , -0.20214844,  0.2421875 , -0.20019531,
#        -0.03417969,  0.09033203, -0.16796875, -0.14453125, -0.22851562,
#        -0.12304688, -0.04248047, -0.15136719,  0.12695312, -0.24804688,
#        -0.18164062,  0.10546875,  0.02722168,  0.03173828, -0.00524902,
#        -0.02526855, -0.11621094,  0.00065231,  0.0144043 ,  0.17773438,
#         0.22949219,  0.07714844,  0.07666016, -0.01586914,  0.01904297,
#         0.07714844, -0.08886719, -0.05249023, -0.3046875 ,  0.30273438,
#         0.01904297,  0.12060547, -0.02026367, -0.18457031, -0.10400391,
#         0.01928711, -0.04394531, -0.05786133,  0.01531982,  0.08447266,
#         0.00921631,  0.2890625 , -0.18066406, -0.26171875,  0.00631714,
#        -0.2109375 ,  0.04589844,  0.10351562,  0.22851562, -0.20605469,
#        -0.1953125 ,  0.16796875,  0.26171875, -0.07421875, -0.20117188,
#         0.14941406, -0.03198242,  0.19726562,  0.01843262, -0.05737305,
#        -0.15917969, -0.15820312, -0.16601562,  0.28125   , -0.00970459,
#         0.19433594, -0.10302734, -0.09033203,  0.04492188, -0.00183105,
#         0.0324707 ,  0.07080078, -0.0300293 ,  0.10058594,  0.04443359,
#        -0.09960938, -0.0032959 ,  0.34765625,  0.25976562, -0.05297852,
#        -0.27734375, -0.18847656,  0.08251953, -0.06933594,  0.05566406,
#         0.09765625, -0.09130859, -0.06396484,  0.00823975,  0.18164062,
#         0.08935547, -0.07666016, -0.04223633,  0.06640625, -0.12011719,
#         0.13574219, -0.06201172, -0.13769531,  0.04296875,  0.06347656,
#         0.09082031, -0.12597656, -0.29101562, -0.06054688,  0.28320312,
#        -0.06787109,  0.11230469,  0.33203125,  0.03710938,  0.12011719,
#        -0.03149414,  0.14257812, -0.11865234, -0.21191406, -0.2265625 ,
#         0.05151367, -0.14746094, -0.10400391,  0.0043335 ,  0.16894531,
#        -0.11328125,  0.19238281,  0.04663086,  0.02258301, -0.15722656],
#       dtype=float32)

# %%
text_tokens = word_tokenize(text)

tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]

# %%
gloss = word_tokenize(wn.synset('state.v.01').definition())
        words_in_gloss = [word for word in gloss if not word in stopwords.words()]
        word_embeddings=[]
        for word in words_in_gloss:
            word_embeddings.model_w2v[word]
        word_embedding_con
        for word_context,tag_context in sent:
            if(tag_amb!=tag_context):
                pass

# %%
len([])
# Out:
# 0

# %%
s

# %%
np.sum(model_w2v[word_context.split('_')],axis=0).shape
# Out:
# (300,)

# %%
synCorpus_words=[]
line=0
for sent in synCorpus:
    synCorpus_words.append([])
    for (word,tag) in sent:
        synCorpus_words[line].append(word)
    line+=1
# Out:
# [['group',
#   'say',
#   'Friday',
#   'investigation',
#   'Atlanta',
#   'recent',
#   'primary_election',
#   'produce',
#   'evidence',
#   'irregularity',
#   'take_place'],
#  ['jury',
#   'far',
#   'say',
#   'term',
#   'end',
#   'presentment',
#   'group',
#   'have',
#   'overall',
#   'charge',
#   'election',
#   'deserve',
#   'praise',
#   'thanks',
#   'location',
#   'manner',
#   'election',
#   'conduct'],
#  ['September',
#   'October',
#   'term',
#   'jury',
#   'charge',
#   'location',
#   'person',
#   'investigate',
#   'report',
#   'possible',
#   'irregularity',
#   'hard-fought',
#   'primary',
#   'win',
#   'person'],
#  ['only',
#   'relative',
#   'handful',
#   'report',
#   'receive',
#   'jury',
#   'say',
#   'consider',
#   'widespread',
#   'interest',
#   'election',
#   'number',
#   'voter',
#   'size',
#   'city'],
#  ['jury',
#   'say',
#   'find',
#   'Georgia',
#   'registration',
#   'election',
#   'law',
#   'be',
#   'outmoded',
#   'inadequate',
#   'often',
#   'ambiguous'],
#  ['recommend',
#   'location',
#   'legislator',
#   'act',
#   'have',
#   'law',
#   'study',
#   'revise',
#   'end',
#   'modernize',
#   'improve'],
#  ['grand_jury',
#   'comment',
#   'number',
#   'other',
#   'topic',
#   'Atlanta',
#   'location',
#   'purchasing_department',
#   'say',
#   'be',
#   'well',
#   'operate',
#   'follow',
#   'generally',
#   'practice',
#   'inure',
#   'best',
#   'interest',
#   'government'],
#  ['however',
#   'jury',
#   'say',
#   'believe',
#   'two',
#   'office',
#   'achieve',
#   'efficiency',
#   'reduce',
#   'cost',
#   'administration'],
#  ['group',
#   'jury',
#   'say',
#   'be',
#   'lacking',
#   'experienced',
#   'clerical',
#   'personnel',
#   'result',
#   'city',
#   'personnel',
#   'policy'],
#  ['urge', 'city', 'take', 'step', 'remedy', 'problem'],
#  ['implementation',
#   'Georgia',
#   'automobile',
#   'title',
#   'law',
#   'also',
#   'recommend',
#   'outgoing',
#   'jury'],
#  ['urge',
#   'next',
#   'legislature',
#   'provide',
#   'enabling',
#   'fund',
#   'reset',
#   'effective',
#   'date',
#   'implementation',
#   'law',
#   'effect'],
#  ['grand_jury',
#   'group',
#   'handling',
#   'federal',
#   'fund',
#   'child_welfare_service',
#   'foster_home'],
#  ['be',
#   'one',
#   'major',
#   'item',
#   'location',
#   'general',
#   'assistance',
#   'program',
#   'jury',
#   'say',
#   'group',
#   'distribute',
#   'fund',
#   'welfare',
#   'department',
#   'all',
#   'county',
#   'state',
#   'exception',
#   'location',
#   'receive',
#   'money'],
#  ['juror',
#   'say',
#   'realize',
#   'proportionate',
#   'distribution',
#   'fund',
#   'disable',
#   'program',
#   'less',
#   'populous',
#   'county'],
#  ['nevertheless',
#   'feel',
#   'location',
#   'receive',
#   'some',
#   'portion',
#   'available',
#   'fund',
#   'juror',
#   'say'],
#  ['failure',
#   'do',
#   'continue',
#   'place',
#   'disproportionate',
#   'burden',
#   'location',
#   'taxpayer'],
#  ['jury',
#   'also',
#   'comment',
#   'location',
#   'ordinary',
#   'court',
#   'under_fire',
#   'practice',
#   'appointment',
#   'appraiser',
#   'guardian',
#   'administrator',
#   'awarding',
#   'fee',
#   'compensation'],
#  ['jury',
#   'say',
#   'find',
#   'court',
#   'incorporate',
#   'operating_procedure',
#   'recommendation',
#   'two',
#   'grand_jury',
#   'group',
#   'interim',
#   'citizens_committee'],
#  ['action',
#   'serve',
#   'protect',
#   'in_fact',
#   'in_effect',
#   'court',
#   'ward',
#   'undue',
#   'cost',
#   'appointed',
#   'elected',
#   'servant',
#   'unmeritorious',
#   'criticism',
#   'jury',
#   'say'],
#  ['regard',
#   'Atlanta',
#   'new',
#   'million',
#   'dollar',
#   'airport',
#   'jury',
#   'recommend',
#   'new',
#   'management',
#   'take_charge',
#   'Jan',
#   'airport',
#   'operate',
#   'manner',
#   'eliminate',
#   'political',
#   'influence'],
#  ['jury',
#   'not',
#   'elaborate',
#   'add',
#   'be',
#   'periodic',
#   'surveillance',
#   'pricing',
#   'practice',
#   'concessionaire',
#   'purpose',
#   'keep',
#   'price',
#   'reasonable'],
#  ['other', 'matter', 'jury', 'recommend'],
#  ['four',
#   'deputy',
#   'employ',
#   'group',
#   'doctor',
#   'medical_intern',
#   'extern',
#   'employ',
#   'night',
#   'weekend',
#   'duty',
#   'jail'],
#  ['location',
#   'legislator',
#   'city',
#   'official',
#   'pass',
#   'enabling_legislation',
#   'permit',
#   'establishment',
#   'equitable',
#   'pension',
#   'plan',
#   'city',
#   'employee'],
#  ['jury',
#   'praise',
#   'administration',
#   'operation',
#   'Atlanta',
#   'police_department',
#   'group',
#   'location',
#   'location',
#   'prison_farm',
#   'group',
#   'group'],
#  ['person', 'file', 'suit', 'divorce', 'wife', 'person', 'group', 'Friday'],
#  ['petition', 'charge', 'mental', 'cruelty'],
#  ['couple', 'marry', 'Aug'],
#  ['have', 'son', 'person', 'daughter', 'person', 'location'],
#  ['attorney',
#   'mayor',
#   'say',
#   'amicable',
#   'property_settlement',
#   'agreed_upon'],
#  ['petition', 'list', 'mayor', 'occupation', 'attorney', 'age'],
#  ['list', 'wife', 'age', 'place_of_birth', 'location'],
#  ['petition',
#   'say',
#   'couple',
#   'not',
#   'live',
#   'together',
#   'man_and_wife',
#   'more',
#   'year'],
#  ['person', 'home', 'be', 'location'],
#  ['person', 'list', 'petition', 'mayor', 'attorney'],
#  ['person',
#   'be',
#   'mayor',
#   'Atlanta',
#   'exception',
#   'one',
#   'brief',
#   'interlude'],
#  ['political', 'career', 'go_back', 'election', 'city_council'],
#  ['mayor', 'present', 'term_of_office', 'expire', 'Jan'],
#  ['succeed',
#   'person',
#   'become',
#   'candidate',
#   'Sept',
#   'primary',
#   'person',
#   'announce',
#   'not',
#   'run',
#   'reelection'],
#  ['Georgia',
#   'Republican',
#   'get',
#   'strong',
#   'encouragement',
#   'enter',
#   'candidate',
#   "governor's_race",
#   'official',
#   'say',
#   'Wednesday'],
#  ['person',
#   'state',
#   'GOP',
#   'chairman',
#   'say',
#   'meeting',
#   'hold',
#   'Tuesday',
#   'night',
#   'location',
#   'bring',
#   'enthusiastic',
#   'response',
#   'audience'],
#  ['person',
#   'add',
#   'enthusiasm',
#   'pick_up',
#   'state',
#   'rally',
#   'hold',
#   'Sept',
#   'Savannah',
#   'newly',
#   'elected',
#   'Texas',
#   'person',
#   'be',
#   'featured',
#   'speaker'],
#  ['location',
#   'meeting',
#   'audience',
#   'warn',
#   'enter',
#   'candidate',
#   'governor',
#   'force',
#   'take',
#   'petition',
#   'voting_precinct',
#   'obtain',
#   'signature',
#   'register',
#   'voter'],
#  ['warning',
#   'be',
#   'unanimous',
#   'vote',
#   'enter',
#   'candidate',
#   'Republican',
#   'attend'],
#  ['crowd',
#   'ask',
#   'want',
#   'wait',
#   'one',
#   'term',
#   'make',
#   'race',
#   'vote',
#   'no',
#   'be',
#   'dissent'],
#  ['hurdle',
#   'Republican',
#   'face',
#   'be',
#   'state',
#   'law',
#   'say',
#   'make',
#   'first',
#   'race',
#   'one',
#   'two',
#   'alternative',
#   'course',
#   'take'],
#  ['five',
#   'percent',
#   'voter',
#   'county',
#   'sign',
#   'petition',
#   'request',
#   'Republican',
#   'allow',
#   'place',
#   'name',
#   'candidate',
#   'general_election',
#   'ballot',
#   'Republican',
#   'hold',
#   'primary',
#   'county',
#   'unit',
#   'system',
#   'system',
#   'party',
#   'oppose',
#   'platform'],
#  ['person',
#   'group',
#   'public_relations',
#   'director',
#   'resign',
#   'Tuesday',
#   'work',
#   'person',
#   'campaign'],
#  ['person', 'resignation', 'expect', 'time'],
#  ['succeed', 'person', 'location', 'be', 'assistant', 'more', 'three', 'year'],
#  ['gubernatorial',
#   'campaign',
#   'start',
#   'person',
#   'expect',
#   'become',
#   'campaign',
#   'coordinator',
#   'person'],
#  ['group',
#   'session',
#   'Monday',
#   'head',
#   'home',
#   'highway',
#   'bond',
#   'money',
#   'approve',
#   'follow',
#   'shortly'],
#  ['adjournment',
#   'Monday',
#   'afternoon',
#   'senate',
#   'expect',
#   'approve',
#   'study',
#   'number',
#   'legislator',
#   'allot',
#   'rural_area',
#   'urban_area',
#   'determine',
#   'adjustment',
#   'make'],
#  ['person',
#   'expect',
#   'make',
#   'traditional',
#   'visit',
#   'chamber',
#   'work',
#   'adjournment'],
#  ['person',
#   'likely',
#   'mention',
#   '100',
#   'million',
#   'highway',
#   'bond',
#   'issue',
#   'approve',
#   'session',
#   'first',
#   'priority',
#   'item'],
#  ['meanwhile',
#   'learn',
#   'group',
#   'be',
#   'very',
#   'near',
#   'be',
#   'ready',
#   'issue',
#   'first',
#   '30',
#   'million',
#   'worth',
#   'highway',
#   'reconstruction',
#   'bond'],
#  ['bond',
#   'issue',
#   'go',
#   'state',
#   'court',
#   'friendly',
#   'test_suit',
#   'test',
#   'validity',
#   'act',
#   'and_then',
#   'sale',
#   'begin',
#   'contract',
#   'let',
#   'repair',
#   'work',
#   'Georgia',
#   'most',
#   'heavily',
#   'traveled',
#   'highway'],
#  ['group',
#   'source',
#   'say',
#   'also',
#   'be',
#   'plan',
#   'there',
#   'issue',
#   'some',
#   '3',
#   'million',
#   '4',
#   'million',
#   'worth',
#   'group',
#   'bond',
#   'rural',
#   'road',
#   'construction',
#   'work'],
#  ['department',
#   'apparently',
#   'intend',
#   'make',
#   'group',
#   'revolving_fund',
#   'new',
#   'bond',
#   'issue',
#   'time',
#   'portion',
#   'old',
#   'pay_off',
#   'tax',
#   'authorities'],
#  ['person',
#   'open',
#   'race',
#   'governor',
#   'battle',
#   'legislature',
#   'issuance',
#   '50',
#   'million',
#   'worth',
#   'rural',
#   'road',
#   'bond',
#   'propose',
#   'then',
#   'person'],
#  ['group',
#   'source',
#   'tell',
#   'however',
#   'person',
#   'not',
#   'consult',
#   'yet',
#   'plan',
#   'issue',
#   'new',
#   'rural',
#   'road',
#   'bond'],
#  ['person',
#   'offer',
#   'resolution',
#   'Monday',
#   'group',
#   'rescind',
#   'body',
#   'action',
#   'Friday',
#   'voting',
#   '10',
#   'day',
#   'increase',
#   'expense',
#   'allowance'],
#  ['person',
#   'say',
#   'Sunday',
#   'night',
#   'be',
#   'research',
#   'do',
#   'quickie',
#   'vote',
#   'increase',
#   'repeal',
#   'outright',
#   'notice',
#   'first',
#   'give',
#   'reconsideration',
#   'action',
#   'seek'],
#  ['emphasize',
#   'technical',
#   'detail',
#   'not',
#   'fully',
#   'work_out',
#   'person',
#   'say',
#   'resolution',
#   'seek',
#   'set_aside',
#   'privilege',
#   'resolution',
#   'group',
#   'vote'],
#  ['similar', 'resolution', 'pass', 'senate', 'vote', '29', '5'],
#  ['Sunday',
#   'night',
#   'be',
#   'word',
#   'resolution',
#   'offer',
#   'there',
#   'rescind',
#   'action'],
#  ['person',
#   'point_out',
#   'Georgia',
#   'voter',
#   'last',
#   'November',
#   'reject',
#   'amendment',
#   'allow',
#   'legislator',
#   'vote',
#   'pay',
#   'raise',
#   'future',
#   'legislature',
#   'session'],
#  ['veteran',
#   'location',
#   'legislator',
#   'ask',
#   'group',
#   'Monday',
#   'back',
#   'federal',
#   'aid',
#   'education',
#   'consistently',
#   'oppose',
#   'past'],
#  ['person',
#   'group',
#   'ask',
#   'group',
#   'privilege',
#   'resolution',
#   'endorse',
#   'increased',
#   'federal',
#   'support',
#   'public',
#   'education',
#   'fund',
#   'receive',
#   'expend',
#   'state',
#   'funds'],
#  ['person',
#   'be',
#   '13th',
#   'year',
#   'legislator',
#   'say',
#   'be',
#   'some',
#   'member',
#   'congressional',
#   'delegation',
#   'Washington',
#   'see',
#   'resolution',
#   'pass'],
#  ['add',
#   'Georgia',
#   'congressman',
#   'specifically',
#   'ask',
#   'offer',
#   'resolution'],
#  ['resolution',
#   'person',
#   'toss',
#   'group',
#   'hopper',
#   'Friday',
#   'formally',
#   'read',
#   'Monday'],
#  ['say',
#   'event',
#   'group',
#   'provide',
#   'increase',
#   'federal',
#   'fund',
#   'group',
#   'direct',
#   'give',
#   'priority',
#   'teacher',
#   'pay',
#   'raise'],
#  ['long',
#   'hot',
#   'controversy',
#   'location',
#   'have',
#   'new',
#   'school_superintendent',
#   'elect',
#   'policeman',
#   'put',
#   'election',
#   'ever',
#   'see',
#   'county'],
#  ['new',
#   'school_superintendent',
#   'be',
#   'person',
#   'veteran',
#   'agriculture',
#   'teacher',
#   'defeat',
#   'person',
#   'school_principal',
#   'chairman',
#   'group'],
#  ['person', 'receive', 'vote', 'Saturday', 'election', 'person', 'get'],
#  ['ordinary',
#   'person',
#   'arm',
#   'pistol',
#   'stand_by',
#   'polls',
#   'insure',
#   'order'],
#  ['be', 'election', 'ever', 'see', 'person', 'say'],
#  ['be', 'polls', 'be', 'just', 'be', 'church'],
#  ['smell', 'drop', 'liquor', 'have', 'trouble'],
#  ['campaign', 'lead_up', 'election', 'be', 'not', 'so', 'quiet', 'however'],
#  ['mark',
#   'controversy',
#   'anonymous',
#   'midnight',
#   'phone_call',
#   'veiled',
#   'threat',
#   'violence'],
#  ['former',
#   'county',
#   'school_superintendent',
#   'person',
#   'shoot',
#   'death',
#   'March',
#   'four',
#   'day',
#   'resign',
#   'post',
#   'dispute',
#   'county',
#   'school_board'],
#  ['election',
#   'campaign',
#   'candidate',
#   'person',
#   'person',
#   'reportedly',
#   'receive',
#   'anonymous',
#   'telephone_call'],
#  ['ordinary',
#   'person',
#   'say',
#   'too',
#   'subject',
#   'anonymous',
#   'call',
#   'soon',
#   'schedule',
#   'election'],
#  ['many',
#   'citizen',
#   'fear',
#   'be',
#   'irregularity',
#   'polls',
#   'person',
#   'get',
#   'permit',
#   'carry',
#   'gun',
#   'promise',
#   'orderly',
#   'election'],
#  ['person', 'say', 'ordinary', 'apparently', 'make_good', 'promise'],
#  ['go', 'real', 'smooth', 'sheriff', 'say'],
#  ['be', 'a_bit', 'trouble'],
#  ['committee',
#   'approval',
#   'person',
#   'abandoned',
#   'property',
#   'act',
#   'seem',
#   'certain',
#   'Thursday',
#   'adamant',
#   'protest',
#   'Texas',
#   'banker'],
#  ['person',
#   'personally',
#   'lead',
#   'fight',
#   'measure',
#   'water_down',
#   'considerably',
#   'rejection',
#   'two',
#   'previous',
#   'legislature',
#   'public',
#   'hearing',
#   'group'],
#  ['committee', 'rule', 'go', 'automatically', 'subcommittee', 'one', 'week'],
#  ['question',
#   'committee_member',
#   'taunt',
#   'banker',
#   'appear',
#   'witness',
#   'leave',
#   'little',
#   'doubt',
#   'recommend',
#   'passage'],
#  ['person',
#   'term',
#   'extremely',
#   'conservative',
#   'estimate',
#   'produce',
#   '17',
#   'million',
#   'dollar',
#   'help',
#   'erase',
#   'anticipated',
#   'deficit',
#   'million',
#   'dollar',
#   'end',
#   'current',
#   'fiscal_year',
#   'next',
#   'Aug'],
#  ['tell',
#   'committee',
#   'measure',
#   'merely',
#   'provide',
#   'means',
#   'enforce',
#   'escheat',
#   'law',
#   'be',
#   'Texas',
#   'be',
#   'republic'],
#  ['permit',
#   'state',
#   'take_over',
#   'bank_account',
#   'stock',
#   'other',
#   'personal_property',
#   'person',
#   'miss',
#   'seven',
#   'year',
#   'more'],
#  ['bill',
#   'person',
#   'say',
#   'draft',
#   'personally',
#   'force',
#   'bank',
#   'insurance_firm',
#   'pipeline_company',
#   'other',
#   'corporation',
#   'report',
#   'property',
#   'state_treasurer'],
#  ['escheat',
#   'law',
#   'enforce',
#   'now',
#   'be',
#   'almost',
#   'impossible',
#   'locate',
#   'property',
#   'person',
#   'declare'],
#  ['person',
#   'location',
#   'lawyer',
#   'represent',
#   'group',
#   'sound',
#   'opposition',
#   'keynote',
#   'say',
#   'force',
#   'bank',
#   'violate',
#   'contractual',
#   'obligation',
#   'depositor',
#   'undermine',
#   'confidence',
#   'bank',
#   'customer'],
#  ['destroy', 'confidence', 'bank', 'do', 'economy', 'say'],
#  ['take', 'circulation', 'many', 'million', 'dollar'],
#  ['person',
#   'location',
#   'sponsor',
#   'bill',
#   'say',
#   'failure',
#   'enact',
#   'amount',
#   'make',
#   'gift',
#   'taxpayer',
#   'pocket',
#   'bank',
#   'insurance_company',
#   'pipeline_company'],
#  ['contention',
#   'deny',
#   'banker',
#   'include',
#   'person',
#   'location',
#   'person',
#   'Houston',
#   'person',
#   'location',
#   'person',
#   'Austin'],
#  ['person',
#   'argue',
#   'bill',
#   'be',
#   'probably',
#   'unconstitutional',
#   'say',
#   'impair',
#   'contract'],
#  ['also',
#   'complain',
#   'not',
#   'enough',
#   'notice',
#   'give',
#   'hearing',
#   'bill',
#   'introduce',
#   'only',
#   'last',
#   'Monday'],
#  ['senator',
#   'unanimously',
#   'approve',
#   'Thursday',
#   'bill',
#   'person',
#   'Dallas',
#   'authorize',
#   'establishment',
#   'day_school',
#   'deaf',
#   'Dallas',
#   'four',
#   'other',
#   'county'],
#  ['bill',
#   'design',
#   'provide',
#   'special',
#   'schooling',
#   'more',
#   'deaf',
#   'student',
#   'scholastic',
#   'age',
#   'reduced',
#   'cost',
#   'state'],
#  ['be', 'no', 'debate', 'senate', 'pass_on', 'bill', 'group'],
#  ['authorize',
#   'group',
#   'establish',
#   'day_school',
#   'deaf',
#   'county',
#   'more',
#   'population',
#   'require',
#   'deaf',
#   'child',
#   '6',
#   '13',
#   'year',
#   'of_age',
#   'attend',
#   'day_school',
#   'permit',
#   'attend',
#   'residential',
#   'location',
#   'here'],
#  ['operating_budget',
#   'day_school',
#   'five',
#   'county',
#   'Dallas',
#   'location',
#   'location',
#   'location',
#   'location',
#   'be',
#   'be',
#   'saving',
#   'first',
#   'year',
#   'capital',
#   'outlay',
#   'absorb',
#   'person',
#   'tell',
#   'senate'],
#  ['group',
#   'estimate',
#   'be',
#   'scholastic',
#   'attend',
#   'day_school',
#   'location',
#   'saving',
#   'come',
#   'Austin',
#   'live',
#   'state',
#   'deaf',
#   'school'],
#  ['Dallas',
#   'hear',
#   'debate',
#   'horse_race',
#   'parimutuel',
#   'soon',
#   'person',
#   'person'],
#  ['details',
#   'still',
#   'work_out',
#   'person',
#   'say',
#   'expect',
#   'tell',
#   'Dallas',
#   'think',
#   'person',
#   'amendment',
#   'reject'],
#  ['get', 'more', 'pro', 'letter', 'con', 'horse_race', 'bet', 'say', 'person'],
#  ['believe', 'people', 'be', 'better', 'inform', 'question', 'oppose', 'also'],
#  ['willing', 'stake', 'political', 'career', 'on_it'],
#  ['person', 'ex-gambler', 'location', 'elect', 'advocacy', 'bet_on', 'pony'],
#  ['group',
#   'committee',
#   'hear',
#   'local_option',
#   'proposal',
#   'expect',
#   'give',
#   'favorable',
#   'report',
#   'resolution',
#   'face',
#   'later'],
#  ['group',
#   'pass',
#   'finally',
#   'send',
#   'senate',
#   'bill',
#   'extend',
#   'group',
#   'authority',
#   'give',
#   'planning',
#   'assistance',
#   'city'],
#  ['group',
#   'quickly',
#   'whip_through',
#   'meager',
#   'fare',
#   'group',
#   'bill',
#   'approve',
#   'committee',
#   'pass',
#   'three',
#   'calendar'],
#  ['one', 'validate', 'act', 'school', 'district'],
#  ['authority', 'group'],
#  ['third',
#   'amend',
#   'enabling_act',
#   'creation',
#   'location',
#   'location',
#   'special',
#   'amendment',
#   'previously',
#   'adopt'],
#  ['dissent',
#   'senator',
#   'pass',
#   'bill',
#   'person',
#   'location',
#   'authorize',
#   'establishment',
#   'future',
#   'school',
#   'mentally_retarded',
#   'location',
#   'district'],
#  ['money',
#   'construction',
#   'seek',
#   'later_on',
#   'in_the_meantime',
#   'location',
#   'board',
#   'accept',
#   'gift',
#   'donation',
#   'site'],
#  ['two', 'tax', 'revision', 'bill', 'pass'],
#  ['one',
#   'person',
#   'location',
#   'aid',
#   'retailer',
#   'pay',
#   'group',
#   'excise_tax',
#   'eliminate',
#   'requirement',
#   'return',
#   'notarize'],
#  ['instead',
#   'retailer',
#   'sign',
#   'certificate',
#   'correctness',
#   'violation',
#   'carry',
#   'penalty',
#   'one',
#   'five',
#   'year',
#   'prison',
#   '1000'],
#  ['be', 'series', 'recommendation', 'group'],
#  ['other',
#   'bill',
#   'person',
#   'location',
#   'relieve',
#   'real_estate_broker',
#   'pay',
#   'own',
#   'licensing_fee',
#   '12',
#   'occupation_license',
#   'broker',
#   'stock',
#   'bond'],
#  ['natural_gas',
#   'public_utility',
#   'company',
#   'give',
#   'right',
#   'eminent_domain',
#   'bill',
#   'person',
#   'location',
#   'acquire',
#   'site',
#   'underground',
#   'storage',
#   'reservoir',
#   'gas'],
#  ['person',
#   'location',
#   'former',
#   'chairman',
#   'group',
#   'suggest',
#   'plan',
#   'fill',
#   'appointment',
#   'future',
#   'vacancy',
#   'group',
#   'group',
#   'eliminate',
#   'need',
#   'costly',
#   'special',
#   'election'],
#  ['person',
#   'plan',
#   'appointee',
#   'select',
#   'board',
#   'compose',
#   'governor',
#   'lieutenant_governor',
#   'Speaker',
#   'house',
#   'attorney_general',
#   'chief_justice',
#   'group'],
#  ['state',
#   'representative',
#   'decide',
#   'Thursday',
#   'kind',
#   'tax',
#   'Texan',
#   'prefer',
#   'pay'],
#  ['adverse',
#   'vote',
#   'keep',
#   'group',
#   'bill',
#   'order',
#   'referendum',
#   'April',
#   '4',
#   'ballot',
#   'Texas',
#   'vote',
#   'U.S.',
#   'senator'],
#  ['person',
#   'location',
#   'sponsor',
#   'poll',
#   'idea',
#   'say',
#   'delay',
#   'committee',
#   'kill',
#   'bill'],
#  ['person',
#   'report',
#   'finally',
#   'person',
#   'committee',
#   'set',
#   'public',
#   'hearing',
#   'Feb',
#   '22'],
#  ['proposal',
#   'receive',
#   'final',
#   'legislative',
#   'approval',
#   'two-thirds',
#   'majority',
#   'March',
#   '1',
#   'print',
#   'April',
#   '4',
#   'ballot',
#   'person',
#   'say'],
#  ['opponent',
#   'generally',
#   'argue',
#   'ballot',
#   'give',
#   'enough',
#   'information',
#   'tax',
#   'proposal',
#   'voter',
#   'make',
#   'intelligent',
#   'choice'],
#  ['Dallas', 'member', 'vote', 'person', 'person', 'be', 'absent'],
#  ['location',
#   'lose',
#   'alleged',
#   'water',
#   'need',
#   'Texas',
#   'big',
#   'city',
#   'Thursday'],
#  ['person',
#   'location',
#   'insist',
#   'water_development',
#   'bill',
#   'pass',
#   'Texas',
#   'House_of_Representatives',
#   'be',
#   'effort',
#   'big',
#   'city',
#   'Dallas',
#   'Fort_Worth',
#   'place',
#   'location',
#   'location',
#   'hamlet',
#   'people'],
#  ['shouting',
#   'end',
#   'bill',
#   'pass',
#   '4',
#   'send',
#   'senate',
#   'similar',
#   'proposal',
#   'sponsor',
#   'person',
#   'Dallas'],
#  ['most', 'fire', 'direct', 'person', 'Dallas', 'person'],
#  ['bill', 'increase', 'maximum', 'loan', 'state', 'water_project'],
#  ['person',
#   'construe',
#   'veiled',
#   'effort',
#   'person',
#   'help',
#   'Dallas',
#   'other',
#   'large',
#   'city',
#   'get',
#   'money',
#   'person',
#   'feel',
#   'better',
#   'be',
#   'spend',
#   'provide',
#   'water',
#   'rural',
#   'Texas'],
#  ['statement',
#   'other',
#   'legislator',
#   'Dallas',
#   'pay',
#   'water_program',
#   'bond',
#   'less',
#   'populous',
#   'place',
#   'benefit',
#   'most',
#   'pending',
#   'bill',
#   'not',
#   'sway',
#   'person',
#   'attack'],
#  ['bill',
#   'defender',
#   'be',
#   'mostly',
#   'small_town',
#   'legislator',
#   'person',
#   'location',
#   'person',
#   'location',
#   'person',
#   'location',
#   'person',
#   'location'],
#  ['be', 'poor', 'boy', 'bill', 'say', 'person'],
#  ['Dallas', 'Fort_Worth', 'vote', 'bond'],
#  ['help', 'little', 'district'],
#  ['Houston',
#   'teacher',
#   'now',
#   'serve',
#   'legislature',
#   'propose',
#   'Thursday',
#   'law',
#   'reduce',
#   'time',
#   'spend',
#   'learn',
#   'educational',
#   'method'],
#  ['person',
#   'teach',
#   'history',
#   'Houston',
#   'public_school',
#   'reduce',
#   '24',
#   '12',
#   'semester_hour',
#   'so-called',
#   'teaching_method',
#   'course',
#   'require',
#   'obtain',
#   'junior_high_school',
#   'senior_high_school',
#   'teaching_certificate'],
#  ['normal', 'work', 'college', 'be', '30', 'semester_hour'],
#  ['person',
#   'also',
#   'require',
#   'junior_high',
#   'senior_high',
#   'teacher',
#   'have',
#   'at_least',
#   '24',
#   'semester_hour',
#   'credit',
#   'subject',
#   'teach'],
#  ['remainder', '4', 'college', 'requirement', 'be', 'subject'],
#  ['person',
#   "master's_degree",
#   'physics',
#   'chemistry',
#   'math',
#   'English',
#   'not',
#   'take',
#   'education',
#   'course',
#   'not',
#   'permit',
#   'teach',
#   'public_school',
#   'say',
#   'person'],
#  ['college',
#   'teacher',
#   'Texas',
#   'not',
#   'require',
#   'have',
#   'education',
#   'course'],
#  ['representative', 'immediately', 'join', 'person', 'cosigner', 'proposal'],
#  ['board_of_regents',
#   'group',
#   'name',
#   'person',
#   'location',
#   'location',
#   'school',
#   'new',
#   'president'],
#  ['person', 'succeed', 'person', 'retire', 'present', 'school_term'],
#  ['person', 'hold', 'earned', 'Doctor_of_Education', 'degree', 'group'],
#  ['also',
#   'receive',
#   'Master_of_Science',
#   'degree',
#   'group',
#   'Bachelor_of_Science',
#   'degree',
#   'group',
#   'location',
#   'location'],
#  ['person', 'study', 'group', 'group'],
#  ['college',
#   'career',
#   'person',
#   'be',
#   'captain',
#   'basketball_team',
#   'be',
#   'football',
#   'letterman'],
#  ['person',
#   'serve',
#   'teacher',
#   'principal',
#   'Oklahoma',
#   'high_school',
#   'teacher',
#   'athletic',
#   'director',
#   'group',
#   'instructor',
#   'group',
#   'associate_professor',
#   'education',
#   'group'],
#  ['serve', 'border_patrolman', 'be', 'group', 'group'],
#  ['principal',
#   '13',
#   'school',
#   'group',
#   'reelect',
#   'session',
#   'recommendation',
#   'person'],
#  ['state',
#   'federal',
#   'legislation',
#   'racial',
#   'discrimination',
#   'employment',
#   'call_for',
#   'yesterday',
#   'report',
#   'blue-ribbon',
#   'citizens_committee',
#   'aid',
#   'dependent',
#   'child',
#   'program'],
#  ['report',
#   'culminate',
#   'year',
#   'long',
#   'study',
#   'group',
#   'program',
#   'location',
#   'county',
#   'New_York_City',
#   'welfare',
#   'consulting_firm',
#   'list',
#   '10',
#   'long-range',
#   'recommendation',
#   'design',
#   'reduce',
#   'soaring',
#   'group',
#   'case_load'],
#  ['report',
#   'call',
#   'racial',
#   'discrimination',
#   'employment',
#   'most',
#   'serious',
#   'cause',
#   'family',
#   'breakdown',
#   'desertion',
#   'group',
#   'dependency'],
#  ['cost',
#   'group',
#   'more',
#   'recipient',
#   'county',
#   'be',
#   'million',
#   'dollar',
#   'say',
#   'person',
#   'president',
#   'group',
#   'committee',
#   'chairman'],
#  ['solve',
#   'problem',
#   'force',
#   'people',
#   'depend_upon',
#   'group',
#   'subsistence',
#   'person',
#   'say'],
#  ['volume',
#   'group',
#   'case',
#   'decrease',
#   'person',
#   'report',
#   'community',
#   'be',
#   'able',
#   'deal',
#   'effectively',
#   'two',
#   'problem',
#   'relatively',
#   'limited',
#   'skill',
#   'discrimination',
#   'employment',
#   'color'],
#  ['say',
#   'be',
#   'two',
#   'principal',
#   'underlying',
#   'cause',
#   'family',
#   'breakup',
#   'lead',
#   'group'],
#  ['other', 'recommendation', 'make', 'committee', 'be'],
#  ['extension',
#   'group',
#   'program',
#   'child',
#   'need',
#   'live',
#   'relative',
#   'include',
#   'parent',
#   'means',
#   'preserve',
#   'family',
#   'unity'],
#  ['research',
#   'project',
#   'soon',
#   'possible',
#   'cause',
#   'dependency',
#   'illegitimacy'],
#  ['group',
#   'tonight',
#   'distinction',
#   'be',
#   'winless',
#   'team',
#   'eighteen',
#   'major-league_club',
#   'drop',
#   'sixth',
#   'straight',
#   'spring',
#   'exhibition',
#   'decision',
#   'Kansas_City',
#   'group',
#   'score'],
#  ['indication',
#   'top',
#   'sixth',
#   'be',
#   'group',
#   'end',
#   'victory',
#   'drought',
#   'coast',
#   'advantage'],
#  ['first',
#   'five',
#   'frame',
#   'person',
#   'big',
#   'right-hander',
#   'figure',
#   'be',
#   'group',
#   'plan',
#   'drive',
#   'group',
#   'pennant',
#   'hold',
#   'scoreless',
#   'yield',
#   'three',
#   'hit'],
#  ['then',
#   'person',
#   'submarine_ball',
#   'hurler',
#   'enter',
#   'contest',
#   'only',
#   'five',
#   'batter',
#   'face',
#   'exist',
#   'deadlock'],
#  ['two',
#   'run',
#   'homer',
#   'person',
#   'solo_blast',
#   'person',
#   'tie',
#   'game',
#   'single',
#   'run',
#   'eighth',
#   'ninth',
#   'give',
#   'group',
#   'fifth',
#   'victory',
#   'eight',
#   'start'],
#  ['one',
#   'eighth',
#   'person',
#   'draw',
#   'walk',
#   'steal',
#   'second_base',
#   'person',
#   'fan',
#   'person'],
#  ['catcher',
#   'person',
#   'throw',
#   'effort',
#   'nab',
#   'person',
#   'be',
#   'wide',
#   'dirt'],
#  ['then',
#   'person',
#   'Kansas_City',
#   'catcher',
#   'single',
#   'up',
#   'middle',
#   'person',
#   'be',
#   'prove',
#   'be',
#   'run'],
#  ['rookie',
#   'southpaw',
#   'person',
#   'relieve',
#   'person',
#   'ninth',
#   'give_up',
#   'fifth',
#   'tally',
#   'walk',
#   'second_baseman',
#   'person',
#   'wild_pitch',
#   'person',
#   'single',
#   'shortstop',
#   'person',
#   'glove',
#   'center'],
#  ['group',
#   'once_again',
#   'perform',
#   'plate',
#   'powder-puff',
#   'fashion',
#   'gather',
#   'only',
#   'seven',
#   'blow',
#   'offering',
#   'three',
#   'Kansas_City',
#   'pitcher'],
#  ['three', 'be', 'double', 'person', 'get', 'pair', 'person'],
#  ['person',
#   'person',
#   'person',
#   'do',
#   'mound',
#   'chore',
#   'club',
#   'down',
#   'location',
#   'play',
#   'game',
#   'pay',
#   'customer',
#   'location'],
#  ['group',
#   'get',
#   'five',
#   'hit',
#   'three',
#   'run',
#   'person',
#   'person',
#   'take_over',
#   'top',
#   'fourth'],
#  ['person',
#   'purchase',
#   'group',
#   'last',
#   'fall',
#   'allow',
#   'hit',
#   'scoreless',
#   'three',
#   'inning',
#   'appearance',
#   'merit',
#   'triumph'],
#  ['person',
#   '6',
#   'foot',
#   '3',
#   'inch',
#   'give_up',
#   'group',
#   'last',
#   'two',
#   'safety',
#   'final',
#   'three',
#   'frame',
#   'escape',
#   'load',
#   'ninth',
#   'group',
#   'threaten',
#   'fail',
#   'tally'],
#  ['ninth',
#   'person',
#   'lead',
#   'second',
#   'double',
#   'night',
#   'blast',
#   'fence',
#   'foot',
#   'deep',
#   'left'],
#  ['person',
#   'perform',
#   'right',
#   'group',
#   'field',
#   'possibly',
#   'strong',
#   'team',
#   'spring',
#   'work',
#   'person',
#   'base_on_balls'],
#  ['then', 'three', 'pinch_hitter', 'fail', 'produce'],
#  ['person',
#   'send',
#   'person',
#   'fail',
#   'bunt',
#   'attempt',
#   'pop',
#   'person',
#   'grass',
#   'back',
#   'short'],
#  ['person',
#   'bat',
#   'person',
#   'fan',
#   'foul',
#   'two',
#   'pitch',
#   'person',
#   'person',
#   'bounce_out',
#   'sharply',
#   'person',
#   'second',
#   'end',
#   '2',
#   'hour',
#   '27',
#   'minute',
#   'contest'],
#  ['group',
#   'get',
#   'run',
#   'first',
#   'inning',
#   'person',
#   'person',
#   'two',
#   'group',
#   'get',
#   'pair',
#   'hit',
#   'double',
#   'right',
#   'center',
#   'move',
#   'third',
#   'person',
#   'single',
#   'right',
#   'cross',
#   'person',
#   'wild_pitch',
#   'dirt',
#   'in_front',
#   'plate'],
#  ['group',
#   'add',
#   'pair',
#   'tally',
#   'third',
#   'three',
#   'straight',
#   'hit',
#   'be',
#   'out'],
#  ['person', 'single', 'deep', 'hole', 'short', 'start', 'rally'],
#  ['person',
#   'bounce',
#   'hard',
#   'shot',
#   'person',
#   'glove',
#   'beat',
#   'single',
#   'person',
#   'grab',
#   'ball',
#   'throw',
#   'first_baseman',
#   'person',
#   'head',
#   'person',
#   'third',
#   'person',
#   'second',
#   'error'],
#  ['then',
#   'person',
#   'slam',
#   'long',
#   'double',
#   'left',
#   'center',
#   'score',
#   'runner'],
#  ['person',
#   'try',
#   'stretch',
#   'blow',
#   'triple',
#   'cut_down',
#   'close',
#   'play',
#   'third',
#   'person',
#   'person'],
#  ['detailed', 'rundown', 'Kansas_City', 'score', 'sixth', 'go'],
#  ['person',
#   'work',
#   'walk',
#   'first',
#   'batter',
#   'face',
#   'person',
#   'romp',
#   'around',
#   'person',
#   'blast',
#   'person',
#   'toss',
#   'foot',
#   'scoreboard',
#   'right',
#   'center'],
#  ['person',
#   'single',
#   'slow',
#   'bounce',
#   'ball',
#   'short',
#   'person',
#   'cut_across',
#   'field',
#   'throw',
#   'wide',
#   'first'],
#  ['rule', 'difficult', 'chance', 'hit'],
#  ['then', 'person', 'rap', 'fast', 'double_play'],
#  ['person',
#   'person',
#   'person',
#   'set_up',
#   'person',
#   'foot',
#   'homer',
#   'wall',
#   'left',
#   'center'],
#  ['group',
#   'break',
#   'losing_streak',
#   'two',
#   'day',
#   'be',
#   'group',
#   'champion',
#   'New_York',
#   'group',
#   'come',
#   'here',
#   'tomorrow',
#   'night_game',
#   'single',
#   'test',
#   'Sunday',
#   'afternoon'],
#  ['flavor',
#   'Baltimore',
#   'group',
#   'news',
#   'ripen',
#   'considerably',
#   'late',
#   'today',
#   'group',
#   'advise',
#   'person',
#   'fulfill',
#   'obligation',
#   'group',
#   'military',
#   'training_program',
#   'be',
#   'ready',
#   'belated',
#   'spring_training'],
#  ['person',
#   'slug',
#   'group',
#   'high',
#   '22',
#   'homer',
#   'drive_in',
#   'run',
#   'freshman',
#   'average',
#   'complete',
#   'group',
#   'spring',
#   'squad',
#   'player'],
#  ['big',
#   '22',
#   'year',
#   'old',
#   'shortstop',
#   'group',
#   'rookie',
#   'year',
#   'fly',
#   'here',
#   'late',
#   'afternoon',
#   'Baltimore',
#   'sign',
#   'contract',
#   'be',
#   'spectator',
#   'tonight',
#   'loss',
#   'Kansas_City',
#   'winless',
#   'group',
#   'sixth',
#   'setback'],
#  ['6',
#   'foot',
#   '3',
#   'inch',
#   'person',
#   'check_in',
#   'close_to',
#   'pound',
#   '15',
#   'pound',
#   'light',
#   'reporting_weight',
#   'last',
#   'spring'],
#  ['hope',
#   'melt_off',
#   'eight',
#   'pound',
#   'group',
#   'break_camp',
#   'three',
#   'week',
#   'hence'],
#  ['induct',
#   'group',
#   'location',
#   'location',
#   'person',
#   'weight',
#   'drop',
#   'too',
#   'light',
#   'be',
#   'best',
#   'say'],
#  ['feel',
#   'good',
#   'physically',
#   'person',
#   'add',
#   'think',
#   'move',
#   'better',
#   'carry',
#   'a_little',
#   'less',
#   'weight',
#   'carry',
#   'now'],
#  ['rangy',
#   'location',
#   'location',
#   'native',
#   'surprise',
#   'slug',
#   'sensation',
#   'group',
#   'last',
#   'year',
#   'as_well',
#   'defensive',
#   'whiz',
#   'set',
#   'improved',
#   'fielding',
#   'goal'],
#  ['think',
#   'do',
#   'better',
#   'job',
#   'glove',
#   'now',
#   'know',
#   'hitter',
#   'league',
#   'a_little',
#   'better',
#   'say'],
#  ['person',
#   'engage',
#   'first',
#   'workout',
#   'location',
#   'prior',
#   'opening',
#   'tomorrow',
#   'night',
#   'two',
#   'game',
#   'weekend',
#   'series',
#   'New_York',
#   'group'],
#  ['person',
#   'person',
#   'group',
#   'veteran',
#   'knuckleball',
#   'specialist',
#   'slate',
#   'oppose',
#   'group',
#   'champion',
#   'tomorrow',
#   '8',
#   'contest'],
#  ['person',
#   'person',
#   'rookie',
#   'right-hander',
#   'post',
#   'record',
#   'last',
#   'year',
#   'location',
#   'location',
#   'farm_club',
#   'class',
#   'group',
#   'be',
#   'probable',
#   'pitcher'],
#  ['twenty-one',
#   'year',
#   'old',
#   'person',
#   'person',
#   'schedule',
#   'share',
#   'group',
#   'mound',
#   'chore',
#   'person',
#   'Sunday',
#   '2',
#   'encounter'],
#  ['person',
#   'successor',
#   'person',
#   'group',
#   'helm',
#   'plan',
#   'bring',
#   'entire',
#   'New_York',
#   'squad',
#   'here',
#   'St._Petersburg',
#   'include',
#   'person',
#   'large',
#   'crowd',
#   'anticipate',
#   'weekend',
#   'game'],
#  ['famed', 'now', 'retired', 'assist', 'batting_coach'],
#  ['pitcher',
#   'person',
#   'join',
#   'club',
#   'one',
#   'week',
#   'ago',
#   'complete',
#   'hitch',
#   'group',
#   'accelerated',
#   'wintertime',
#   'military',
#   'course',
#   'also',
#   'location',
#   'location'],
#  ['22',
#   'year',
#   'old',
#   'southpaw',
#   'enlist',
#   'earlier',
#   'last',
#   'fall',
#   'person'],
#  ['Baltimore',
#   'bulky',
#   'spring_training',
#   'contingent',
#   'now',
#   'gradually',
#   'reduce',
#   'manager',
#   'person',
#   'coach',
#   'seek',
#   'trim_down',
#   'more',
#   'streamlined',
#   'workable',
#   'unit'],
#  ['take',
#   'ride',
#   'person',
#   'greet',
#   'person',
#   'group',
#   'third_sacker',
#   'grab',
#   'head',
#   'plate',
#   'bounce',
#   'third',
#   'inning',
#   'two',
#   'run',
#   'double',
#   'left',
#   'centerfield',
#   'wall',
#   'tonight'],
#  ['be', 'first', 'two', 'double', 'person', 'be', 'mood', 'celebrate'],
#  ['just',
#   'game',
#   'time',
#   'person',
#   'pretty',
#   'wife',
#   'person',
#   'inform',
#   'addition',
#   'family',
#   'expect',
#   'late',
#   'summer'],
#  ['unfortunately',
#   'person',
#   'teammate',
#   'be',
#   'not',
#   'festive',
#   'mood',
#   'group',
#   'expire',
#   'seven',
#   'hit',
#   'pitching',
#   'three',
#   'Kansas_City',
#   'rookie',
#   'hurler'],
#  ['person',
#   'arrive',
#   'just',
#   'nightfall',
#   'two',
#   'hour',
#   'late',
#   'company',
#   'person',
#   'person',
#   'chairman',
#   'group',
#   'board_of_directors',
#   'person',
#   'person'],
#  ['flight',
#   'delay',
#   'person',
#   'say',
#   'boarding',
#   'ramp',
#   'inflict',
#   'minor',
#   'damage',
#   'wing',
#   'plane'],
#  ['group',
#   'person',
#   'now',
#   'catching',
#   'be',
#   'group',
#   'expansion',
#   'location'],
#  ['Tokyo', 'too', 'add', 'person'],
#  ['then', 'really', 'have', 'go'],
#  ['gain',
#   'second',
#   'straight',
#   'victory',
#   'person',
#   '3',
#   'year',
#   'old',
#   'filly',
#   'down',
#   'promising',
#   'colt',
#   'feature',
#   'seventh',
#   'race',
#   'here',
#   'today',
#   'pay'],
#  ['toy_with',
#   'field',
#   'early',
#   'stage',
#   'ask',
#   'speed',
#   'only',
#   'stretch',
#   'jockey',
#   'person',
#   'win',
#   'length',
#   'half',
#   '7',
#   'furlong'],
#  ['person',
#   'have',
#   'seem',
#   'be',
#   'substantial',
#   'lead',
#   'early',
#   'stage',
#   'tire',
#   'rapidly',
#   'near',
#   'wire',
#   'be',
#   'able',
#   'money',
#   'only',
#   'head',
#   'in_front',
#   'person'],
#  ['bright',
#   'sun',
#   'brisk',
#   'wind',
#   'have',
#   'track',
#   'fast',
#   'condition',
#   'for_the_first_time',
#   'week',
#   'celebrant',
#   'bet_on',
#   'well',
#   'prepared',
#   'program'],
#  ['prior',
#   'featured',
#   'race',
#   'steward',
#   'announce',
#   'apprentice',
#   'person',
#   'suspend',
#   'ten',
#   'day',
#   'crowd',
#   'horse',
#   'cross',
#   'field',
#   'sharply',
#   'two',
#   'race',
#   'Wednesday'],
#  ['result',
#   'mating',
#   'seem',
#   'improve',
#   'start',
#   'appear',
#   'win',
#   'speed',
#   'reserve'],
#  ['move_up', 'allowance', 'department', 'win', 'claim', 'event'],
#  ['person',
#   'swift',
#   'Jamaican',
#   'set',
#   'meet',
#   'record',
#   'yard',
#   'run',
#   'group',
#   'track_meet',
#   'tonight',
#   'beat',
#   'group',
#   'person',
#   'hot',
#   'duel'],
#  ['person',
#   'set',
#   'world_record',
#   'earlier',
#   'month',
#   'New_York',
#   'clocking',
#   'wiped_out',
#   'person',
#   'early',
#   'pace',
#   'beat',
#   'young',
#   'quarter_mile',
#   'king',
#   '5',
#   'yard'],
#  ['be', 'meet', 'mark', 'set', 'person'],
#  ['person', 'shoot', 'in_front', 'keep', 'lead', 'two', 'third', 'race'],
#  ['then',
#   'person',
#   'graduate_student',
#   'Illinois',
#   'move',
#   'past',
#   'straightaway',
#   'hold_off',
#   'person',
#   'challenge',
#   'final',
#   'turn'],
#  ['person', 'time'],
#  ['crowd',
#   'twenty-first',
#   'annual',
#   'final',
#   'indoor',
#   'meet',
#   'season',
#   'get',
#   'thrill',
#   'a_few',
#   'minute',
#   'earlier',
#   'slender',
#   'bespectacled',
#   'woman',
#   'break',
#   'one',
#   'week',
#   'old',
#   'world_record',
#   'half_mile',
#   'run'],
#  ['person',
#   'nearby',
#   'location',
#   '27',
#   'year',
#   'old',
#   'housewife',
#   'have',
#   'two',
#   'child',
#   'finish'],
#  ['snap',
#   'five',
#   'tenth',
#   'second',
#   'mark',
#   'set',
#   'person',
#   'group',
#   'meet',
#   'Columbus',
#   'Ohio'],
#  ['person',
#   'location',
#   'location',
#   'relief',
#   'quarterback',
#   'San_Francisco',
#   'group',
#   'group',
#   'knee',
#   'operation',
#   'tomorrow',
#   'group',
#   'here'],
#  ['person', 'injure', 'left', 'knee', 'last', 'game', 'season'],
#  ['work_out',
#   'location',
#   'swelling',
#   'develop',
#   'knee',
#   'come',
#   'here',
#   'consult',
#   'team',
#   'physician'],
#  ['two',
#   'error',
#   'New_York',
#   'group',
#   'shortstop',
#   'person',
#   'eleventh',
#   'inning',
#   'donate',
#   'four',
#   'unearned_run',
#   'victory',
#   'today'],
#  ['Texas',
#   'halfback',
#   'even',
#   'know',
#   'team',
#   'play',
#   'person',
#   'rank',
#   'fourth',
#   'group',
#   'score',
#   'three',
#   'game'],
#  ['time',
#   'stand_still',
#   'time',
#   'person',
#   '26',
#   'year',
#   'old',
#   'group',
#   'veteran',
#   'go_into',
#   'field'],
#  ['never',
#   'play',
#   'clock',
#   'run',
#   'get',
#   'big',
#   'kick',
#   'Saturday',
#   'in_fact',
#   'football'],
#  ['person',
#   'even',
#   'have',
#   'nose',
#   'guard',
#   'hip_pad',
#   'one',
#   'most',
#   'valuable',
#   'member',
#   'group',
#   'team',
#   'heavily',
#   'favor',
#   'Saturday',
#   'Oklahoma'],
#  ['already', 'kick', '14', '15', 'try'],
#  ['run',
#   'string',
#   'successful',
#   'conversion',
#   'season',
#   '13',
#   'straight',
#   'go',
#   'astray',
#   'last',
#   'Saturday',
#   'night',
#   '8',
#   'slaughter',
#   'group'],
#  ['person',
#   'list',
#   'group',
#   'roster',
#   'right',
#   'halfback',
#   'position',
#   'letter',
#   'team'],
#  ['ask',
#   'coach',
#   'person',
#   'position',
#   'play',
#   'get',
#   'quick',
#   'response',
#   'place-kicker'],
#  ['pound',
#   '6',
#   'foot',
#   '1',
#   'inch',
#   'senior',
#   'location',
#   'person',
#   'practice',
#   'nothing',
#   'place-kicking'],
#  ['last',
#   'year',
#   'work_out',
#   'halfback',
#   'season',
#   'get_into',
#   'single',
#   'game'],
#  ['year',
#   'coach',
#   'person',
#   'tell',
#   'work_on',
#   'place-kicking',
#   'think',
#   'use',
#   'say',
#   'person'],
#  ['start', 'practice', 'spring_training'],
#  ['person',
#   'bother',
#   'first',
#   'two',
#   'game',
#   'year',
#   'pull',
#   'muscle',
#   'thigh',
#   'right',
#   'kick',
#   'leg',
#   'result',
#   'successful',
#   'conversion',
#   'go',
#   'barely',
#   'far',
#   'enough'],
#  ['person',
#   'say',
#   'Monday',
#   'leg',
#   'feel',
#   'fine',
#   'result',
#   'hope',
#   'start',
#   'practice',
#   'field_goal',
#   'week'],
#  ['kick', 'play', 'group', 'include', 'beat', 'group', 'district', 'game'],
#  ['kick',
#   'about',
#   'try',
#   'three',
#   'year',
#   'high_school',
#   'say',
#   'make',
#   '26',
#   'one',
#   'time'],
#  ['never',
#   'miss',
#   'playoff_game',
#   'kick',
#   'about',
#   '20',
#   'five',
#   'playoff_game',
#   'last',
#   'two',
#   'year'],
#  ['person',
#   'come',
#   'Texas',
#   'freshman',
#   'football',
#   'effort',
#   'hamper',
#   'knee',
#   'injury'],
#  ['miss', 'season', 'operation', 'ailing', 'knee', 'then', 'play', 'minute'],
#  ['statistical',
#   'record',
#   'year',
#   'group',
#   'win',
#   'only',
#   'one',
#   'game',
#   'lose',
#   'nine',
#   'be',
#   'far',
#   'impressive',
#   'carry',
#   'ball',
#   'three',
#   'time',
#   'net',
#   'gain',
#   '10',
#   'yard',
#   'punt',
#   'once',
#   'yard',
#   'catch',
#   'one',
#   'pass',
#   '13',
#   'yard'],
#  ['go_into', 'group', 'March', 'return', 'two', 'year', 'later'],
#  ['be', 'scholastically', 'ineligible', 'merely', 'present', 'last', 'season'],
#  ['place', 'be', 'largely', 'matter', 'timing', 'person', 'declare'],
#  ['once', 'get', 'feel', 'not', 'much'],
#  ['try', 'teach', 'other', 'boy', 'kick', 'get', 'feel'],
#  ['practice', 'help', 'get', 'timing', 'down'],
#  ['kind_of', 'golf', 'swing', 'club', 'very', 'often', 'timing', 'get', 'off'],
#  ['person', 'however', 'kick', 'only', '10', '12', 'practice_session'],
#  ['kick', 'too_much', 'leg', 'get', 'kinda', 'dead', 'explain'],
#  ['first',
#   'three',
#   'game',
#   'group',
#   'have',
#   'ball',
#   'time',
#   'score',
#   '16',
#   'time',
#   '40',
#   'percent',
#   'total',
#   'passing',
#   'yardage',
#   'three',
#   'game',
#   '30',
#   'completion',
#   'attempt',
#   'be',
#   'only',
#   '22',
#   'yard',
#   'short',
#   'total',
#   'passing',
#   'yardage',
#   'make',
#   'completion',
#   'try'],
#  ['tailback',
#   'person',
#   'already',
#   'surpass',
#   'rushing',
#   'total',
#   'brilliant',
#   'sophomore',
#   'season',
#   'net',
#   'yard',
#   'carry',
#   'now',
#   'have',
#   'yard',
#   '22',
#   'try',
#   'three',
#   'game'],
#  ['person',
#   'make',
#   'only',
#   'one',
#   'second_half',
#   'appearance',
#   'season',
#   'be',
#   'group',
#   'game',
#   'four',
#   'play',
#   'return',
#   'kickoff',
#   '30',
#   'yard',
#   'gain',
#   'five',
#   'yard',
#   'line',
#   'and_then',
#   'uncork',
#   'yard',
#   'touchdown',
#   'run',
#   'retire'],
#  ['wingback',
#   'person',
#   'injure',
#   'knee',
#   'group',
#   'game',
#   'insist',
#   'be',
#   'ready',
#   'group'],
#  ['last',
#   'week',
#   'person',
#   'inform',
#   'three',
#   'group',
#   'be',
#   'conference',
#   'top',
#   'four',
#   'rushing',
#   'say',
#   'last',
#   'long'],
#  ['Monday', 'have', 'four', 'group', 'top', 'four'],
#  ['good',
#   'feeling',
#   'prevail',
#   'group',
#   'coach',
#   'staff',
#   'Monday',
#   'attention',
#   'quickly',
#   'turn',
#   'Saturday',
#   'victory',
#   'week',
#   'problem',
#   'group'],
#  ['group', 'play', 'week'],
#  ['just',
#   'real',
#   'happy',
#   'player',
#   'coach',
#   'person',
#   'say',
#   'victory',
#   'group'],
#  ['think',
#   'big',
#   'thing',
#   'game',
#   'be',
#   'kid',
#   'third',
#   'straight',
#   'week',
#   'stay',
#   'there',
#   'pitch',
#   'keep',
#   'pressure',
#   'on'],
#  ['be',
#   'first',
#   'time',
#   'be',
#   'ahead',
#   'season',
#   'person',
#   'kick',
#   'prove',
#   'be',
#   'field_goal'],
#  ['assistant',
#   'coach',
#   'person',
#   'describe',
#   'victory',
#   'good',
#   'feeling',
#   'think',
#   'part',
#   'coach',
#   'player'],
#  ['get'],
#  ['person',
#   'express',
#   'particular',
#   'gratification',
#   'defensive',
#   'performance',
#   'end',
#   'person',
#   'halfback',
#   'person'],
#  ['job', 'second', 'straight', 'game'],
#  ['person', 'play', 'magnificent', 'football', 'person', 'praise'],
#  ['knock_down', 'interference', 'make', 'key', 'stop', 'time'],
#  ['cause', 'fumble', 'set_up', 'touchdown'],
#  ['break',
#   'boy',
#   'group',
#   'fullback',
#   'person',
#   'two',
#   'knock',
#   'loose',
#   'football'],
#  ['person', 'contribute', 'saving', 'group', 'thrust', 'late', 'stage'],
#  ['be',
#   'fourth',
#   'down',
#   'screen_pass',
#   'group',
#   'incomplete',
#   'pass',
#   'person',
#   'territory'],
#  ['start', 'form', 'person', 'spot', 'person', 'say'],
#  ['time',
#   'just_right',
#   'break_through',
#   'there',
#   'boy',
#   'halfback',
#   'person',
#   'have',
#   'time',
#   'turn_around'],
#  ['really', 'crucify'],
#  ['nail', 'yard', 'loss'],
#  ['group',
#   'game',
#   'final',
#   'play',
#   'be',
#   'long',
#   'pass',
#   'quarterback',
#   'person',
#   'person',
#   'intercept',
#   'own',
#   'return',
#   '22',
#   'yard'],
#  ['just', 'lie', 'there', 'wait', 'person', 'say'],
#  ['almost', 'bring', 'back', 'all_the_way'],
#  ['sophomore',
#   'center',
#   'person',
#   'fullback',
#   'person',
#   'person',
#   'expect',
#   'squad',
#   'be',
#   'physically',
#   'sound',
#   'group'],
#  ['person', 'be', 'very', 'doubtful', 'group', 'game', 'person', 'say'],
#  ['be', 'week'],
#  ['hit', 'blind', 'side', 'split_end', 'second', 'play', 'game'],
#  ['be', 'definitely', 'ligament', 'damage', 'knee'],
#  ['person', 'not', 'play', 'injure', 'knee', 'opener', 'group'],
#  ['look', 'a_lot', 'better', 'able', 'run', 'person', 'explain'],
#  ['let', 'running', 'week', 'know', 'be', 'able', 'play'],
#  ['game',
#   'player',
#   'see',
#   'group',
#   'film',
#   'Monday',
#   'run',
#   '30_minutes',
#   'then',
#   'go',
#   'reserve',
#   'scrimmage',
#   'minute'],
#  ['work',
#   'hard',
#   'Tuesday',
#   'Wednesday',
#   'Thursday',
#   'person',
#   'say',
#   'probably',
#   'have',
#   'good',
#   'scrimmage',
#   'Friday'],
#  ['work_out',
#   'hour',
#   'Saturday',
#   'then',
#   'work',
#   'Monday',
#   'Tuesday',
#   'week',
#   'then',
#   'taper_off'],
#  ['group',
#   'play',
#   'group',
#   'location',
#   'Houston',
#   'night_game',
#   'Saturday',
#   'Oct'],
#  ['hold',
#   'group',
#   'sweat_suit',
#   'drill',
#   'Monday',
#   'group',
#   'tackle',
#   'person',
#   'treatment',
#   'leg',
#   'injury',
#   'suffer',
#   'group',
#   'loss',
#   'group'],
#  ['important',
#   'game',
#   'Arkansas',
#   'come_up',
#   'Saturday',
#   'group',
#   'work_out',
#   'rain',
#   'Monday',
#   'mud',
#   'mud'],
#  ['end',
#   'person',
#   'break',
#   'hand',
#   'group',
#   'game',
#   'group',
#   'be',
#   'back',
#   'work_out',
#   'group',
#   'person',
#   'sophomore',
#   'guard',
#   'move_back',
#   'action',
#   'week',
#   'idleness',
#   'ankle',
#   'injury'],
#  ['group',
#   'get',
#   'day_off',
#   'Monday',
#   'special',
#   'gift',
#   'coach',
#   'person',
#   'conference',
#   'victory',
#   'last',
#   'Saturday',
#   'night',
#   'person',
#   'announce',
#   'halfback',
#   'person',
#   'shake_up',
#   'group',
#   'game',
#   'not',
#   'play',
#   'group',
#   'Saturday'],
#  ['halfback',
#   'person',
#   'slow',
#   'almost',
#   'month',
#   'slowly',
#   'mend',
#   'sprain',
#   'ankle',
#   'join',
#   'group',
#   'workout',
#   'Monday'],
#  ['Dallas',
#   'group',
#   'be',
#   'back',
#   'home',
#   'Monday',
#   'third',
#   'victory',
#   'four',
#   'group',
#   'start',
#   '19',
#   '12',
#   'triumph',
#   'group',
#   'visit',
#   'be',
#   'short',
#   'one'],
#  ['group',
#   'have',
#   'two',
#   'more',
#   'road_game',
#   'location',
#   'Houston',
#   'play',
#   'again',
#   'look',
#   'coach',
#   'person',
#   'men',
#   'meet',
#   'group',
#   'develop',
#   'kind',
#   'team',
#   'expect',
#   'be',
#   'preseason',
#   'reckoning'],
#  ['location',
#   'coach',
#   'person',
#   'become',
#   'one',
#   'game',
#   'collector',
#   'quarterback',
#   'apparently',
#   'now',
#   'find',
#   'productive',
#   'pair',
#   'two',
#   'group',
#   'person',
#   'person'],
#  ['person',
#   'former',
#   'group',
#   'field_general',
#   'come_off',
#   'debut',
#   'group',
#   'Sunday',
#   'direct',
#   'new',
#   'team',
#   'upset',
#   'victory',
#   'group',
#   'defend',
#   'league',
#   'champion'],
#  ['just', 'luck', 'exclaim', 'person'],
#  ['person', 'solve', 'quarterback', 'problem', 'head', 'way'],
#  ['person',
#   'have',
#   'thing',
#   'two',
#   'mutter',
#   'Dallas',
#   'defensive',
#   'unit',
#   'splendid',
#   'effort',
#   'Denver',
#   'group',
#   'be',
#   'able',
#   'whip',
#   'dangerous',
#   'group',
#   'fullback',
#   'top',
#   'star',
#   'person',
#   'team',
#   'place-kicking',
#   'nurse',
#   'knee',
#   'injury'],
#  ['interior',
#   'line',
#   'linebacker',
#   'play',
#   'exceptionally',
#   'well',
#   'say',
#   'person',
#   'staff',
#   'review',
#   'movie',
#   'game'],
#  ['in_fact', 'whole', 'defensive', 'unit', 'do', 'good', 'job'],
#  ['group',
#   'win',
#   'game',
#   'ball',
#   'control',
#   'quarterback',
#   'person',
#   'throw',
#   'only',
#   '17',
#   'pass'],
#  ['always',
#   'like',
#   'keep',
#   'ball',
#   'much',
#   'Denver',
#   'have',
#   'explosive',
#   'attack',
#   'explain',
#   'person'],
#  ['go_along',
#   'do',
#   'little',
#   'damage',
#   'then',
#   'hit',
#   'a_couple_of',
#   'pass',
#   'touchdown',
#   'put'],
#  ['group',
#   'hit',
#   'two',
#   'quick',
#   'strike',
#   'final_period',
#   'group',
#   'Dallas',
#   'have',
#   'enough',
#   'lead',
#   'hold_off'],
#  ['principal', 'tactic', 'ball', 'give', 'person', 'flashy', 'halfback'],
#  ['26', 'time', 'more', 'other', 'ball', 'carrier', 'deliver', 'yard'],
#  ['group',
#   'make',
#   'comforting',
#   'break',
#   'opening',
#   'kickoff',
#   'Denver',
#   'person',
#   'jar',
#   'loose',
#   'ball',
#   'person',
#   'speedy',
#   'halfback',
#   'hit',
#   'guard',
#   'person',
#   'claim',
#   'Dallas'],
#  ['quick', 'touchdown', 'result'],
#  ['permit',
#   'start',
#   'ball',
#   'right_away',
#   'say',
#   'person',
#   'quip',
#   'think',
#   'put',
#   'play',
#   'book'],
#  ['early',
#   'group',
#   'football',
#   'leader',
#   'group',
#   'group',
#   'group',
#   'make',
#   'big',
#   'dent',
#   'statistic',
#   'last',
#   'week'],
#  ['group',
#   'yard',
#   'spree',
#   'group',
#   'give',
#   'group',
#   '3',
#   'game',
#   'total',
#   'offense',
#   'yard',
#   'rushing',
#   'passing',
#   'new',
#   'group',
#   'high'],
#  ['group',
#   'combine',
#   'yard',
#   'rushing',
#   'yard',
#   'passing',
#   '5',
#   'completion',
#   '7',
#   'toss',
#   'tough',
#   'defense',
#   'whip',
#   'group',
#   'group',
#   'point',
#   'bulge',
#   'group',
#   'run_up',
#   'total',
#   'play'],
#  ['complete',
#   '12',
#   '15',
#   'pass',
#   'yard',
#   'group',
#   'have',
#   'total',
#   'offense',
#   'yard'],
#  ['group',
#   'lead',
#   'game',
#   'rushing',
#   'average',
#   'yard',
#   'passing',
#   'group',
#   'idle',
#   'group',
#   'have',
#   'best',
#   'defensive',
#   'record',
#   'yard',
#   'game',
#   'group'],
#  ['group', 'have', 'best', 'defense', 'pass', 'yard', 'game'],
#  ['not',
#   'satisfied',
#   'various',
#   'unofficial',
#   'check',
# ...
#   'departure',
#   'location',
#   'now',
#   'run',
#   'rate',
#   'not',
#   'week',
#   'application',
#   'leave',
#   'rise',
#   'week'],
#  ['official',
#   'statistic',
#   'show',
#   '60',
#   'percent',
#   'be',
#   'employed',
#   'worker',
#   'independent',
#   'professional',
#   'people'],
#  ['whole', 'family', 'move', 'removal_firm', 'be', 'booked', 'month', 'ahead'],
#  ['loss',
#   'partly',
#   'counterbalance',
#   '500',
#   'arrival',
#   'each_week',
#   'location',
#   'hard',
#   'truth',
#   'say',
#   'person',
#   'be',
#   'closing_off',
#   'location',
#   'interference',
#   'West',
#   'use',
#   'only',
#   'East_German',
#   'distinct',
#   'Russian',
#   'troops',
#   'be',
#   'major',
#   'communist',
#   'victory',
#   'deal',
#   'location',
#   'deadly',
#   'possibly',
#   'fatal',
#   'blow'],
#  ['gallant', 'half', 'city', 'die'],
#  ['piece', 'evidence', 'appear', 'dispatch', 'Bonn', 'London'],
#  ['person', 'write', 'people', 'leave', 'location', 'think', 'die'],
#  ['leave',
#   'so',
#   'fast',
#   'president',
#   'location',
#   'issue',
#   'appeal',
#   'week',
#   'factory_worker',
#   'West',
#   'volunteer',
#   'six',
#   'month',
#   'front_line',
#   'work',
#   'factory',
#   'location'],
#  ['Berlin',
#   'resilience',
#   'be',
#   'amazing',
#   'hire',
#   'labor',
#   'West',
#   'struggle',
#   'be',
#   'hard',
#   'indeed'],
#  ['handwriting', 'be'],
#  ['hope',
#   'location',
#   'lie_in',
#   'compromise',
#   'bring_down',
#   'wall',
#   'reunite',
#   'city'],
#  ['State_Department',
#   'official',
#   'refuse',
#   'show',
#   'pass',
#   'boundary',
#   'drive',
#   'two',
#   'block',
#   'location',
#   'military',
#   'escort',
#   'not',
#   'avail'],
#  ['tank', 'line_up', 'border', 'be', 'no_more'],
#  ['material',
#   'compromise',
#   'be',
#   'at_hand',
#   'person',
#   'other',
#   'sober',
#   'commentator',
#   'person',
#   'spell_out',
#   'again_and_again'],
#  ['compromise', 'leave', 'side', 'glow', 'triumph', 'save', 'location'],
#  ['city',
#   'be',
#   'graveyard',
#   'monument',
#   'western',
#   'intransigence',
#   'be',
#   'West',
#   'want'],
#  ['removal',
#   'person',
#   'body',
#   'mausoleum',
#   'share',
#   'person',
#   'less',
#   'distinguished',
#   'quarters',
#   'location',
#   'wall',
#   'not',
#   'unprecedented',
#   'history'],
#  ['be', 'in_fact', 'relatively', 'mild', 'chastisement', 'dead'],
#  ['British',
#   'writer',
#   'person',
#   'book',
#   'recall',
#   'turmoil',
#   'precede',
#   'French_Revolution',
#   'body',
#   'person',
#   'die',
#   'nearly',
#   'year',
#   'earlier',
#   'tear',
#   'piece',
#   'mob'],
#  ['location', 'Restoration', 'body', 'person', 'disinter', 'hang', 'location'],
#  ['head',
#   'then',
#   'fix',
#   'pole',
#   'location',
#   'rest',
#   'body',
#   'bury',
#   'gallows'],
#  ['contemplate', 'posthumous', 'punishment', 'person', 'not', 'lose', 'hope'],
#  ['group',
#   'erect',
#   'statue',
#   'person',
#   'location',
#   'location',
#   'there',
#   'presumably',
#   'still',
#   'stand'],
#  ['person', 'however', 'create', 'yet', 'problem'],
#  ['person',
#   'tomb',
#   'be',
#   'obviously',
#   'adequate',
#   'double',
#   'occupancy',
#   'Moscow',
#   'be',
#   'crowded',
#   'city',
#   'creed',
#   'communism',
#   'deplore',
#   'waste'],
#  ['take', 'person', 'place', 'person'],
#  ['person', 'of_course', 'bury', 'London'],
#  ['person',
#   'government',
#   'let_go_of',
#   'be',
#   'dead',
#   'year',
#   'even',
#   'Soviet',
#   'mortician',
#   'not',
#   'make',
#   'look',
#   'presentable'],
#  ['then', 'be', 'sufficient', 'stature', 'lodge', 'person'],
#  ['person'],
#  ['just',
#   'be',
#   'top_dog',
#   'not',
#   'be',
#   'ready',
#   'receive',
#   'honor',
#   'gift',
#   'Soviet',
#   'people'],
#  ['besides',
#   'hardly',
#   'avoid',
#   'muse',
#   'instability',
#   'death',
#   'exhumation',
#   'rehabilitation',
#   'seem',
#   'match',
#   'life'],
#  ['suppose', 'lie', 'person', 'be', 'permanent'],
#  ['future',
#   'person',
#   'decide',
#   'rake_up',
#   'misdeed',
#   'revered',
#   'predecessor',
#   'not',
#   'factory_worker',
#   'pass',
#   'same',
#   'resolution',
#   'applaud',
#   'dispossession'],
#  ['man', 'lay_to_rest', 'entitle', 'stay_put'],
#  ['person',
#   'buy',
#   'small',
#   'plot',
#   'modest',
#   'rural',
#   'cemetery',
#   'understand'],
#  ['appointment',
#   'person',
#   'Burma',
#   'group',
#   'acting',
#   'Secretary_General',
#   'writing',
#   'choice',
#   'appear',
#   'be',
#   'certain',
#   'offer',
#   'proof',
#   'be',
#   'more',
#   'important',
#   'influential',
#   'enemy',
#   'influential',
#   'friend'],
#  ['person',
#   'Tunisia',
#   'person',
#   'Ireland',
#   'be',
#   'early',
#   'favorite',
#   'France',
#   'like',
#   'Soviet_Union',
#   'latter'],
#  ['neutralist',
#   'maintain',
#   'pressure',
#   'own',
#   'succeed',
#   'person',
#   'person',
#   'emerge',
#   'possible',
#   'candidate',
#   'unlikely',
#   'waylay',
#   'veto'],
#  ['be',
#   'interesting',
#   'be',
#   'positive',
#   'qualification',
#   'post',
#   'reveal',
#   'only',
#   'kind',
#   'tail',
#   'candidacy'],
#  ['all',
#   'bitter',
#   'in-fighting',
#   'squabble',
#   'election',
#   'procedure',
#   'complicated',
#   'numbers_game',
#   'East',
#   'West',
#   'play',
#   'assistant',
#   'secretary',
#   'theme',
#   'gentleman',
#   'Burma',
#   'man',
#   'principle',
#   'skilled',
#   'diplomat'],
#  ['have', 'moreover', 'qualification', 'augur', 'well', 'future'],
#  ['be',
#   'Buddhist',
#   'mean',
#   'peace',
#   'sanctity',
#   'human',
#   'life',
#   'be',
#   'dogma',
#   'profound',
#   'unshakable',
#   'Weltanschauung'],
#  ['person',
#   'of_course',
#   'hold',
#   'office',
#   'spring',
#   'person',
#   'term',
#   'come',
#   'end'],
#  ['compromise',
#   'side',
#   'interim',
#   'appointment',
#   'then',
#   'repeat',
#   'remain',
#   'see'],
#  ['person',
#   'demand',
#   'troika',
#   'be',
#   'not',
#   'dead',
#   'West',
#   'not',
#   'remain',
#   'satisfied',
#   'kind',
#   'neutralism',
#   'person',
#   'represent'],
#  ['showdown',
#   'promise',
#   'person',
#   'sudden',
#   'tragic',
#   'death',
#   'avoid',
#   'precedent',
#   'set',
#   'as_yet',
#   'structurally',
#   'group',
#   'be',
#   'still',
#   'fluid',
#   'vulnerable',
#   'pressure',
#   'new',
#   'membership',
#   'bring_to_bear'],
#  ['at_least',
#   'pessimist',
#   'believe',
#   'world_organization',
#   'plunge',
#   'death',
#   'plane',
#   'crash',
#   'Congo',
#   'prove',
#   'wrong'],
#  ['study', 'radical', 'right', 'suppose', 'words', 'be', 'staple', 'trade'],
#  ['be',
#   'mentality',
#   'crave',
#   'action',
#   'begin',
#   'get_it',
#   'person',
#   'person',
#   'report',
#   'page'],
#  ['even', 'area', 'political', 'connotation', 'deliberately'],
#  ['leave', 'vague', 'spirit', 'vigilantism', 'spread'],
#  ['picture',
#   'magazine',
#   'distribute',
#   'group',
#   'dealer',
#   'describe',
#   'paramilitary_organization',
#   'employee',
#   'group',
#   'location',
#   'location'],
#  ['day',
#   'ever',
#   'come',
#   'foreign',
#   'invader',
#   'swarm',
#   'ashore',
#   'group',
#   'account',
#   'read',
#   'heavy',
#   'opposition',
#   'group',
#   'commando',
#   'trained',
#   'telephone',
#   'employee',
#   'all',
#   'girl'],
#  ['heavily',
#   'armed',
#   'mobilize',
#   'fast',
#   'moving',
#   'civil_defense',
#   'outfit',
#   '23',
#   'telephone_operator',
#   'office',
#   'personnel',
#   'stand',
#   'ready',
#   'move_into',
#   'action',
#   'minute',
#   'notice'],
#  ['unit',
#   'organize',
#   'person',
#   'former',
#   'commando',
#   'be',
#   'vice_president',
#   'general_manager',
#   'telephone_company'],
#  ['girl',
#   'very',
#   'fetching',
#   'uniform',
#   'show',
#   'fire',
#   'rocket',
#   'launcher',
#   'mount',
#   'dump_truck',
#   'also',
#   'train',
#   'carbine',
#   'automatic',
#   'weapon',
#   'pistol',
#   'rifle',
#   'other',
#   'lady',
#   'accessory'],
#  ['be',
#   'opera_bouffe',
#   'now',
#   'become',
#   'more',
#   'serious',
#   'cold_war',
#   'mount',
#   'frenzy'],
#  ['country', 'be', 'committed', 'doctrine', 'security', 'military', 'means'],
#  ['doctrine', 'never', 'work', 'not', 'work', 'now'],
#  ['official',
#   'military',
#   'establishment',
#   'only',
#   'threaten',
#   'use',
#   'nuclear',
#   'arms',
#   'bring',
#   'actual',
#   'play'],
#  ['more', 'dangerous', 'formula', 'national', 'frustration', 'imagine'],
#  ['civic',
#   'temper',
#   'rise',
#   'more',
#   'naive',
#   'citizen',
#   'begin',
#   'play',
#   'soldier',
#   'gun',
#   'be',
#   'real'],
#  ['soon', 'begin', 'hunt_down', 'traitor', 'be', 'assure', 'be', 'midst'],
#  ['not', 'news', 'person', 'be', 'wizard', 'violin'],
#  ['certainly',
#   'not',
#   'location',
#   'play',
#   'countless',
#   'recital',
#   'Thursday',
#   'night',
#   'celebrate',
#   '20th',
#   'season',
#   'group',
#   'play',
#   'own',
#   'slashing',
#   'demon-ridden',
#   'cadenza',
#   'melt',
#   'high',
#   'pale',
#   'pure',
#   'lovely',
#   'song',
#   'violinist',
#   'unlock',
#   'heart',
#   'music',
#   'forever',
#   'find',
#   'closed'],
#  ['be', 'song', 'incandescent', 'location', 'be', 'person', 'white_heat'],
#  ['not',
#   'noble',
#   'performance',
#   'hear',
#   'play',
#   'most',
#   'spacious',
#   'even',
#   'most',
#   'eloquent'],
#  ['reserve', 'orchestra', 'night', 'soloist', 'surpass'],
#  ['time',
#   'orchestra',
#   'give',
#   'some',
#   'superb',
#   'support',
#   'fire',
#   'response',
#   'own',
#   'high',
#   'mood'],
#  ['have', 'person', 'willing', 'conductor', 'able', 'only', 'point'],
#  ['person',
#   'thrust',
#   'straight',
#   'core',
#   'music',
#   'spark',
#   'fly',
#   'bow',
#   'shred',
#   'violin',
#   'singing',
#   'glitter',
#   'sometimes',
#   'spit',
#   'person',
#   'go_along'],
#  ['person', 'not', 'go', 'straight', 'point'],
#  ['flounder', 'let', 'music', 'sprawl'],
#  ['be',
#   'person',
#   'mysterious',
#   'marvelous',
#   'great',
#   'conductor',
#   'bring',
#   'soloist',
#   'orchestra',
#   'music',
#   'ultimate',
#   'fusion'],
#  ['have', 'some', 'dazzling', 'memorable', 'person', 'not', 'great', 'person'],
#  ['concert',
#   'open',
#   'another',
#   'big',
#   'romantic',
#   'score',
#   'person',
#   'suffer',
#   'fate',
#   'time',
#   'orchestral',
#   'thrust',
#   'point',
#   'keep',
#   'afloat'],
#  ['person',
#   'joust',
#   'person',
#   'tune',
#   'be',
#   'considerably',
#   'more',
#   'serious',
#   'misfortune',
#   'demand',
#   'translucent',
#   'texture',
#   'buoyant',
#   'rhythm',
#   'astringent',
#   'wit'],
#  ['get',
#   'kind',
#   'scrambled',
#   'coarsened',
#   'performance',
#   'happen',
#   'best',
#   'orchestra',
#   'man',
#   'baton',
#   'lack',
#   'technique',
#   'style'],
#  ['open',
#   'July',
#   'new',
#   'production',
#   'stage',
#   'person',
#   'do',
#   'all',
#   'opera',
#   'time',
#   'conduct',
#   'person'],
#  ['person', 'also', 'conduct', 'open', 'July'],
#  ['follow', 'July', 'person', 'conduct', 'also', 'conduct', 'present', 'Aug'],
#  ['cycle', 'be', 'July', 'Aug'],
#  ['person', 'conduct'],
#  ['cast',
#   'list',
#   'person',
#   'send_word',
#   'negro',
#   'soprano',
#   'person',
#   'sing',
#   'Venus'],
#  ['remember',
#   'series',
#   'booking',
#   'absurdity',
#   'Chicago',
#   'miss',
#   'see',
#   'group'],
#  ['remember',
#   'lack',
#   'two',
#   'big',
#   'theater',
#   'Chicago',
#   'miss',
#   'first',
#   'visit',
#   'group'],
#  ['now', 'have', 'two', 'big', 'theater'],
#  ['bar',
#   'miracle',
#   'hold',
#   'breath',
#   'Chicago',
#   'not',
#   'see',
#   'group',
#   'stem',
#   'ballet',
#   'cradle',
#   'group',
#   'be',
#   'company'],
#  ['let_loose',
#   'howl',
#   'say',
#   'announce',
#   'coming',
#   'not',
#   'once',
#   'several',
#   'time',
#   'indeed'],
#  ['engagement',
#   'be',
#   'set',
#   'big',
#   'theater',
#   'location',
#   'person',
#   'ballet',
#   'booker',
#   'extraordinary',
#   'consider',
#   'house',
#   'kind',
#   'country',
#   'of_course',
#   'weep',
#   'capacity',
#   'either'],
#  ['set'],
#  ['group', 'corporation', 'first', 'list', 'Chicago', 'date', 'Dec'],
#  ['later',
#   'person',
#   'office',
#   'make',
#   'Dec',
#   'nice',
#   'long',
#   'booking',
#   'full',
#   'repertory'],
#  ['keep', 'calendar', 'event', 'notice', 'conflict'],
#  ['group', 'book', 'person', 'location', 'Dec'],
#  ['give'],
#  ['not', 'person'],
#  ['group',
#   'then',
#   'notify',
#   'group',
#   'cut_short',
#   'Los_Angeles',
#   'booking',
#   'fly',
#   'here',
#   'open',
#   'Nov',
#   'close',
#   'Dec'],
#  ['short', 'booking', 'still', 'booking'],
#  ['print'],
#  ['a_couple_of',
#   'day',
#   'later',
#   'balletomane',
#   'tell',
#   'telephone',
#   'group',
#   'ticket',
#   'information',
#   'tell',
#   'newspaper',
#   'make',
#   'mistake'],
#  ['start', 'make', 'call', 'own'],
#  ['be', 'result'],
#  ['group', 'firmly', 'book', 'location', 'Los_Angeles', 'Nov', 'Dec'],
#  ['not', 'chance', 'open', 'here', 'Nov', 'bar', 'miracle'],
#  ['then', 'not', 'juicy', 'booking', 'person', 'hold'],
#  ['person', 'budge', 'group'],
#  ['then', 'group'],
#  ['group', 'book', 'person', 'there', 'week', 'start', 'Dec'],
#  ['query',
#   'impasse',
#   'group',
#   'say',
#   'better',
#   'cancel',
#   'group',
#   'for_the_time_being'],
#  ['up_in_the_air', 'again'],
#  ['group',
#   'fly',
#   'back',
#   'Russia',
#   'Chicago',
#   'engagement',
#   'serious',
#   'loss',
#   'dance',
#   'fan',
#   'frustrated',
#   'booker',
#   'cancellation',
#   'rich',
#   'booking',
#   'country'],
#  ['reopen', 'auditorium'],
#  ['painting',
#   'drawing',
#   'person',
#   'location',
#   'Virgin_Islands',
#   'show',
#   'Nov',
#   'location',
#   'location',
#   'weekday',
#   '3',
#   '8',
#   'Sunday',
#   '3',
#   '6',
#   'close',
#   'Monday'],
#  ['exhibition',
#   'person',
#   'painting',
#   'open',
#   'reception',
#   'Nov',
#   'location',
#   'location'],
#  ['continue', 'month'],
#  ['abstraction', 'abstraction', 'person', 'exhibit', 'location', 'Nov'],
#  ['line',
#   'operatic',
#   'trade',
#   'cushion',
#   'budget',
#   'group',
#   'use',
#   'San_Francisco',
#   'new',
#   'group',
#   'production',
#   'season',
#   'return',
#   'favor',
#   'next',
#   'season',
#   'San_Francisco',
#   'use',
#   'Dallas',
#   'design',
#   'person'],
#  ['person', 'scribble', 'farce'],
#  ['be', 'most', 'irresponsible', 'novel', 'season'],
#  ['moral', 'lurk', 'shenanigan', 'be', 'hard', 'find'],
#  ['perhaps',
#   'lesson',
#   'take',
#   'page',
#   'be',
#   'welfare_state',
#   'England',
#   'still',
#   'allow',
#   'wild',
#   'scope',
#   'kind',
#   'rugged',
#   'eccentric'],
#  ['anyway', 'number', 'meet', 'here', 'devastating', 'collision'],
#  ['be', 'imperial', 'London', 'stockbroker', 'person'],
#  ['be',
#   'wily',
#   'countryman',
#   'person',
#   'blandly',
#   'boisterous',
#   'progress',
#   'chronicle',
#   'believe',
#   'early',
#   'volume',
#   'person'],
#  ['now'],
#  ['person',
#   'wife',
#   'person',
#   'reach',
#   'stage',
#   'affluence',
#   'stir',
#   'longing',
#   'more',
#   'atrociously',
#   'expensive',
#   'rustic',
#   'simplicity'],
#  ['own',
#   'junior-grade',
#   'castle',
#   'manor_house',
#   'modest',
#   'little',
#   'place',
#   'Shakespeare',
#   'once',
#   'stage',
#   'pageant',
#   'person',
#   'all',
#   'bearded',
#   'courtier'],
#  ['willing',
#   'settle',
#   'however',
#   'offer',
#   'pheasant',
#   'shoot',
#   'peasant',
#   'work_at'],
#  ['of_course', 'person', 'have', 'just', 'thing', 'want'],
#  ['horror'],
#  ['name', 'be', 'location', 'surround', 'wasteland', 'impress', 'person'],
#  ['not', 'precisely', 'way', 'person', 'urge', 'look_at', 'though'],
#  ['conjure_up', 'herd', 'deer', 'wild', 'bird', 'crowd', 'air'],
#  ['suggest', 'location', 'embody', 'glory', 'Tudor', 'splendor'],
#  ['stained-glass_window',
#   'develop',
#   'unpremeditated',
#   'patina',
#   'paneling',
#   'be',
#   'no',
#   'more',
#   'durable',
#   'plank',
#   'political_platform'],
#  ['vast',
#   'dungeon',
#   'kitchen',
#   'seem',
#   'hardly',
#   'worth',
#   'use',
#   'occasion',
#   'face',
#   'unexpected',
#   'guest',
#   'lunch'],
#  ['person', 'have', 'answer'],
#  ['spaciousness',
#   'Tudor',
#   'area',
#   'for_example',
#   'provide',
#   'needed',
#   'space',
#   'television_set',
#   'require',
#   'modern',
#   'butler',
#   'cook',
#   'maid'],
#  ['also',
#   'perhaps',
#   'table_tennis',
#   'other',
#   'indoor',
#   'sport',
#   'keep',
#   'fit',
#   'contented'],
#  ['wonder',
#   'really',
#   'much',
#   'mendacious',
#   'trouble',
#   'person',
#   'put',
#   'sell',
#   'person',
#   'preposterous',
#   'manse'],
#  ['really',
#   'need',
#   'immense',
#   'sum_of_money',
#   'probably',
#   'convert',
#   'American',
#   'gold',
#   'group',
#   'make',
#   'pay'],
#  ['person', 'already', 'wonderfully', 'content', 'lot'],
#  ['have', 'wife', 'many', 'child'],
#  ['need',
#   'money',
#   'buy',
#   'keep',
#   'vegetable_patch',
#   'sale',
#   'surplus',
#   'army'],
#  ['capital_gain', 'venture', 'in_fact', 'saddle', 'location'],
#  ['willing', 'sell', 'just'],
#  ['person', 'willing', 'buy'],
#  ['plan',
#   'become',
#   'county',
#   'people',
#   'know',
#   'proper',
#   'way',
#   'terminate',
#   'fox',
#   'life',
#   'Earth'],
#  ['person',
#   'eye',
#   'be',
#   'nothing',
#   'location',
#   'farmer',
#   'have',
#   'much',
#   'learn',
#   'learn',
#   'way',
#   'truly',
#   'rural',
#   'living'],
#  ['person', 'show', 'mutual', 'education', 'spread', 'inevitable', 'havoc'],
#  ['one-upmanship', 'practice', 'side', 'war'],
#  ...]

# %%
length_of_wordvec=len(model_w2v["the"])
context_bag_vector = []
for sent in synCorpus_words:
    context_count=0
    context_list=np.zeros((length_of_wordvec,))
    #for every sentence get the context bag
    single_sentence='_'.join(word for word in sent)
    single_sentence=single_sentence.replace('-','_')
    splits=single_sentence.split('_')
    for word in splits:
        try:
            context_list+=model_w2v[word]
            context_count+=1
        except:
            print(word)
    if context_count!=0:
        context_bag_vector.append(context_list/context_count)
    else:
        context_bag_vector.append(context_list)
    #words_in_sentence=[word for word in splits if not word in stopwords.words()]
# Out:
# of
# and
# of
# governor's
# 100
# 30
# and
# 50
# 10
# 29
# 13th
# a
# 17
# 13
# of
# 1000
# 12
# 22
# of
# 24
# 12
# 30
# 24
# of
# of
# of
# of
# 13
# 10
# 27
# 22
# 22
# to
# 15
# a
# a
# 22
# of
# a
# 27
# 26
# 14
# 15
# 13
# 26
# 20
# 10
# 13
# of
# 10
# 12
# 16
# 40
# 30
# 22
# 22
# 30
# and
# 22
# a
# 30
# 19
# 12
# 17
# a
# of
# 26
# 12
# 15
# 27
# 25th
# 12
# a
# 40
# of
# 40
# beardown
# 25
# 25
# 30
# 19th
# 15
# and
# 20
# 15
# a
# of
# 12
# of
# of
# of
# 11
# of
# 19
# 16
# of
# a
# 12
# of
#
# a
# 25
# a
# plunker
# 10
# 10
# a
# a
# 10
# 24
# 10
# 60
# 10
# lustre
# and
# of
# malposed
#
#
# catalogue
# to
# catalogue
# a
# a
# bull's
# and
# bull's
# to
# frowningly
#
# of
# 15
# 52
# 20
# a
# 30
# 50
# of
# and
# 100
# of
# of
# 50
# 18
# 60
# 500
# and
# of
# of
# to
# of
# to
# 23
# 20th
# of
# a
# of
# of
# of
# addlebrained
# errantry
# of
# a
# 26
# a
# a
# of
# a
# of
# operagoer
# 12
# microphoning
# 12
# a
# 40
# i.e.
# 100
# to
# 10
# to
# a
# of
# and
#
# to
# to
# unstilted
# a
# of
# a
# a
# and
# of
# presentness
# to
# of
# Klux
# givenness
# of
# demythologization
# expurgation
# conceptuality
# kerygma
# and
# conceptuality
# demythologized
# demythologization
# to
# a
# demythologized
# kerygma
# kerygma
# of
# of
# to
# to
# to
# demythologization
# demythologization
# demythologization
# a
# demythologization
# of
# 18
# 25
# 19th
# Tractarian
# of
# 27
# of
# of
# 20
# to
# nonchurchgoing
# 50
# of
# 19th
# to
# of
# of
# 14th
# a
# preexistence
# preexistent
# of
# of
# to
# and
# and
# i.e.
# a
# sternocleido
# mastoideus
# anticus
# 12
# 10
# wonderworking
# of
# a
# a
# hipline
# to
# a
#
# a
# of
# a
# of
# 24
# a
# to
# a
# of
# a
# of
# a
# bartlett
# a
# to
# of
# 16
# 27
# 12
# 12
# of
# landler
# tensionless
# theatre
# obtrude
# of
# spirito
# and
# of
# a
# a
# a
# of
# to
# of
# 16
# wives'
# 29
# 11
# a
# of
# a
# a
# a
# of
# a
# of
# of
# to
# of
# a
# of
# a
# arm's
# a
# of
# a
# and
# to
# of
# a
# offence
# a
# of
# retrovision
# a
# of
# a
# of
# Cassite
# of
# to
# of
# and
# naprapath
# electrotherapist
# of
# 10
# of
# of
# 27
# 50
# 10
# 60
# T.B.
# a
# 10
# of
# of
# 60
# subliterary
# to
# of
# a
# to
# and
# a
# axe
# a
# 16
# 24
# to
# of
# to
# a
# of
# to
# of
# of
# of
# a
# of
# of
# a
# a
# and
# of
# 19th
# 20th
# to
# constatation
# encipher
# to
# to
# to
# to
# to
# to
# to
# psychopomp
# imprecate
# to
# to
# unthematic
# of
# of
# 25
# 25
# of
# of
# Massachuset
# of
# 30
# 60
# of
# 10
# Massachuset
# 25
# of
# of
# of
# 25
# of
# of
# 25
# of
# 10
# 25
# of
# e.g.
# to
# a
# 10
# a
# lunation
# 15
# of
# 50
# subtend
# 10
# 22
# 11
# 50
# subtend
# lunation
# 18
# 15
# transpirate
# 100
# 90
# 50
# of
#
#
#
# thoriated
# 50
# 30
# 100
# 50
# millivoltmeter
# 100
#
# 16
# polybutene
# polybutene
# spinnability
# molal
# molal
# of
# thermostatics
# of
# of
# of
# of
# to
# of
# of
# cyclohexanol
# of
# cosecant
# i.e.
# to
# paramagnet
# dimethylglyoxime
# semiempirical
# dimethylglyoxime
# trigonal
#
# nonequivalent
# nonequivalence
# of
# a
# 500
# 15
# thermogravimetric
# 1000
# 12
# 40
# 10
# 16
# 40
# to
# 10
# 16
# of
# alundum
# alkylbenzenesulfonate
# 50
# tripolyphosphate
# tripolyphosphate
# 100000
# grey
# redeposition
# to
# nonparticulate
# Waal's
# to
# to
# solvating
# to
# 60
# 80
# oleophilic
# oleophilic
# to
# 26
# of
# oleophilic
# redeposition
# antiredeposition
# tetrahalide
# of
# prechlorination
# radiochlorine
# radiochlorine
# 50
# 1000
# a
# 25
# precooled
# 15
# a
# 20
# 10
# 20
# 70
# 12
# radiochlorine
# irreproducibility
# a
# 80
# 13
# 40
# irreproducibility
# 11
# 18
# actinometer
# of
#
# 1000
# 60
# i.e.
# semiminor
# and
# micrometeoritic
# of
# a
# of
# micrometeoritic
# 1000
# 22
# 11
# a
# 40
# 10
# gegenschein
# 25
# 50
# of
# of
# to
# of
# a
# Earth's
# spherule
# to
# alveolus
# of
# 24
# i.e.
# isopleth
# var.
# 29
# 100
# 23
# isopleth
# 100
# of
# botulinal
# of
# of
# a
# diethylaminoethyl
# DEAE
# carboxymethyl
# DEAE
# agglutinin
# preisolate
# DEAE
# 1000
# 30
# 1000
# 1000
# immunoelectrophoresis
# glycerolize
# 20
# 30
# deglycerolize
# 20
# 18
# 10
# 24
# aminomethane
# DEAE
# DEAE
# meq
# 100
# 25
# 12
# pervaporation
# barbital
# 18
# bromophenol
# eluate
# 16
# 500
# 80
# 20
# 12
# agglutinin
# agglutinin
# DEAE
# agglutinin
# 15
# agglutinin
# agglutinin
# agglutinating
# agglutinin
# al.
# agglutinin
# eluate
# to
# 50
# a
# of
# staminate
# nectary
# 26
# staminate
# beebread
# beebread
# beebread
# to
# beebread
# Psithyrus
# Psithyrus
# beebread
# beebread
# Psithyrus
# Psithyrus
# a
# andrena
# andrena
# beebread
# andrena
# andrena
# andrena
# andrena
# andrena
# nomia
# Nomia
# melanderi
# of
# andrena
# prepupal
# nomia
# of
# Thamnophis
# a
# amethystine
# a
# 18
# 40
# to
# amethystine
# of
# of
# amethystine
# 10
# Tropidoclonion
# Storeria
# Ancistrodon
# to
# 25
# amethystine
# 22
# 20
# 18
# 12
# 30
# 50
# 70
# of
# 22
# 29
# 27
# 20
# 26
# 19
# 14
# 16
# of
# 19
# 10
# 12
# 13
# 14
# 14
# 50
# 30
# to
# 20
# 14
# 25
# 11
# of
# 22
# bronchiole
# alveolus
# bronchiole
# bronchiole
# interlobular
# bronchiole
# bronchiole
# 14
# 15
# septation
# 24
# 23
# 24
# vasorum
# bronchiole
# interlobular
# 10
# interlobular
# interlobular
# netlike
# vasorum
# 16
# 23
# 24
# 17
# 18
# interlobular
# bronchiole
# 14
# 17
# 18
# 19
# bronchiolar
# 26
# interlobular
# to
# bronchiole
# of
# intrapulmonary
# alveolus
# bronchiole
# alveolus
# uninjectable
# to
# lobularity
# interlobular
# bronchiole
# bronchiole
# bronchiole
# bronchiole
# interlobular
# 12
# 10
# 20
# 21
# 30
# 40
# 21
# of
# 21
# 21
# 21
# 17
# 18
# 21
# 18
# 29
# 21
# 26
# 13
# 14
# 24
# 25
# 23
# 15
# 22
# 16
# 18
# 23
# 17
# 30
# 19
# 24
# organification
# iodotyrosine
# homogenate
# iodoprotein
# iodinate
# iodoamino
# iodotyrosine
# homogenate
# iodotyrosine
# iodinating
# iodinating
# thyronine
# iodination
# iodotyrosine
# iodotyrosine
# iodothyronine
# nonenzymatic
# iodotyrosine
# iodocompound
# iodination
# tumour
# organification
# iodothyronine
# iodinating
# iodinase
# triphosphopyridine
# iodinating
# iodotyrosine
# iodotyrosine
# iodinate
# iodothyronine
# iodotyrosine
# iodothyronine
# iodination
# univalent
# fluoroboride
# iodinating
# thiouracil
# organification
# iodinate
# a
# of
# thiouracil
# antagonise
# thiouracil
# goitrogen
# goitrogen
# goitrogen
# goitrogen
# 100
# iodinate
# iodotyrosine
# iodotyrosine
# iodothyronine
# organification
# thyrotrophin
# thyrotrophic
# thyroidal
#
# hypophysectomised
# trichloroacetic
# 100
# thyrotoxic
# emphasise
# 20
# 15
# 40
# 10
# chlorothiazide
# 16
# 30
# meq
# 16
# chlorothiazide
# fasciculation
# 24
# 12
# sarcolemmal
# glutamic
# oxaloacetic
# 10
# 20
# 30
# hypoadrenocorticism
# norethandrolone
# senilis
# 19
# basophilic
# emphysematous
# hyperemic
# fibrocalcific
# alveolus
# hemosiderin
# arteriolosclerosis
# vacuolated
# hemosiderin
# 40
# 14
# sanguineous
# hyperemic
# Monilia
# pyocanea
# Aerobacter
# aerogenes
# anhemolyticus
# arteriolosclerosis
# hyalinization
# arteriole
# hypercellularity
# hypocellularity
# megakaryocytic
# transversus
# abdominis
# brachii
# vacuolization
# a
# pyknotic
# myofibril
# vacuolization
# flocculate
# myofibrilla
# pyknotic
# 10
# 15
# basophilic
# myofibrilla
# trichrome
# arteriole
# tumefaciens
# 30
# 20
# 50
# 80
# 80
# lyophilize
# diethylaminoethyl
# al.
# 16
# 20
# 30
# 15
# 30
# 24
# 30
# 40
# 15
# 30
# 30
# 15
# 30
# 30
# 15
# 30
# 50
# 100
# 10
# 30
# 15
# 30
# 15
# pseudophloem
# 10
# 10
# 100
# 500
# DEAE
# 50
# 10
# 30
# 15
# 30
# 15
# 50
# 50
# DEAE
# 30
# 15
# DEAE
# precipitin
# DEAE
# DEAE
# and
# pseudophloem
# a
# pseudophloem
# DEAE
# pseudophloem
# a
# pseudophloem
# al.
# pseudophloem
# cortically
# and
# paleocortex
# to
# paleocortical
# corticofugal
# corticofugal
# reflexly
# analeptic
# to
# maniclike
# analeptic
# hypothalamically
# hypophyseal
# reflexly
# to
# a
# Metrazol
# desynchronizing
# abreaction
# trophotropic
# ergotropic
# i.e.
# monic
# diagonalizable
# diagonalizable
# of
# of
# monic
# i.e.
# i.e.
# i.e.
# i.e.
# a
# i.e.
# diagonalizable
# diagonalizable
# nilpotent
# diagonalizable
# nilpotent
# diagonalizable
# nilpotent
# diagonalizable
# nilpotent
# diagonalizable
# nilpotent
# diagonalizable
# diagonalizable
# diagonalizable
# nilpotent
# nilpotent
# nilpotent
# diagonalizable
# nilpotent
# nilpotent
# diagonalizable
# e.g.
# diagonalizable
# nilpotent
# nilpotent
# monic
# i.e.
# i.e.
# a
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# bull's
# of
# bull's
# i.e.
# abscissa
# of
# of
# of
# extremum
# analyticity
# of
# of
# to
# of
# of
# to
# summate
# and
# of
# a
# freewheeler
# and
# of
# and
# to
# scrutin
# scrutin
# of
# of
# and
# of
# of
# of
# of
# to
# of
# tactual
# of
# of
# tactual
# of
# of
# of
# tactual
# of
# tactual
# of
# of
# tactual
# and
# of
# of
# of
# tactual
# tactual
# of
# and
# and
# subfigure
# and
# tactual
# and
# of
# tactually
# and
# hexameter
# to
# protogeometric
# protogeometric
# of
# Argive
# Boeotian
# basileus
# to
# archaize
# Dipylon
# protogeometric
# and
# a
# a
# a
# and
# 100
# posseman
# 100
# 100
# a
# a
# a
# besieger
# besieger
# posseman
# of
# 10
# a
# 21
# 15
# to
# drygoods
# 14
# of
# and
# of
# severalty
# of
# of
# misname
# a
# of
# arm's
# extraneousness
# of
# undepicted
# undepicted
# l'oeil
# woodgraining
# of
# undepicted
# undepicted
# of
# of
# a
# a
# of
# to
# of
# and
# drygoods
# hotelman
# drygoods
# a
# 30
# 60
# 15
# 18
# of
# 24
# 24
# 24
# 50
# 24
# 24
# 24
# 24
# a
# 1000
# 20
# 12
# 40
# ciliate
# predomination
# 10
# 10
# 24
# 60
# a
# 60
# 13
# 18
# 16
# of
# a
# a
# and
# a
# to
#
#
# a
# a
# to
# a
# a
# malevolency
# of
#
#
# and
# to
# whisky
# to
# a
# of
# and
# whisky
# to
# of
# a
# to
# Krauthead
# 50
# worshipper
# and
# to
# of
# of
# 500
# a
# of
# of
# of
# of
# pretence
# of
# a
# and
# honour
# practised
# theatre
# theatre
# a
# and
# ironshod
#
#
#
#
#
# alligatored
#
#
# of
# of
# of
# of
# a
# of
# to
#
# redheader
# and
#
# of
# and
#
#
#
#
#
#
# and
#
#
# a
#
# to
#
#
#
#
#
#
#
#
# to
# of
#
# a
# a
#
# of
#
# of
# and
# of
# of
#
# of
# a
# and
# to
# outface
# outface
# to
# raftered
# of
# to
# gospeler
# arianist
# of
# to
# of
# arianist
# a
#
# of
# hardbake
# befog
#
# bestubbled
# whisky
# trustfully
# to
# untellable
# of
# whisky
# of
# and
# to
#
# of
# of
# of
# of
# of
# of
# of
# a
# of
# sowbelly
# lobscuse
# lobscouse
# lobscuse
# a
# a
#
# southernism
# overcurious
# unservile
# a
# a
# a
# of
# of
# a
# teacart
# teacart
# and
# and
# a
# to
#
# unpicturesque
# of
# grey
# of
# of
#
# fieldhand
# to
# a
# whisky
# whisky
# and
#
# of
# and
# to
# of
# a
# of
# chevaux
# frise
# and
# and
# of
# of
# of
# a
# of
#
#
# of
# a
# of
# a
#
# a
# of
# to
# ginmill
# ginmill
# a
# and
# to
# of
#
# to
# sickish
# of
# and
# a
# bullethead
# to
# to
# portwatcher
# portwatcher
# a
# of
# of
# oyabun
#
# oyabun
# oyabun
#
# and
# oyabun
# a
#
# and
# of
# a
# to
# to
# and
# cassocked
# amorist
# to
# beadsman
# of
# of
# of
# reprovingly
# of
# a
# of
#
# and
# incertain
#
# nighted
#
#
#
#
#
# bewilderedly
#
#
# of
# of
# of
# mobcap
# and
# a
# and
# of
# and
# a
# to
# of
# a
#
# a
# of
# of
# a
# escritoire
# of
# uncousinly
# of
# and
# escritoire
# whisky
# whisky
# a
# a
# of
#
#
#
#
#
#
#
#
#
# axe
# of
# to
# whisky
# whisky
#
#
# whisky
# axe
# axe
# whisky
#
# whisky
#
# whisky
#
# whisky
# axe
# and
# whisky
#
#
# and
# and
# Year's
# of
# a
# to
# a
# of
# a
# uncombable
# a
# to
# of
# of
# of
# a
# and
# to
# a
#
# of
#
# a
# of
# a
# a
# to
# and
# patronne
# revery
# lappet
# patronne
# patronne
# enquire
# patronne
# sforzando
# a
# and
# cackly
# and
#
# to
# a
# a
# clothesbrush
#
# of
# to
# a
#
# a
# catalogue
# unsloped
# epistolatory
# enrol
# schoolgirlish
# Year's
# of
# of
# Year's
# traveller
# reveller
# and
# Year's
# a
# Year's
# a
# of
# a
# a
# a
# to
# a
#
# of
# of
# a
# and
# and
#
# to
# a
# and
# worshipper
#
# to
# to
# a
# of
# to
#
#
# of
# of
#
# discorporate
# to
# and
# and
#
# to
#
#
#
# a
#
# matsyendra
# of
# to
#
#
# to
# and
# of
# of
# of
# a
#
# of
# earthman
# earthman
# of
# quirt
# to
#
#
#
# quirt
# to
#
# and
# quirt
# quirt
# a
# of
# quirt
# quirt
# a
# and
#
# quirt
# of
# of
# a
# to
#
# of
# a
# signore
# to
# to
#
#
# and
#
# to
# of
# soutane
# a
# amphibology
# parisology
# gagwriter
# misrelated
# headlinese
# entendre
# to
# a
# of
# of
# indefinity
# entendre
# of
# a
# of
# and
# to
# a
# and
# a
# theatre
# theatre
# to
# horselaugh
# of
# a
# of
# a
#
# and
# restively
# and
# a
# of
#
# twirlingly
# a
# of
# of
# of
# a
# of
# a
# a
# a
# a
# a
# of
# a
# of
# and
# and
# to
#
#
# a
#
#
# atonally
# to
# of
# a
# a
# theatre
# theatre
# theatre
# triphammer
# and
# Jongg
# Bogartian
# curvaceously
# unpaintable
# and
# i.e.
# a
# d'art
# effloresce
# frambesia
# king's
# clonic
# a
# of
#
# a
# of
# chaulmoogra
# fantods
# catalogue
# of
# thuggee
#
# rooftree
# a
# of
# a
# areaway
# chivy
# of
# of
# of
# granville
# bilharziasis
# a
# 70th
# of
# of
# 18th
# dadaism
# theatre
# of
# of
# neoromanticism
# ecclesiasticism
# reharmonization
# 20th
# of
# of
# practise
# 20th
# 30th
# of
# and
# a
# and
# and
# stylemark
# of
# of
# of
# and
# 10
# alizarin
# Hooker's
# ochre
# Payne's
# Davy's
# to
# decorativeness
# mind's
# 15th
# 18
# 20
# academicianship
# a
# orthicon
# orthicon
# 20
# 21
# 16
# 25
# 30
# and
# 15
# 90
# 90
# 12
# of
# 10
# galvanism
# 30
# electrophorus
# 60
# of
# transversally
# sheepman
# 10
# 25
# 50
# 100
# 10
# 20
# 50
# 70
# Aureomycin
# 70
# 30
# 30
# 50
# Aureomycin
# Aureomycin
# enterotoxemia
# 20
# 50
# Aureomycin
# vibrionic
# 80
# 20
# 10
# 10
# 25
# 10
# 10
# 10
# 100
# 14
# 14
# 60
# 10
# 100
# 70
# phenothiazine
# 12
# 50
# 50
# 24
# phenothiazine
# phenothiazine
# acetonemia
# acetonemia
# 10
# acetonemia
# 20
# 25
#
# 10
# 14
# of
# 10
# 10
# of
# and
# 10
# 10
# 24
# a
# 12
# of
# a
# of
# of
# of
# a
# outmode
# 40
# of
# 23
# to
# a
# of
# a
# a
# 70
# 15
# 10
# 30
# of
# to
# 29
# of
# of
# of
# of
# a
# of
# 19
# 20
# 90
# of
# 20
# to
# laborsaving
# to
# of
# of
# 14
# of
# 500
# 14
# of
# delicti
# to
# of
# of
# to
# to
# of
# and
# i.e.
# to
# of
# of
# 22
# 28
# 17th
# of
# of
# a
# 11th
# and
# axe
# 100
# a
# thill
# of
# 100
# 30
# to
# 15th
# 24th
# 20
# whisky
# a
# of
# and
# crupper
# of
# and
# and
# diarrhoea
# of
# diarrhoea
# diarrhoea
# a
# i.e.
# 50
# a
# 19th
# and
# of
# a
# of
# a
# homefolk
# of
# candour
# bawdyhouse
# neighbourhood
# safebreaker
# labour
# pistoleer
# organise
# dishonour
# honour
# honour
# aggrandisement
# theatre
# to
# whisky
# whisky
# 100
# 15
# 25
# 1000
# of
# a
# 1000
# 100
# 60
# 500
# 10
# 100
# 20
# 60
# 15
# 21
# 26
# Noctiluca
# miliaris
# 10
# 40
# of
# 15
# 18th
# of
# to
# to
# 25
# 12
# 1000
# 25
# and
# to
# to
# and
# 23
# 25
# of
# of
# a
# of
# and
# a
# 11
# and
# a
# 15
# 20th
# a
# to
# to
# 15
# 30
# 28
# 21
# to
# to
# of
# of
# of
# to
# of
# detribalize
# 30
# 25
# a
# and
# a
# a
# of
# of
# to
# and
# of
# and
# a
# a
# to
# optation
# optation
# 60
# optation
# optation
# optation
# optation
# optation
# optation
# to
# to
# of
# of
#
# Jansenist
# of
# of
# of
# of
# of
# a
# millwheel
# a
# a
# petticoated
# of
# a
# a
# catalogue
# to
# unselfconsciousness
# crocketed
# slantwise
# of
# unimpassioned
# conventionalize
# carven
# abstractive
# scepticism
# melioration
# to
# a
# instancy
# of
#
# a
# of
# a
# tokenish
# and
# a
# of
# a
# a
# a
# to
# of
# of
# of
# 19th
# of
# 20th
# to
# of
# of
# to
# a
# distortable
# of
# a
# and
# incipience
# to
# of
# Rousseauan
# to
# to
# of
# to
# of
# e.g.
# of
# of
# e.g.
# e.g.
# of
# e.g.
# to
# a
# to
# of
# calibre
#
# to
# of
# resift
# steprelationship
# barnful
# beplastered
# of
# of
#
# to
# of
# to
# of
# of
# unliterary
# of
# unmalicious
# of
# importunity
# a
# of
# a
# a
# a
# of
# a
# and
# bobbysoxer
# of
# a
# to
# a
# relyric
# of
# a
# of
# negroid
# a
# and
# of
# of
# of
# to
# of
# a
# of
# theatre
# of
# anaesthesia
# colour
# of
# of
# to
# to
# of
# of
# to
# i.e.
# to
# of
# to
# of
# of
# of
# of
# to
# of
# of
# of
# of
# and
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# of
# 15
# a
# of
# 100
# a
# 60
# 80
# 21
# 21
# 15
# 20
# thermometric
# 10
# millidegree
# millidegree
# millidegree
# millidegree
# 15
# 25
# millidegree
# millidegree
# 25
# to
# of
# 1000
# 10
# 90
# catalogue
# 70
# 18
# 10
# 10
# of
# to
# of
# of
# of
# of
# of
# of
# 31
# of
# of
# 500
# of
# of
# of
# of
# of
# of
# 1000
# 1000
# 1000
# 25
# 1000
# to
# 1000
# of
# of
# of
# of
# 60
# 14
# 40
# of
# 17th
#
# 90
# of
# 100
# 100
# 50
# of
# of
# 50
# 50
# 50
# 100
# and
# 10
# 11
# 13
# 11
# 12
# 13
# to
# 40
# 60
# 25
# 40
# 50
# 30
# of
# of
# 40
# 40
# 40
# 70
# 100
# 50
# 70
# 21
# 10
# 22
# 23
# 20
# 20
# 28
# 10
# 24
# 25
# 50
# 100
# 1000
# 11
# 26
# 27
# 500
# 12
# 10
# 11
# 10
# 29
# 29
# 14
# 30
# 10
# of
# a
#
#
# of
# incipiency
# incipiency
#
#
#
#
# 18
# 25
# 25
# to
# 14
# to
# of
# to
# of
# 60
#
#
#
# 15
#
#
# 17th
# 100
# 13th
# 100
# 50
# 100
# 30th
# 11th
# 17th
# 100
# 12
# 20
# 25
# 100
#
#
#
# tecum
# of
#
# a
# of
# of
# of
# of
# to
# of
# a
# of
# of
# of
# 14
# to
# of
# 30
# of
# of
# of
# 11
# 15
# 28
# of
# of
# obligational
# of
# 52
# 52
# 52
# to
# 15th
# of
# 15th
# 15th
# 15th
# 15th
# 15th
# of
# 30
# of
# of
# of
# 15
# 10
# 12
# 10
# devisee
# 20
# 50
# 24
# 30
# 19
# 16
# al.
# al.
# I.Q.
# I.Q.
# I.Q.
# I.Q.
# of
# al.
# of
# a
# of
# a
# enrol
# and
#
# introject
# parrotlike
# and
# hebephrenic
# introject
# and
# a
# introject
# introjected
# introject
# hebephrenic
# introject
# and
# hebephrenic
# to
# of
# of
# of
# a
# hebephrenic
# hebephrenic
# dedifferentiated
# hebephrenic
# to
# concretistic
# concretistic
# hebephrenic
# grammatic
# grammatic
# grammatic
# grammatic
# grammatic
# of
# of
# of
# of
# to
# to
# of
# gerundial
# gerundial
# vocalic
# consonantal
# of
# to
# consonantal
# analyse
# phonologic
# phonologic
# phonologic
# phonologic
# consonantal
# nonlinguistic
# uninitiate
# cooccurring
# nonlinguistic
# of
# consonantal
# phonologic
# phonemics
# accentual
# phonologic
# morphophonemic
# morphemic
# i.e.
# morphophonemics
# morphophonemics
# consonantal
# morphophonemics
# morphophonemic
# consonantal
# morphophonemic
# of
# consonantal
# morphophonemic
# morphophonemics
# morphophonemics
# consonantal
# morphophonemics
# morphophonemic
# consonantal
# of
# morphophonemics
# morphophonemics
# morphophonemic
# analyse
# morphophonemics
# morphophonemic
# abstruseness
# phonologic
# syllabicity
# a
# phonemics
# phonologic
# phonologic
# phonologic
# 24
# 21
# unambiguity
# glottochronological
# 70
# 16
# 25
# 100
# 29
# 17
# 16
# 15
# 22
# 22
# lingually
# 20
# 15
# 11
# 16
# 19
# 14
# 15
# 11
# 12
# of
# 20
# 20
# 11
# 100
# glottochronological
# 100
# unasterisked
# glottochronological
# 15
# 15
# 15
# and
# lexicostatistics
# Penutian
# lexicostatistics
# lexicostatistics
# lexicostatistics
# glottochronology
# lexicostatistic
# 29
# 15
# 13
# 11
# 10
# 17
# 10
# a
# of
# a
# e.g.
# 10
# 14
# and
# of
# of
# of
# of
# to
# of
# of
# of
# 19th
# of
# of
# of
# to
# of
# jurisprudentially
# to
# to
# to
# of
# of
# of
# a
# of
# a
# of
# a
# a
# of
# o.k.
# o.k.
# and
# of
# a
# a
# of
# to
# a
# to
#
# a
# to
# to
# a
# to
# of
# a
#
# a
#
# of
# unprocurable
#
# of
# a
# to
#
#
#
#
#
#
#
#
# of
# and
#
# of
# a
#
# of
# and
# of
# a
# to
#
#
# of
# a
# of
# wilfully
#
#
#
#
#
# a
# of
# of
# of
# of
# of
#
# to
# of
# to
# a
# of
#
#
# of
#
# of
# handclasp
#
# and
# of
# to
# and
# of
# of
# to
# a
# to
# a
# of
# to
# a
# to
# of
# a
# of
# of
# of
#
#
#
# and
# of
#
# a
# and
# prise
# washbowl
# and
# of
# a
#
# a
# of
#
# of
# and
# and
#
# to
# nasale
# midwatch
#
# of
# velour
# a
# a
# of
# and
# a
# of
#
# whisky
# and
# and
# of
#
#
# a
# a
# a
# of
# of
# a
#
#
# a
#
#
#
# a
#
#
# levis
# a
# of
#
#
#
# of
# of
# a
# to
# a
#
# and
# of
#
# and
# bedground
# offsaddle
# remuda
# workboard
# cookfire
#
# of
# and
# cantle
# a
# a
# and
# of
#
# scarecrowish
# to
# a
# soddy
# of
# 10
# of
# a
# 30
# a
# of
# a
# of
# to
#
# a
#
# a
# a
# crowbait
# of
#
# a
# a
# canyonside
# to
# a
# cowpuncher
# a
#
#
# of
# a
# a
# and
# of
# a
# a
#
# and
# of
# a
# and
#
# 60
# a
# to
# of
# and
# reecho
# slivery
#
# to
# of
# a
#
# of
# of
# a
# of
#
# a
#
#
#
#
#
# of
# a
# a
#
#
#
# a
# a
# dandily
# a
# a
#
# of
#
#
# a
# of
# plainclothesman
# a
# dichondra
# plainclothesman
# a
# of
# 10
#
# unlash
# draught
# a
# semitrance
# and
# sharecrop
# marrowbone
# and
# and
# haggardly
# and
# floodhead
# bloodedly
# pretence
# of
# handspike
# holystone
# handspike
# topgallant
# topgallant
# handspike
# and
# of
# of
# to
#
# of
# of
# a
# and
#
# of
# to
# of
# of
# to
# a
# of
# and
# jeweler's
# a
# of
# to
# of
#
# and
# to
# to
# a
# of
# a
# of
# a
# and
#
# a
#
#
# a
#
# to
#
# a
#
# a
# of
# to
# to
# to
# of
#
# to
# to
#
# and
# and
# of
# a
# to
# a
# a
# to
# a
# a
# of
# batter's
# batter's
# batter's
#
#
# and
# a
#
# and
# of
# of
# a
#
#
# a
#
# to
# of
# to
# to
# doweling
#
# a
# of
# a
# of
#
#
#
# of
# fulfil
#
#
# of
#
#
# indorse
#
#
#
#
#
#
#
#
#
#
#
#
#
# to
# to
#
#
#
# to
#
#
#
#
#
# of
# to
#
#
#
#
#
# of
#
#
#
#
#
# of
# to
#
#
#
#
#
# to
#
#
# to
#
# to
#
#
#
#
#
#
#
#
#
# to
#
# of
#
#
#
#
#
#
# to
# to
# to
# fulfil
# of
#
#
# to
# to
# to
#
#
# to
# a
# to
# cerebrate
#
#
#
# of
# to
#
#
#
#
#
#
#
#
#
#
#
# to
# of
#
#
#
#
#
# of
# to
#
#
#
#
# of
#
#
# a
# of
#
#
# to
#
#
#
#
#
#
# to
# of
# of
#
# to
# to
#
# a
#
#
#
#
#
# to
#
#
#
#
# to
#
#
#
#
#
#
#
#
#
#
#
# retranslate
#
#
#
# of
#
#
#
#
#
# to
#
#
#
# to
#
#
#
#
#
#
#
#
#
#
# of
# to
#
# of
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# of
#
#
#
# of
#
#
#
#
#
#
#
#
#
#
#
#
# of
# misgauge
# outgeneral
#
#
#
#
#
#
#
# to
#
#
#
#
#
# to
# of
#
# catalogue
# to
#
#
# to
# to
# to
# a
#
#
#
#
#
#
# of
# of
# communize
# to
# of
# to
#
# narcotize
#
# calumniate
# to
# of
# to
#
#
# to
# to
#
#
#
#
#
#
#
#
#
# of
#
#
#
#
#
#
#
#
#
# to
# foreknow
# a
# a
# a
# a
# to
# to
#
# to
# a
# a
# mould
#
#
# enrol
#
#
#
# to
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# to
#
# to
#
#
#
#
#
#
#
#
# to
# to
#
#
#
#
# unsolder
#
#
#
#
#
# a
#
#
#
#
#
#
#
#
#
#
# to
# of
#
#
#
#
#
#
#
#
# backstitch
#
# backstitch
#
#
#
#
#
#
# to
# to
#
#
# to
#
#
#
#
#
# of
# of
#
# of
#
#
#
#
#
# sulphur
# chandelle
#
#
#
#
#
#
# to
#
#
#
#
#
# a
# of
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# to
# of
#
#
#
#
#
#
#
# of
#
#
# of
# of
# to
# to
# of
# to
# of
#
# to
# animize
#
# of
# to
#
# to
#
#
# of
#
#
#
#
# of
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# to
# of
# of
#
#
#
# to
#
#
#
#
#
#
#
#
#
# a
# to
#
#
# of
# of
#
#
# of
#
#
# to
#
# to
# of
#
#
# to
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# of
#
#
#
#
#
#
#
#
#
#
#
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# of
#
#
#
#
#
#
#
#
#
#
#
#
#
# of
#
# of
#
#
#
#
#
#
#
#
#
# a
#
#
#
#
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# to
#
#
#
#
# to
#
#
#
#
# of
#
#
#
#
#
# of
# to
# of
#
#
#
#
#
# to
#
#
# to
#
# a
# to
# of
#
#
#
#
#
#
#
#
#
#
#
# to
#
#
# of
# of
# to
# to
#
#
#
#
#
# a
#
#
#
#
#
#
#
#
#
#
#
# a
#
# a
#
#
# to
#
# to
#
#
#
#
#
#
#
#
#
#
# to
# to
# of
# of
#
#
#
#
# harshen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# of
#
#
# to
#
#
# to
#
#
#
#
#
#
#
# to
#
#
#
#
#
#
#
#
#
#
# to
#
#
#
#
#
#
#
#
#
#
# of
#
#
#
#
# to
#
# woolgather
#
#
#
#
#
#
#
# of
#
# of

# %%
overlapCorpus=[]
count=0
test=0
test1=0
for sent in synCorpus_words:
    overlapCorpus.append([])
    for word in sent:
        synsets_word=wn.synsets(word)
#         amb_list=np.zeros((length_of_wordvec,))
#         amb_count=0
        curr_sim=-1
        curr_synset=synsets_word[0]
        for synset_word in synsets_word:
            amb_list=np.zeros((length_of_wordvec,))
            amb_count=0
            synset_gloss=synset_word.definition()
            ########TEST
#             synset_examples=synset_word.examples()
#             synset_examples_combined='_'.join(ex for ex in synset_examples)
#             synset_gloss='_'.join(ex for ex in synset_examples_combined+synset_def)
            
            ###########TEST
            splits=synset_gloss.split()
#             print(splits)
            for word1 in splits:
                try:
                    if(word1!=word):
                        amb_list+=model_w2v[word1]
                        amb_count+=1
                except:
                    pass
            if amb_count!=0:
                amb_vec=(amb_list/amb_count)
            else:
                amb_vec=amb_list
            cos_similarity=model_w2v.cosine_similarities(context_bag_vector[count].T,[amb_vec.T])[0]
            if curr_sim<cos_similarity:
                curr_sim=cos_similarity
                curr_synset=synset_word
        overlapCorpus[count].append((word,curr_synset.name()))
    count+=1

# %%
cat=model_w2v["lungs"]
dog=model_w2v["physics"]
model_w2v.cosine_similarities(cat,[dog])[0]
# Out:
# 0.0892538

# %%
overlapCorpus
# Out:
# [[('group', 'group.n.01'),
#   ('say', 'say.n.01'),
#   ('Friday', 'friday.n.01'),
#   ('investigation', 'probe.n.01'),
#   ('Atlanta', 'atlanta.n.01'),
#   ('recent', 'holocene.n.01'),
#   ('primary_election', 'primary.n.01'),
#   ('produce', 'produce.n.01'),
#   ('evidence', 'evidence.n.01'),
#   ('irregularity', 'abnormality.n.04'),
#   ('take_place', 'happen.v.01')],
#  [('jury', 'jury.n.01'),
#   ('far', 'army_for_the_liberation_of_rwanda.n.01'),
#   ('say', 'say.n.01'),
#   ('term', 'term.n.01'),
#   ('end', 'end.n.01'),
#   ('presentment', 'presentment.n.01'),
#   ('group', 'group.n.01'),
#   ('have', 'rich_person.n.01'),
#   ('overall', 'overall.n.01'),
#   ('charge', 'charge.n.01'),
#   ('election', 'election.n.01'),
#   ('deserve', 'deserve.v.01'),
#   ('praise', 'praise.n.01'),
#   ('thanks', 'thanks.n.01'),
#   ('location', 'location.n.01'),
#   ('manner', 'manner.n.01'),
#   ('election', 'election.n.01'),
#   ('conduct', 'behavior.n.01')],
#  [('September', 'september.n.01'),
#   ('October', 'october.n.01'),
#   ('term', 'term.n.01'),
#   ('jury', 'jury.n.01'),
#   ('charge', 'charge.n.01'),
#   ('location', 'location.n.01'),
#   ('person', 'person.n.01'),
#   ('investigate', 'investigate.v.01'),
#   ('report', 'report.n.01'),
#   ('possible', 'possible.n.01'),
#   ('irregularity', 'abnormality.n.04'),
#   ('hard-fought', 'hard-fought.s.01'),
#   ('primary', 'primary.n.01'),
#   ('win', 'win.n.01'),
#   ('person', 'person.n.01')],
#  [('only', 'lone.s.03'),
#   ('relative', 'relative.n.01'),
#   ('handful', 'handful.n.01'),
#   ('report', 'report.n.01'),
#   ('receive', 'receive.v.01'),
#   ('jury', 'jury.n.01'),
#   ('say', 'say.n.01'),
#   ('consider', 'see.v.05'),
#   ('widespread', 'widespread.s.01'),
#   ('interest', 'interest.n.01'),
#   ('election', 'election.n.01'),
#   ('number', 'number.n.01'),
#   ('voter', 'voter.n.01'),
#   ('size', 'size.n.01'),
#   ('city', 'city.n.01')],
#  [('jury', 'jury.n.01'),
#   ('say', 'say.n.01'),
#   ('find', 'discovery.n.03'),
#   ('Georgia', 'georgia.n.01'),
#   ('registration', 'registration.n.01'),
#   ('election', 'election.n.01'),
#   ('law', 'law.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('outmoded', 'outmode.v.01'),
#   ('inadequate', 'inadequate.a.01'),
#   ('often', 'frequently.r.01'),
#   ('ambiguous', 'equivocal.a.01')],
#  [('recommend', 'recommend.v.01'),
#   ('location', 'location.n.01'),
#   ('legislator', 'legislator.n.01'),
#   ('act', 'act.n.01'),
#   ('have', 'rich_person.n.01'),
#   ('law', 'law.n.01'),
#   ('study', 'survey.n.01'),
#   ('revise', 'revision.n.02'),
#   ('end', 'end.n.01'),
#   ('modernize', 'overhaul.v.02'),
#   ('improve', 'better.v.02')],
#  [('grand_jury', 'grand_jury.n.01'),
#   ('comment', 'remark.n.01'),
#   ('number', 'number.n.01'),
#   ('other', 'other.a.01'),
#   ('topic', 'subject.n.01'),
#   ('Atlanta', 'atlanta.n.01'),
#   ('location', 'location.n.01'),
#   ('purchasing_department', 'purchasing_department.n.01'),
#   ('say', 'say.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('well', 'well.n.01'),
#   ('operate', 'operate.v.01'),
#   ('follow', 'follow.v.01'),
#   ('generally', 'by_and_large.r.01'),
#   ('practice', 'practice.n.01'),
#   ('inure', 'inure.v.01'),
#   ('best', 'best.n.01'),
#   ('interest', 'interest.n.01'),
#   ('government', 'government.n.01')],
#  [('however', 'however.r.01'),
#   ('jury', 'jury.n.01'),
#   ('say', 'say.n.01'),
#   ('believe', 'believe.v.01'),
#   ('two', 'two.n.01'),
#   ('office', 'office.n.01'),
#   ('achieve', 'achieve.v.01'),
#   ('efficiency', 'efficiency.n.01'),
#   ('reduce', 'reduce.v.01'),
#   ('cost', 'cost.n.01'),
#   ('administration', 'administration.n.01')],
#  [('group', 'group.n.01'),
#   ('jury', 'jury.n.01'),
#   ('say', 'say.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('lacking', 'miss.v.06'),
#   ('experienced', 'experience.v.01'),
#   ('clerical', 'clerical.a.01'),
#   ('personnel', 'force.n.04'),
#   ('result', 'consequence.n.01'),
#   ('city', 'city.n.01'),
#   ('personnel', 'force.n.04'),
#   ('policy', 'policy.n.01')],
#  [('urge', 'urge.n.01'),
#   ('city', 'city.n.01'),
#   ('take', 'return.n.06'),
#   ('step', 'measure.n.01'),
#   ('remedy', 'redress.n.02'),
#   ('problem', 'problem.n.01')],
#  [('implementation', 'execution.n.06'),
#   ('Georgia', 'georgia.n.01'),
#   ('automobile', 'car.n.01'),
#   ('title', 'title.n.01'),
#   ('law', 'law.n.01'),
#   ('also', 'besides.r.02'),
#   ('recommend', 'recommend.v.01'),
#   ('outgoing', 'surpass.v.02'),
#   ('jury', 'jury.n.01')],
#  [('urge', 'urge.n.01'),
#   ('next', 'following.s.02'),
#   ('legislature', 'legislature.n.01'),
#   ('provide', 'supply.v.01'),
#   ('enabling', 'enable.v.01'),
#   ('fund', 'fund.n.01'),
#   ('reset', 'reset.n.01'),
#   ('effective', 'effective.a.01'),
#   ('date', 'date.n.01'),
#   ('implementation', 'execution.n.06'),
#   ('law', 'law.n.01'),
#   ('effect', 'consequence.n.01')],
#  [('grand_jury', 'grand_jury.n.01'),
#   ('group', 'group.n.01'),
#   ('handling', 'handling.n.01'),
#   ('federal', 'federal.n.01'),
#   ('fund', 'fund.n.01'),
#   ('child_welfare_service', 'child_welfare_agency.n.01'),
#   ('foster_home', 'foster_home.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('one', 'one.n.01'),
#   ('major', 'major.n.01'),
#   ('item', 'item.n.01'),
#   ('location', 'location.n.01'),
#   ('general', 'general.n.01'),
#   ('assistance', 'aid.n.02'),
#   ('program', 'plan.n.01'),
#   ('jury', 'jury.n.01'),
#   ('say', 'say.n.01'),
#   ('group', 'group.n.01'),
#   ('distribute', 'distribute.v.01'),
#   ('fund', 'fund.n.01'),
#   ('welfare', 'social_welfare.n.01'),
#   ('department', 'department.n.01'),
#   ('all', 'all.a.01'),
#   ('county', 'county.n.01'),
#   ('state', 'state.n.01'),
#   ('exception', 'exception.n.01'),
#   ('location', 'location.n.01'),
#   ('receive', 'receive.v.01'),
#   ('money', 'money.n.01')],
#  [('juror', 'juror.n.01'),
#   ('say', 'say.n.01'),
#   ('realize', 'recognize.v.02'),
#   ('proportionate', 'proportionate.a.01'),
#   ('distribution', 'distribution.n.01'),
#   ('fund', 'fund.n.01'),
#   ('disable', 'disable.v.01'),
#   ('program', 'plan.n.01'),
#   ('less', 'lupus_erythematosus.n.01'),
#   ('populous', 'populous.s.01'),
#   ('county', 'county.n.01')],
#  [('nevertheless', 'however.r.01'),
#   ('feel', 'feel.n.01'),
#   ('location', 'location.n.01'),
#   ('receive', 'receive.v.01'),
#   ('some', 'some.a.01'),
#   ('portion', 'part.n.01'),
#   ('available', 'available.a.01'),
#   ('fund', 'fund.n.01'),
#   ('juror', 'juror.n.01'),
#   ('say', 'say.n.01')],
#  [('failure', 'failure.n.01'),
#   ('do', 'bash.n.02'),
#   ('continue', 'continue.v.01'),
#   ('place', 'topographic_point.n.01'),
#   ('disproportionate', 'disproportionate.a.01'),
#   ('burden', 'burden.n.01'),
#   ('location', 'location.n.01'),
#   ('taxpayer', 'taxpayer.n.01')],
#  [('jury', 'jury.n.01'),
#   ('also', 'besides.r.02'),
#   ('comment', 'remark.n.01'),
#   ('location', 'location.n.01'),
#   ('ordinary', 'ordinary.n.01'),
#   ('court', 'court.n.01'),
#   ('under_fire', 'under_attack.s.01'),
#   ('practice', 'practice.n.01'),
#   ('appointment', 'appointment.n.01'),
#   ('appraiser', 'appraiser.n.01'),
#   ('guardian', 'defender.n.01'),
#   ('administrator', 'administrator.n.01'),
#   ('awarding', 'award.n.01'),
#   ('fee', 'fee.n.01'),
#   ('compensation', 'compensation.n.01')],
#  [('jury', 'jury.n.01'),
#   ('say', 'say.n.01'),
#   ('find', 'discovery.n.03'),
#   ('court', 'court.n.01'),
#   ('incorporate', 'integrate.v.01'),
#   ('operating_procedure', 'operating_procedure.n.01'),
#   ('recommendation', 'recommendation.n.01'),
#   ('two', 'two.n.01'),
#   ('grand_jury', 'grand_jury.n.01'),
#   ('group', 'group.n.01'),
#   ('interim', 'interim.n.01'),
#   ('citizens_committee', 'committee.n.02')],
#  [('action', 'action.n.01'),
#   ('serve', 'serve.n.01'),
#   ('protect', 'protect.v.01'),
#   ('in_fact', 'in_fact.r.01'),
#   ('in_effect', 'effective.s.04'),
#   ('court', 'court.n.01'),
#   ('ward', 'ward.n.01'),
#   ('undue', 'undue.a.01'),
#   ('cost', 'cost.n.01'),
#   ('appointed', 'appoint.v.01'),
#   ('elected', 'elect.v.01'),
#   ('servant', 'servant.n.01'),
#   ('unmeritorious', 'unmeritorious.s.01'),
#   ('criticism', 'criticism.n.01'),
#   ('jury', 'jury.n.01'),
#   ('say', 'say.n.01')],
#  [('regard', 'respect.n.01'),
#   ('Atlanta', 'atlanta.n.01'),
#   ('new', 'new.a.01'),
#   ('million', 'million.n.01'),
#   ('dollar', 'dollar.n.01'),
#   ('airport', 'airport.n.01'),
#   ('jury', 'jury.n.01'),
#   ('recommend', 'recommend.v.01'),
#   ('new', 'new.a.01'),
#   ('management', 'management.n.01'),
#   ('take_charge', 'take_hold.v.01'),
#   ('Jan', 'january.n.01'),
#   ('airport', 'airport.n.01'),
#   ('operate', 'operate.v.01'),
#   ('manner', 'manner.n.01'),
#   ('eliminate', 'extinguish.v.04'),
#   ('political', 'political.a.01'),
#   ('influence', 'influence.n.01')],
#  [('jury', 'jury.n.01'),
#   ('not', 'not.r.01'),
#   ('elaborate', 'elaborate.v.01'),
#   ('add', 'attention_deficit_disorder.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('periodic', 'periodic.a.01'),
#   ('surveillance', 'surveillance.n.01'),
#   ('pricing', 'pricing.n.01'),
#   ('practice', 'practice.n.01'),
#   ('concessionaire', 'concessionaire.n.01'),
#   ('purpose', 'purpose.n.01'),
#   ('keep', 'support.n.06'),
#   ('price', 'monetary_value.n.01'),
#   ('reasonable', 'reasonable.a.01')],
#  [('other', 'other.a.01'),
#   ('matter', 'matter.n.01'),
#   ('jury', 'jury.n.01'),
#   ('recommend', 'recommend.v.01')],
#  [('four', 'four.n.01'),
#   ('deputy', 'deputy.n.01'),
#   ('employ', 'employment.n.01'),
#   ('group', 'group.n.01'),
#   ('doctor', 'doctor.n.01'),
#   ('medical_intern', 'intern.n.01'),
#   ('extern', 'extern.n.01'),
#   ('employ', 'employment.n.01'),
#   ('night', 'night.n.01'),
#   ('weekend', 'weekend.n.01'),
#   ('duty', 'duty.n.01'),
#   ('jail', 'jail.n.01')],
#  [('location', 'location.n.01'),
#   ('legislator', 'legislator.n.01'),
#   ('city', 'city.n.01'),
#   ('official', 'official.n.01'),
#   ('pass', 'base_on_balls.n.01'),
#   ('enabling_legislation', 'enabling_legislation.n.01'),
#   ('permit', 'license.n.01'),
#   ('establishment', 'constitution.n.02'),
#   ('equitable', 'equitable.a.01'),
#   ('pension', 'pension.n.01'),
#   ('plan', 'plan.n.01'),
#   ('city', 'city.n.01'),
#   ('employee', 'employee.n.01')],
#  [('jury', 'jury.n.01'),
#   ('praise', 'praise.n.01'),
#   ('administration', 'administration.n.01'),
#   ('operation', 'operation.n.01'),
#   ('Atlanta', 'atlanta.n.01'),
#   ('police_department', 'police_department.n.01'),
#   ('group', 'group.n.01'),
#   ('location', 'location.n.01'),
#   ('location', 'location.n.01'),
#   ('prison_farm', 'work_camp.n.01'),
#   ('group', 'group.n.01'),
#   ('group', 'group.n.01')],
#  [('person', 'person.n.01'),
#   ('file', 'file.n.01'),
#   ('suit', 'suit.n.01'),
#   ('divorce', 'divorce.n.01'),
#   ('wife', 'wife.n.01'),
#   ('person', 'person.n.01'),
#   ('group', 'group.n.01'),
#   ('Friday', 'friday.n.01')],
#  [('petition', 'request.n.01'),
#   ('charge', 'charge.n.01'),
#   ('mental', 'mental.a.01'),
#   ('cruelty', 'cruelty.n.01')],
#  [('couple', 'couple.n.01'), ('marry', 'marry.v.01'), ('Aug', 'august.n.01')],
#  [('have', 'rich_person.n.01'),
#   ('son', 'son.n.01'),
#   ('person', 'person.n.01'),
#   ('daughter', 'daughter.n.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01')],
#  [('attorney', 'lawyer.n.01'),
#   ('mayor', 'mayor.n.01'),
#   ('say', 'say.n.01'),
#   ('amicable', 'amicable.a.01'),
#   ('property_settlement', 'property_settlement.n.01'),
#   ('agreed_upon', 'agreed_upon.s.01')],
#  [('petition', 'request.n.01'),
#   ('list', 'list.n.01'),
#   ('mayor', 'mayor.n.01'),
#   ('occupation', 'occupation.n.01'),
#   ('attorney', 'lawyer.n.01'),
#   ('age', 'age.n.01')],
#  [('list', 'list.n.01'),
#   ('wife', 'wife.n.01'),
#   ('age', 'age.n.01'),
#   ('place_of_birth', 'birthplace.n.01'),
#   ('location', 'location.n.01')],
#  [('petition', 'request.n.01'),
#   ('say', 'say.n.01'),
#   ('couple', 'couple.n.01'),
#   ('not', 'not.r.01'),
#   ('live', 'populate.v.01'),
#   ('together', 'together.s.01'),
#   ('man_and_wife', 'marriage.n.02'),
#   ('more', 'more.n.01'),
#   ('year', 'year.n.01')],
#  [('person', 'person.n.01'),
#   ('home', 'home.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('location', 'location.n.01')],
#  [('person', 'person.n.01'),
#   ('list', 'list.n.01'),
#   ('petition', 'request.n.01'),
#   ('mayor', 'mayor.n.01'),
#   ('attorney', 'lawyer.n.01')],
#  [('person', 'person.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('mayor', 'mayor.n.01'),
#   ('Atlanta', 'atlanta.n.01'),
#   ('exception', 'exception.n.01'),
#   ('one', 'one.n.01'),
#   ('brief', 'brief.n.01'),
#   ('interlude', 'interlude.n.01')],
#  [('political', 'political.a.01'),
#   ('career', 'career.n.01'),
#   ('go_back', 'go_back.v.01'),
#   ('election', 'election.n.01'),
#   ('city_council', 'city_council.n.01')],
#  [('mayor', 'mayor.n.01'),
#   ('present', 'present.n.01'),
#   ('term_of_office', 'tenure.n.01'),
#   ('expire', 'run_out.v.04'),
#   ('Jan', 'january.n.01')],
#  [('succeed', 'succeed.v.01'),
#   ('person', 'person.n.01'),
#   ('become', 'become.v.01'),
#   ('candidate', 'campaigner.n.01'),
#   ('Sept', 'september.n.01'),
#   ('primary', 'primary.n.01'),
#   ('person', 'person.n.01'),
#   ('announce', 'announce.v.01'),
#   ('not', 'not.r.01'),
#   ('run', 'run.n.01'),
#   ('reelection', 'reelection.n.01')],
#  [('Georgia', 'georgia.n.01'),
#   ('Republican', 'republican.n.01'),
#   ('get', 'get.n.01'),
#   ('strong', 'strong.a.01'),
#   ('encouragement', 'encouragement.n.01'),
#   ('enter', 'enter.v.01'),
#   ('candidate', 'campaigner.n.01'),
#   ("governor's_race", "governor's_race.n.01"),
#   ('official', 'official.n.01'),
#   ('say', 'say.n.01'),
#   ('Wednesday', 'wednesday.n.01')],
#  [('person', 'person.n.01'),
#   ('state', 'state.n.01'),
#   ('GOP', 'republican_party.n.01'),
#   ('chairman', 'president.n.04'),
#   ('say', 'say.n.01'),
#   ('meeting', 'meeting.n.01'),
#   ('hold', 'clasp.n.02'),
#   ('Tuesday', 'tuesday.n.01'),
#   ('night', 'night.n.01'),
#   ('location', 'location.n.01'),
#   ('bring', 'bring.v.01'),
#   ('enthusiastic', 'enthusiastic.a.01'),
#   ('response', 'response.n.01'),
#   ('audience', 'audience.n.01')],
#  [('person', 'person.n.01'),
#   ('add', 'attention_deficit_disorder.n.01'),
#   ('enthusiasm', 'enthusiasm.n.01'),
#   ('pick_up', 'pick_up.v.01'),
#   ('state', 'state.n.01'),
#   ('rally', 'rally.n.01'),
#   ('hold', 'clasp.n.02'),
#   ('Sept', 'september.n.01'),
#   ('Savannah', 'savannah.n.01'),
#   ('newly', 'newly.r.01'),
#   ('elected', 'elect.v.01'),
#   ('Texas', 'texas.n.01'),
#   ('person', 'person.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('featured', 'have.v.02'),
#   ('speaker', 'speaker.n.01')],
#  [('location', 'location.n.01'),
#   ('meeting', 'meeting.n.01'),
#   ('audience', 'audience.n.01'),
#   ('warn', 'warn.v.01'),
#   ('enter', 'enter.v.01'),
#   ('candidate', 'campaigner.n.01'),
#   ('governor', 'governor.n.01'),
#   ('force', 'force.n.01'),
#   ('take', 'return.n.06'),
#   ('petition', 'request.n.01'),
#   ('voting_precinct', 'voting_precinct.n.01'),
#   ('obtain', 'obtain.v.01'),
#   ('signature', 'signature.n.01'),
#   ('register', 'register.n.01'),
#   ('voter', 'voter.n.01')],
#  [('warning', 'warning.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('unanimous', 'consentaneous.s.01'),
#   ('vote', 'vote.n.01'),
#   ('enter', 'enter.v.01'),
#   ('candidate', 'campaigner.n.01'),
#   ('Republican', 'republican.n.01'),
#   ('attend', 'attend.v.01')],
#  [('crowd', 'crowd.n.01'),
#   ('ask', 'ask.v.01'),
#   ('want', 'privation.n.01'),
#   ('wait', 'delay.n.01'),
#   ('one', 'one.n.01'),
#   ('term', 'term.n.01'),
#   ('make', 'brand.n.02'),
#   ('race', 'race.n.01'),
#   ('vote', 'vote.n.01'),
#   ('no', 'no.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('dissent', 'dissent.n.01')],
#  [('hurdle', 'hurdle.n.01'),
#   ('Republican', 'republican.n.01'),
#   ('face', 'face.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('state', 'state.n.01'),
#   ('law', 'law.n.01'),
#   ('say', 'say.n.01'),
#   ('make', 'brand.n.02'),
#   ('first', 'first.n.01'),
#   ('race', 'race.n.01'),
#   ('one', 'one.n.01'),
#   ('two', 'two.n.01'),
#   ('alternative', 'option.n.02'),
#   ('course', 'course.n.01'),
#   ('take', 'return.n.06')],
#  [('five', 'five.n.01'),
#   ('percent', 'percentage.n.01'),
#   ('voter', 'voter.n.01'),
#   ('county', 'county.n.01'),
#   ('sign', 'sign.n.01'),
#   ('petition', 'request.n.01'),
#   ('request', 'request.n.01'),
#   ('Republican', 'republican.n.01'),
#   ('allow', 'let.v.01'),
#   ('place', 'topographic_point.n.01'),
#   ('name', 'name.n.01'),
#   ('candidate', 'campaigner.n.01'),
#   ('general_election', 'general_election.n.01'),
#   ('ballot', 'ballot.n.01'),
#   ('Republican', 'republican.n.01'),
#   ('hold', 'clasp.n.02'),
#   ('primary', 'primary.n.01'),
#   ('county', 'county.n.01'),
#   ('unit', 'unit_of_measurement.n.01'),
#   ('system', 'system.n.01'),
#   ('system', 'system.n.01'),
#   ('party', 'party.n.01'),
#   ('oppose', 'oppose.v.01'),
#   ('platform', 'platform.n.01')],
#  [('person', 'person.n.01'),
#   ('group', 'group.n.01'),
#   ('public_relations', 'public_relations.n.01'),
#   ('director', 'director.n.01'),
#   ('resign', 'vacate.v.01'),
#   ('Tuesday', 'tuesday.n.01'),
#   ('work', 'work.n.01'),
#   ('person', 'person.n.01'),
#   ('campaign', 'political_campaign.n.01')],
#  [('person', 'person.n.01'),
#   ('resignation', 'resignation.n.01'),
#   ('expect', 'expect.v.01'),
#   ('time', 'time.n.01')],
#  [('succeed', 'succeed.v.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('assistant', 'assistant.n.01'),
#   ('more', 'more.n.01'),
#   ('three', 'three.n.01'),
#   ('year', 'year.n.01')],
#  [('gubernatorial', 'gubernatorial.a.01'),
#   ('campaign', 'political_campaign.n.01'),
#   ('start', 'start.n.01'),
#   ('person', 'person.n.01'),
#   ('expect', 'expect.v.01'),
#   ('become', 'become.v.01'),
#   ('campaign', 'political_campaign.n.01'),
#   ('coordinator', 'coordinator.n.01'),
#   ('person', 'person.n.01')],
#  [('group', 'group.n.01'),
#   ('session', 'session.n.01'),
#   ('Monday', 'monday.n.01'),
#   ('head', 'head.n.01'),
#   ('home', 'home.n.01'),
#   ('highway', 'highway.n.01'),
#   ('bond', 'chemical_bond.n.01'),
#   ('money', 'money.n.01'),
#   ('approve', 'approve.v.01'),
#   ('follow', 'follow.v.01'),
#   ('shortly', 'shortly.r.01')],
#  [('adjournment', 'adjournment.n.01'),
#   ('Monday', 'monday.n.01'),
#   ('afternoon', 'afternoon.n.01'),
#   ('senate', 'senate.n.01'),
#   ('expect', 'expect.v.01'),
#   ('approve', 'approve.v.01'),
#   ('study', 'survey.n.01'),
#   ('number', 'number.n.01'),
#   ('legislator', 'legislator.n.01'),
#   ('allot', 'assign.v.02'),
#   ('rural_area', 'country.n.04'),
#   ('urban_area', 'urban_area.n.01'),
#   ('determine', 'determine.v.01'),
#   ('adjustment', 'adjustment.n.01'),
#   ('make', 'brand.n.02')],
#  [('person', 'person.n.01'),
#   ('expect', 'expect.v.01'),
#   ('make', 'brand.n.02'),
#   ('traditional', 'traditional.a.01'),
#   ('visit', 'visit.n.01'),
#   ('chamber', 'chamber.n.01'),
#   ('work', 'work.n.01'),
#   ('adjournment', 'adjournment.n.01')],
#  [('person', 'person.n.01'),
#   ('likely', 'likely.a.01'),
#   ('mention', 'mention.n.01'),
#   ('100', 'hundred.n.01'),
#   ('million', 'million.n.01'),
#   ('highway', 'highway.n.01'),
#   ('bond', 'chemical_bond.n.01'),
#   ('issue', 'issue.n.01'),
#   ('approve', 'approve.v.01'),
#   ('session', 'session.n.01'),
#   ('first', 'first.n.01'),
#   ('priority', 'precedence.n.01'),
#   ('item', 'item.n.01')],
#  [('meanwhile', 'interim.n.01'),
#   ('learn', 'learn.v.01'),
#   ('group', 'group.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('very', 'very.s.01'),
#   ('near', 'approach.v.01'),
#   ('be', 'beryllium.n.01'),
#   ('ready', 'ready.n.01'),
#   ('issue', 'issue.n.01'),
#   ('first', 'first.n.01'),
#   ('30', 'thirty.n.01'),
#   ('million', 'million.n.01'),
#   ('worth', 'worth.n.01'),
#   ('highway', 'highway.n.01'),
#   ('reconstruction', 'reconstruction.n.01'),
#   ('bond', 'chemical_bond.n.01')],
#  [('bond', 'chemical_bond.n.01'),
#   ('issue', 'issue.n.01'),
#   ('go', 'go.n.01'),
#   ('state', 'state.n.01'),
#   ('court', 'court.n.01'),
#   ('friendly', 'friendly.n.01'),
#   ('test_suit', 'test_case.n.01'),
#   ('test', 'trial.n.02'),
#   ('validity', 'cogency.n.02'),
#   ('act', 'act.n.01'),
#   ('and_then', 'then.r.01'),
#   ('sale', 'sale.n.01'),
#   ('begin', 'begin.n.01'),
#   ('contract', 'contract.n.01'),
#   ('let', 'lashkar-e-taiba.n.01'),
#   ('repair', 'repair.n.01'),
#   ('work', 'work.n.01'),
#   ('Georgia', 'georgia.n.01'),
#   ('most', 'most.a.01'),
#   ('heavily', 'heavily.r.01'),
#   ('traveled', 'travel.v.01'),
#   ('highway', 'highway.n.01')],
#  [('group', 'group.n.01'),
#   ('source', 'beginning.n.04'),
#   ('say', 'say.n.01'),
#   ('also', 'besides.r.02'),
#   ('be', 'beryllium.n.01'),
#   ('plan', 'plan.n.01'),
#   ('there', 'there.n.01'),
#   ('issue', 'issue.n.01'),
#   ('some', 'some.a.01'),
#   ('3', 'three.n.01'),
#   ('million', 'million.n.01'),
#   ('4', 'four.n.01'),
#   ('million', 'million.n.01'),
#   ('worth', 'worth.n.01'),
#   ('group', 'group.n.01'),
#   ('bond', 'chemical_bond.n.01'),
#   ('rural', 'rural.a.01'),
#   ('road', 'road.n.01'),
#   ('construction', 'construction.n.01'),
#   ('work', 'work.n.01')],
#  [('department', 'department.n.01'),
#   ('apparently', 'apparently.r.01'),
#   ('intend', 'intend.v.01'),
#   ('make', 'brand.n.02'),
#   ('group', 'group.n.01'),
#   ('revolving_fund', 'revolving_fund.n.01'),
#   ('new', 'new.a.01'),
#   ('bond', 'chemical_bond.n.01'),
#   ('issue', 'issue.n.01'),
#   ('time', 'time.n.01'),
#   ('portion', 'part.n.01'),
#   ('old', 'old.n.01'),
#   ('pay_off', 'pay_off.v.01'),
#   ('tax', 'tax.n.01'),
#   ('authorities', 'government.n.01')],
#  [('person', 'person.n.01'),
#   ('open', 'open.n.01'),
#   ('race', 'race.n.01'),
#   ('governor', 'governor.n.01'),
#   ('battle', 'battle.n.01'),
#   ('legislature', 'legislature.n.01'),
#   ('issuance', 'issue.n.04'),
#   ('50', 'fifty.n.01'),
#   ('million', 'million.n.01'),
#   ('worth', 'worth.n.01'),
#   ('rural', 'rural.a.01'),
#   ('road', 'road.n.01'),
#   ('bond', 'chemical_bond.n.01'),
#   ('propose', 'propose.v.01'),
#   ('then', 'then.n.01'),
#   ('person', 'person.n.01')],
#  [('group', 'group.n.01'),
#   ('source', 'beginning.n.04'),
#   ('tell', 'tell.n.01'),
#   ('however', 'however.r.01'),
#   ('person', 'person.n.01'),
#   ('not', 'not.r.01'),
#   ('consult', 'consult.v.01'),
#   ('yet', 'yet.r.01'),
#   ('plan', 'plan.n.01'),
#   ('issue', 'issue.n.01'),
#   ('new', 'new.a.01'),
#   ('rural', 'rural.a.01'),
#   ('road', 'road.n.01'),
#   ('bond', 'chemical_bond.n.01')],
#  [('person', 'person.n.01'),
#   ('offer', 'offer.n.01'),
#   ('resolution', 'resolution.n.01'),
#   ('Monday', 'monday.n.01'),
#   ('group', 'group.n.01'),
#   ('rescind', 'revoke.v.02'),
#   ('body', 'body.n.01'),
#   ('action', 'action.n.01'),
#   ('Friday', 'friday.n.01'),
#   ('voting', 'vote.n.01'),
#   ('10', 'ten.n.01'),
#   ('day', 'day.n.01'),
#   ('increase', 'addition.n.03'),
#   ('expense', 'expense.n.01'),
#   ('allowance', 'allowance.n.01')],
#  [('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('Sunday', 'sunday.n.01'),
#   ('night', 'night.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('research', 'research.n.01'),
#   ('do', 'bash.n.02'),
#   ('quickie', 'band_aid.n.02'),
#   ('vote', 'vote.n.01'),
#   ('increase', 'addition.n.03'),
#   ('repeal', 'abrogation.n.01'),
#   ('outright', 'outright.s.01'),
#   ('notice', 'notice.n.01'),
#   ('first', 'first.n.01'),
#   ('give', 'give.n.01'),
#   ('reconsideration', 'reconsideration.n.01'),
#   ('action', 'action.n.01'),
#   ('seek', 'seek.n.01')],
#  [('emphasize', 'stress.v.01'),
#   ('technical', 'technical.n.01'),
#   ('detail', 'detail.n.01'),
#   ('not', 'not.r.01'),
#   ('fully', 'fully.r.01'),
#   ('work_out', 'work_out.v.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('resolution', 'resolution.n.01'),
#   ('seek', 'seek.n.01'),
#   ('set_aside', 'allow.v.04'),
#   ('privilege', 'privilege.n.01'),
#   ('resolution', 'resolution.n.01'),
#   ('group', 'group.n.01'),
#   ('vote', 'vote.n.01')],
#  [('similar', 'similar.a.01'),
#   ('resolution', 'resolution.n.01'),
#   ('pass', 'base_on_balls.n.01'),
#   ('senate', 'senate.n.01'),
#   ('vote', 'vote.n.01'),
#   ('29', 'twenty-nine.n.01'),
#   ('5', 'five.n.01')],
#  [('Sunday', 'sunday.n.01'),
#   ('night', 'night.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('word', 'word.n.01'),
#   ('resolution', 'resolution.n.01'),
#   ('offer', 'offer.n.01'),
#   ('there', 'there.n.01'),
#   ('rescind', 'revoke.v.02'),
#   ('action', 'action.n.01')],
#  [('person', 'person.n.01'),
#   ('point_out', 'comment.v.01'),
#   ('Georgia', 'georgia.n.01'),
#   ('voter', 'voter.n.01'),
#   ('last', 'stopping_point.n.01'),
#   ('November', 'november.n.01'),
#   ('reject', 'cull.n.01'),
#   ('amendment', 'amendment.n.01'),
#   ('allow', 'let.v.01'),
#   ('legislator', 'legislator.n.01'),
#   ('vote', 'vote.n.01'),
#   ('pay', 'wage.n.01'),
#   ('raise', 'raise.n.01'),
#   ('future', 'future.n.01'),
#   ('legislature', 'legislature.n.01'),
#   ('session', 'session.n.01')],
#  [('veteran', 'veteran.n.01'),
#   ('location', 'location.n.01'),
#   ('legislator', 'legislator.n.01'),
#   ('ask', 'ask.v.01'),
#   ('group', 'group.n.01'),
#   ('Monday', 'monday.n.01'),
#   ('back', 'back.n.01'),
#   ('federal', 'federal.n.01'),
#   ('aid', 'aid.n.01'),
#   ('education', 'education.n.01'),
#   ('consistently', 'systematically.r.01'),
#   ('oppose', 'oppose.v.01'),
#   ('past', 'past.n.01')],
#  [('person', 'person.n.01'),
#   ('group', 'group.n.01'),
#   ('ask', 'ask.v.01'),
#   ('group', 'group.n.01'),
#   ('privilege', 'privilege.n.01'),
#   ('resolution', 'resolution.n.01'),
#   ('endorse', 'back.v.01'),
#   ('increased', 'increase.v.01'),
#   ('federal', 'federal.n.01'),
#   ('support', 'support.n.01'),
#   ('public', 'populace.n.01'),
#   ('education', 'education.n.01'),
#   ('fund', 'fund.n.01'),
#   ('receive', 'receive.v.01'),
#   ('expend', 'use.v.03'),
#   ('state', 'state.n.01'),
#   ('funds', 'funds.n.01')],
#  [('person', 'person.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('13th', 'thirteenth.s.01'),
#   ('year', 'year.n.01'),
#   ('legislator', 'legislator.n.01'),
#   ('say', 'say.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('some', 'some.a.01'),
#   ('member', 'member.n.01'),
#   ('congressional', 'congressional.a.01'),
#   ('delegation', 'deputation.n.01'),
#   ('Washington', 'washington.n.01'),
#   ('see', 'see.n.01'),
#   ('resolution', 'resolution.n.01'),
#   ('pass', 'base_on_balls.n.01')],
#  [('add', 'attention_deficit_disorder.n.01'),
#   ('Georgia', 'georgia.n.01'),
#   ('congressman', 'congressman.n.01'),
#   ('specifically', 'specifically.r.01'),
#   ('ask', 'ask.v.01'),
#   ('offer', 'offer.n.01'),
#   ('resolution', 'resolution.n.01')],
#  [('resolution', 'resolution.n.01'),
#   ('person', 'person.n.01'),
#   ('toss', 'flip.n.04'),
#   ('group', 'group.n.01'),
#   ('hopper', 'hopper.n.01'),
#   ('Friday', 'friday.n.01'),
#   ('formally', 'formally.r.01'),
#   ('read', 'read.n.01'),
#   ('Monday', 'monday.n.01')],
#  [('say', 'say.n.01'),
#   ('event', 'event.n.01'),
#   ('group', 'group.n.01'),
#   ('provide', 'supply.v.01'),
#   ('increase', 'addition.n.03'),
#   ('federal', 'federal.n.01'),
#   ('fund', 'fund.n.01'),
#   ('group', 'group.n.01'),
#   ('direct', 'direct.v.01'),
#   ('give', 'give.n.01'),
#   ('priority', 'precedence.n.01'),
#   ('teacher', 'teacher.n.01'),
#   ('pay', 'wage.n.01'),
#   ('raise', 'raise.n.01')],
#  [('long', 'hanker.v.01'),
#   ('hot', 'hot.a.01'),
#   ('controversy', 'controversy.n.01'),
#   ('location', 'location.n.01'),
#   ('have', 'rich_person.n.01'),
#   ('new', 'new.a.01'),
#   ('school_superintendent', 'school_superintendent.n.01'),
#   ('elect', 'chosen.n.03'),
#   ('policeman', 'policeman.n.01'),
#   ('put', 'put_option.n.02'),
#   ('election', 'election.n.01'),
#   ('ever', 'ever.r.01'),
#   ('see', 'see.n.01'),
#   ('county', 'county.n.01')],
#  [('new', 'new.a.01'),
#   ('school_superintendent', 'school_superintendent.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('person', 'person.n.01'),
#   ('veteran', 'veteran.n.01'),
#   ('agriculture', 'agribusiness.n.01'),
#   ('teacher', 'teacher.n.01'),
#   ('defeat', 'defeat.n.01'),
#   ('person', 'person.n.01'),
#   ('school_principal', 'principal.n.02'),
#   ('chairman', 'president.n.04'),
#   ('group', 'group.n.01')],
#  [('person', 'person.n.01'),
#   ('receive', 'receive.v.01'),
#   ('vote', 'vote.n.01'),
#   ('Saturday', 'saturday.n.01'),
#   ('election', 'election.n.01'),
#   ('person', 'person.n.01'),
#   ('get', 'get.n.01')],
#  [('ordinary', 'ordinary.n.01'),
#   ('person', 'person.n.01'),
#   ('arm', 'arm.n.01'),
#   ('pistol', 'pistol.n.01'),
#   ('stand_by', 'stand_by.v.01'),
#   ('polls', 'polls.n.01'),
#   ('insure', 'see.v.10'),
#   ('order', 'order.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('election', 'election.n.01'),
#   ('ever', 'ever.r.01'),
#   ('see', 'see.n.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('polls', 'polls.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('just', 'just.a.01'),
#   ('be', 'beryllium.n.01'),
#   ('church', 'church.n.01')],
#  [('smell', 'smell.n.01'),
#   ('drop', 'drop.n.01'),
#   ('liquor', 'liquor.n.01'),
#   ('have', 'rich_person.n.01'),
#   ('trouble', 'trouble.n.01')],
#  [('campaign', 'political_campaign.n.01'),
#   ('lead_up', 'lead_up.v.01'),
#   ('election', 'election.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('not', 'not.r.01'),
#   ('so', 'sol.n.03'),
#   ('quiet', 'lull.n.02'),
#   ('however', 'however.r.01')],
#  [('mark', 'mark.n.01'),
#   ('controversy', 'controversy.n.01'),
#   ('anonymous', 'anonymous.a.01'),
#   ('midnight', 'midnight.n.01'),
#   ('phone_call', 'call.n.01'),
#   ('veiled', 'veil.v.01'),
#   ('threat', 'menace.n.01'),
#   ('violence', 'violence.n.01')],
#  [('former', 'former.n.01'),
#   ('county', 'county.n.01'),
#   ('school_superintendent', 'school_superintendent.n.01'),
#   ('person', 'person.n.01'),
#   ('shoot', 'shoot.n.01'),
#   ('death', 'death.n.01'),
#   ('March', 'march.n.01'),
#   ('four', 'four.n.01'),
#   ('day', 'day.n.01'),
#   ('resign', 'vacate.v.01'),
#   ('post', 'post.n.01'),
#   ('dispute', 'dispute.n.01'),
#   ('county', 'county.n.01'),
#   ('school_board', 'school_board.n.01')],
#  [('election', 'election.n.01'),
#   ('campaign', 'political_campaign.n.01'),
#   ('candidate', 'campaigner.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('reportedly', 'reportedly.r.01'),
#   ('receive', 'receive.v.01'),
#   ('anonymous', 'anonymous.a.01'),
#   ('telephone_call', 'call.n.01')],
#  [('ordinary', 'ordinary.n.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('too', 'excessively.r.01'),
#   ('subject', 'subject.n.01'),
#   ('anonymous', 'anonymous.a.01'),
#   ('call', 'call.n.01'),
#   ('soon', 'soon.r.01'),
#   ('schedule', 'agenda.n.01'),
#   ('election', 'election.n.01')],
#  [('many', 'many.a.01'),
#   ('citizen', 'citizen.n.01'),
#   ('fear', 'fear.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('irregularity', 'abnormality.n.04'),
#   ('polls', 'polls.n.01'),
#   ('person', 'person.n.01'),
#   ('get', 'get.n.01'),
#   ('permit', 'license.n.01'),
#   ('carry', 'carry.n.01'),
#   ('gun', 'gun.n.01'),
#   ('promise', 'promise.n.01'),
#   ('orderly', 'orderly.n.01'),
#   ('election', 'election.n.01')],
#  [('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('ordinary', 'ordinary.n.01'),
#   ('apparently', 'apparently.r.01'),
#   ('make_good', 'make_good.v.01'),
#   ('promise', 'promise.n.01')],
#  [('go', 'go.n.01'),
#   ('real', 'real_number.n.01'),
#   ('smooth', 'smooth.n.01'),
#   ('sheriff', 'sheriff.n.01'),
#   ('say', 'say.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('a_bit', 'a_bit.r.01'),
#   ('trouble', 'trouble.n.01')],
#  [('committee', 'committee.n.01'),
#   ('approval', 'blessing.n.01'),
#   ('person', 'person.n.01'),
#   ('abandoned', 'abandon.v.01'),
#   ('property', 'property.n.01'),
#   ('act', 'act.n.01'),
#   ('seem', 'look.v.02'),
#   ('certain', 'certain.s.01'),
#   ('Thursday', 'thursday.n.01'),
#   ('adamant', 'diamond.n.02'),
#   ('protest', 'protest.n.01'),
#   ('Texas', 'texas.n.01'),
#   ('banker', 'banker.n.01')],
#  [('person', 'person.n.01'),
#   ('personally', 'personally.r.01'),
#   ('lead', 'lead.n.01'),
#   ('fight', 'battle.n.01'),
#   ('measure', 'measure.n.01'),
#   ('water_down', 'water_down.v.01'),
#   ('considerably', 'well.r.07'),
#   ('rejection', 'rejection.n.01'),
#   ('two', 'two.n.01'),
#   ('previous', 'previous.s.01'),
#   ('legislature', 'legislature.n.01'),
#   ('public', 'populace.n.01'),
#   ('hearing', 'hearing.n.01'),
#   ('group', 'group.n.01')],
#  [('committee', 'committee.n.01'),
#   ('rule', 'rule.n.01'),
#   ('go', 'go.n.01'),
#   ('automatically', 'automatically.r.01'),
#   ('subcommittee', 'subcommittee.n.01'),
#   ('one', 'one.n.01'),
#   ('week', 'week.n.01')],
#  [('question', 'question.n.01'),
#   ('committee_member', 'committee_member.n.01'),
#   ('taunt', 'twit.n.02'),
#   ('banker', 'banker.n.01'),
#   ('appear', 'look.v.02'),
#   ('witness', 'witness.n.01'),
#   ('leave', 'leave.n.01'),
#   ('little', 'little.n.01'),
#   ('doubt', 'doubt.n.01'),
#   ('recommend', 'recommend.v.01'),
#   ('passage', 'passage.n.01')],
#  [('person', 'person.n.01'),
#   ('term', 'term.n.01'),
#   ('extremely', 'highly.r.01'),
#   ('conservative', 'conservative.n.01'),
#   ('estimate', 'estimate.n.01'),
#   ('produce', 'produce.n.01'),
#   ('17', 'seventeen.n.01'),
#   ('million', 'million.n.01'),
#   ('dollar', 'dollar.n.01'),
#   ('help', 'aid.n.02'),
#   ('erase', 'erase.v.01'),
#   ('anticipated', 'expect.v.01'),
#   ('deficit', 'deficit.n.01'),
#   ('million', 'million.n.01'),
#   ('dollar', 'dollar.n.01'),
#   ('end', 'end.n.01'),
#   ('current', 'current.n.01'),
#   ('fiscal_year', 'fiscal_year.n.01'),
#   ('next', 'following.s.02'),
#   ('Aug', 'august.n.01')],
#  [('tell', 'tell.n.01'),
#   ('committee', 'committee.n.01'),
#   ('measure', 'measure.n.01'),
#   ('merely', 'merely.r.01'),
#   ('provide', 'supply.v.01'),
#   ('means', 'means.n.01'),
#   ('enforce', 'enforce.v.01'),
#   ('escheat', 'escheat.n.01'),
#   ('law', 'law.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('Texas', 'texas.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('republic', 'democracy.n.02')],
#  [('permit', 'license.n.01'),
#   ('state', 'state.n.01'),
#   ('take_over', 'assume.v.06'),
#   ('bank_account', 'bank_account.n.01'),
#   ('stock', 'stock.n.01'),
#   ('other', 'other.a.01'),
#   ('personal_property', 'personal_property.n.01'),
#   ('person', 'person.n.01'),
#   ('miss', 'girl.n.01'),
#   ('seven', 'seven.n.01'),
#   ('year', 'year.n.01'),
#   ('more', 'more.n.01')],
#  [('bill', 'bill.n.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('draft', 'draft.n.01'),
#   ('personally', 'personally.r.01'),
#   ('force', 'force.n.01'),
#   ('bank', 'bank.n.01'),
#   ('insurance_firm', 'insurance_company.n.01'),
#   ('pipeline_company', 'pipeline_company.n.01'),
#   ('other', 'other.a.01'),
#   ('corporation', 'corporation.n.01'),
#   ('report', 'report.n.01'),
#   ('property', 'property.n.01'),
#   ('state_treasurer', 'state_treasurer.n.01')],
#  [('escheat', 'escheat.n.01'),
#   ('law', 'law.n.01'),
#   ('enforce', 'enforce.v.01'),
#   ('now', 'now.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('almost', 'about.r.07'),
#   ('impossible', 'impossible.n.01'),
#   ('locate', 'locate.v.01'),
#   ('property', 'property.n.01'),
#   ('person', 'person.n.01'),
#   ('declare', 'declare.v.01')],
#  [('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('lawyer', 'lawyer.n.01'),
#   ('represent', 'represent.v.01'),
#   ('group', 'group.n.01'),
#   ('sound', 'sound.n.01'),
#   ('opposition', 'resistance.n.01'),
#   ('keynote', 'keynote.n.01'),
#   ('say', 'say.n.01'),
#   ('force', 'force.n.01'),
#   ('bank', 'bank.n.01'),
#   ('violate', 'violate.v.01'),
#   ('contractual', 'contractual.a.01'),
#   ('obligation', 'duty.n.01'),
#   ('depositor', 'depositor.n.01'),
#   ('undermine', 'sabotage.v.01'),
#   ('confidence', 'assurance.n.01'),
#   ('bank', 'bank.n.01'),
#   ('customer', 'customer.n.01')],
#  [('destroy', 'destroy.v.01'),
#   ('confidence', 'assurance.n.01'),
#   ('bank', 'bank.n.01'),
#   ('do', 'bash.n.02'),
#   ('economy', 'economy.n.01'),
#   ('say', 'say.n.01')],
#  [('take', 'return.n.06'),
#   ('circulation', 'circulation.n.01'),
#   ('many', 'many.a.01'),
#   ('million', 'million.n.01'),
#   ('dollar', 'dollar.n.01')],
#  [('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('sponsor', 'patron.n.03'),
#   ('bill', 'bill.n.01'),
#   ('say', 'say.n.01'),
#   ('failure', 'failure.n.01'),
#   ('enact', 'ordain.v.01'),
#   ('amount', 'sum.n.01'),
#   ('make', 'brand.n.02'),
#   ('gift', 'gift.n.01'),
#   ('taxpayer', 'taxpayer.n.01'),
#   ('pocket', 'pocket.n.01'),
#   ('bank', 'bank.n.01'),
#   ('insurance_company', 'insurance_company.n.01'),
#   ('pipeline_company', 'pipeline_company.n.01')],
#  [('contention', 'contention.n.01'),
#   ('deny', 'deny.v.01'),
#   ('banker', 'banker.n.01'),
#   ('include', 'include.v.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('person', 'person.n.01'),
#   ('Houston', 'houston.n.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('person', 'person.n.01'),
#   ('Austin', 'austin.n.01')],
#  [('person', 'person.n.01'),
#   ('argue', 'argue.v.01'),
#   ('bill', 'bill.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('probably', 'probably.r.01'),
#   ('unconstitutional', 'unconstitutional.a.01'),
#   ('say', 'say.n.01'),
#   ('impair', 'impair.v.01'),
#   ('contract', 'contract.n.01')],
#  [('also', 'besides.r.02'),
#   ('complain', 'complain.v.01'),
#   ('not', 'not.r.01'),
#   ('enough', 'enough.n.01'),
#   ('notice', 'notice.n.01'),
#   ('give', 'give.n.01'),
#   ('hearing', 'hearing.n.01'),
#   ('bill', 'bill.n.01'),
#   ('introduce', 'introduce.v.01'),
#   ('only', 'lone.s.03'),
#   ('last', 'stopping_point.n.01'),
#   ('Monday', 'monday.n.01')],
#  [('senator', 'senator.n.01'),
#   ('unanimously', 'unanimously.r.01'),
#   ('approve', 'approve.v.01'),
#   ('Thursday', 'thursday.n.01'),
#   ('bill', 'bill.n.01'),
#   ('person', 'person.n.01'),
#   ('Dallas', 'dallas.n.01'),
#   ('authorize', 'authorize.v.01'),
#   ('establishment', 'constitution.n.02'),
#   ('day_school', 'day_school.n.01'),
#   ('deaf', 'deaf.n.01'),
#   ('Dallas', 'dallas.n.01'),
#   ('four', 'four.n.01'),
#   ('other', 'other.a.01'),
#   ('county', 'county.n.01')],
#  [('bill', 'bill.n.01'),
#   ('design', 'design.n.01'),
#   ('provide', 'supply.v.01'),
#   ('special', 'special.n.01'),
#   ('schooling', 'schooling.n.01'),
#   ('more', 'more.n.01'),
#   ('deaf', 'deaf.n.01'),
#   ('student', 'student.n.01'),
#   ('scholastic', 'pedant.n.01'),
#   ('age', 'age.n.01'),
#   ('reduced', 'reduce.v.01'),
#   ('cost', 'cost.n.01'),
#   ('state', 'state.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('no', 'no.n.01'),
#   ('debate', 'argument.n.03'),
#   ('senate', 'senate.n.01'),
#   ('pass_on', 'pass.v.05'),
#   ('bill', 'bill.n.01'),
#   ('group', 'group.n.01')],
#  [('authorize', 'authorize.v.01'),
#   ('group', 'group.n.01'),
#   ('establish', 'establish.v.01'),
#   ('day_school', 'day_school.n.01'),
#   ('deaf', 'deaf.n.01'),
#   ('county', 'county.n.01'),
#   ('more', 'more.n.01'),
#   ('population', 'population.n.01'),
#   ('require', 'necessitate.v.01'),
#   ('deaf', 'deaf.n.01'),
#   ('child', 'child.n.01'),
#   ('6', 'six.n.01'),
#   ('13', 'thirteen.n.01'),
#   ('year', 'year.n.01'),
#   ('of_age', 'aged.s.03'),
#   ('attend', 'attend.v.01'),
#   ('day_school', 'day_school.n.01'),
#   ('permit', 'license.n.01'),
#   ('attend', 'attend.v.01'),
#   ('residential', 'residential.a.01'),
#   ('location', 'location.n.01'),
#   ('here', 'here.n.01')],
#  [('operating_budget', 'operating_budget.n.01'),
#   ('day_school', 'day_school.n.01'),
#   ('five', 'five.n.01'),
#   ('county', 'county.n.01'),
#   ('Dallas', 'dallas.n.01'),
#   ('location', 'location.n.01'),
#   ('location', 'location.n.01'),
#   ('location', 'location.n.01'),
#   ('location', 'location.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('saving', 'economy.n.04'),
#   ('first', 'first.n.01'),
#   ('year', 'year.n.01'),
#   ('capital', 'capital.n.01'),
#   ('outlay', 'spending.n.01'),
#   ('absorb', 'absorb.v.01'),
#   ('person', 'person.n.01'),
#   ('tell', 'tell.n.01'),
#   ('senate', 'senate.n.01')],
#  [('group', 'group.n.01'),
#   ('estimate', 'estimate.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('scholastic', 'pedant.n.01'),
#   ('attend', 'attend.v.01'),
#   ('day_school', 'day_school.n.01'),
#   ('location', 'location.n.01'),
#   ('saving', 'economy.n.04'),
#   ('come', 'semen.n.01'),
#   ('Austin', 'austin.n.01'),
#   ('live', 'populate.v.01'),
#   ('state', 'state.n.01'),
#   ('deaf', 'deaf.n.01'),
#   ('school', 'school.n.01')],
#  [('Dallas', 'dallas.n.01'),
#   ('hear', 'hear.v.01'),
#   ('debate', 'argument.n.03'),
#   ('horse_race', 'horse_race.n.01'),
#   ('parimutuel', 'parimutuel.n.01'),
#   ('soon', 'soon.r.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01')],
#  [('details', 'details.n.01'),
#   ('still', 'still.n.01'),
#   ('work_out', 'work_out.v.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('expect', 'expect.v.01'),
#   ('tell', 'tell.n.01'),
#   ('Dallas', 'dallas.n.01'),
#   ('think', 'think.n.01'),
#   ('person', 'person.n.01'),
#   ('amendment', 'amendment.n.01'),
#   ('reject', 'cull.n.01')],
#  [('get', 'get.n.01'),
#   ('more', 'more.n.01'),
#   ('pro', 'professional.n.02'),
#   ('letter', 'letter.n.01'),
#   ('con', 'con.n.01'),
#   ('horse_race', 'horse_race.n.01'),
#   ('bet', 'stake.n.04'),
#   ('say', 'say.n.01'),
#   ('person', 'person.n.01')],
#  [('believe', 'believe.v.01'),
#   ('people', 'people.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('better', 'better.n.01'),
#   ('inform', 'inform.v.01'),
#   ('question', 'question.n.01'),
#   ('oppose', 'oppose.v.01'),
#   ('also', 'besides.r.02')],
#  [('willing', 'volition.n.02'),
#   ('stake', 'interest.n.05'),
#   ('political', 'political.a.01'),
#   ('career', 'career.n.01'),
#   ('on_it', 'thereon.r.01')],
#  [('person', 'person.n.01'),
#   ('ex-gambler', 'ex-gambler.n.01'),
#   ('location', 'location.n.01'),
#   ('elect', 'chosen.n.03'),
#   ('advocacy', 'advocacy.n.01'),
#   ('bet_on', 'bet_on.v.01'),
#   ('pony', 'pony.n.01')],
#  [('group', 'group.n.01'),
#   ('committee', 'committee.n.01'),
#   ('hear', 'hear.v.01'),
#   ('local_option', 'local_option.n.01'),
#   ('proposal', 'proposal.n.01'),
#   ('expect', 'expect.v.01'),
#   ('give', 'give.n.01'),
#   ('favorable', 'favorable.a.01'),
#   ('report', 'report.n.01'),
#   ('resolution', 'resolution.n.01'),
#   ('face', 'face.n.01'),
#   ('later', 'later.s.01')],
#  [('group', 'group.n.01'),
#   ('pass', 'base_on_balls.n.01'),
#   ('finally', 'finally.r.01'),
#   ('send', 'send.v.01'),
#   ('senate', 'senate.n.01'),
#   ('bill', 'bill.n.01'),
#   ('extend', 'widen.v.04'),
#   ('group', 'group.n.01'),
#   ('authority', 'authority.n.01'),
#   ('give', 'give.n.01'),
#   ('planning', 'planning.n.01'),
#   ('assistance', 'aid.n.02'),
#   ('city', 'city.n.01')],
#  [('group', 'group.n.01'),
#   ('quickly', 'quickly.r.01'),
#   ('whip_through', 'whip_through.v.01'),
#   ('meager', 'meager.a.01'),
#   ('fare', 'menu.n.04'),
#   ('group', 'group.n.01'),
#   ('bill', 'bill.n.01'),
#   ('approve', 'approve.v.01'),
#   ('committee', 'committee.n.01'),
#   ('pass', 'base_on_balls.n.01'),
#   ('three', 'three.n.01'),
#   ('calendar', 'calendar.n.01')],
#  [('one', 'one.n.01'),
#   ('validate', 'validate.v.01'),
#   ('act', 'act.n.01'),
#   ('school', 'school.n.01'),
#   ('district', 'district.n.01')],
#  [('authority', 'authority.n.01'), ('group', 'group.n.01')],
#  [('third', 'one-third.n.01'),
#   ('amend', 'amend.v.01'),
#   ('enabling_act', 'enabling_act.n.01'),
#   ('creation', 'creation.n.01'),
#   ('location', 'location.n.01'),
#   ('location', 'location.n.01'),
#   ('special', 'special.n.01'),
#   ('amendment', 'amendment.n.01'),
#   ('previously', 'previously.r.01'),
#   ('adopt', 'adopt.v.01')],
#  [('dissent', 'dissent.n.01'),
#   ('senator', 'senator.n.01'),
#   ('pass', 'base_on_balls.n.01'),
#   ('bill', 'bill.n.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('authorize', 'authorize.v.01'),
#   ('establishment', 'constitution.n.02'),
#   ('future', 'future.n.01'),
#   ('school', 'school.n.01'),
#   ('mentally_retarded', 'mentally_retarded.n.01'),
#   ('location', 'location.n.01'),
#   ('district', 'district.n.01')],
#  [('money', 'money.n.01'),
#   ('construction', 'construction.n.01'),
#   ('seek', 'seek.n.01'),
#   ('later_on', 'subsequently.r.01'),
#   ('in_the_meantime', 'meanwhile.r.02'),
#   ('location', 'location.n.01'),
#   ('board', 'board.n.01'),
#   ('accept', 'accept.v.01'),
#   ('gift', 'gift.n.01'),
#   ('donation', 'contribution.n.02'),
#   ('site', 'site.n.01')],
#  [('two', 'two.n.01'),
#   ('tax', 'tax.n.01'),
#   ('revision', 'revision.n.01'),
#   ('bill', 'bill.n.01'),
#   ('pass', 'base_on_balls.n.01')],
#  [('one', 'one.n.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('aid', 'aid.n.01'),
#   ('retailer', 'retailer.n.01'),
#   ('pay', 'wage.n.01'),
#   ('group', 'group.n.01'),
#   ('excise_tax', 'excise.n.01'),
#   ('eliminate', 'extinguish.v.04'),
#   ('requirement', 'requirement.n.01'),
#   ('return', 'tax_return.n.01'),
#   ('notarize', 'notarize.v.01')],
#  [('instead', 'alternatively.r.01'),
#   ('retailer', 'retailer.n.01'),
#   ('sign', 'sign.n.01'),
#   ('certificate', 'certificate.n.01'),
#   ('correctness', 'correctness.n.01'),
#   ('violation', 'misdemeanor.n.01'),
#   ('carry', 'carry.n.01'),
#   ('penalty', 'punishment.n.01'),
#   ('one', 'one.n.01'),
#   ('five', 'five.n.01'),
#   ('year', 'year.n.01'),
#   ('prison', 'prison.n.01'),
#   ('1000', 'thousand.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('series', 'series.n.01'),
#   ('recommendation', 'recommendation.n.01'),
#   ('group', 'group.n.01')],
#  [('other', 'other.a.01'),
#   ('bill', 'bill.n.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('relieve', 'relieve.v.01'),
#   ('real_estate_broker', 'real_estate_broker.n.01'),
#   ('pay', 'wage.n.01'),
#   ('own', 'own.v.01'),
#   ('licensing_fee', 'licensing_fee.n.01'),
#   ('12', 'twelve.n.01'),
#   ('occupation_license', 'occupation_license.n.01'),
#   ('broker', 'agent.n.04'),
#   ('stock', 'stock.n.01'),
#   ('bond', 'chemical_bond.n.01')],
#  [('natural_gas', 'natural_gas.n.01'),
#   ('public_utility', 'utility.n.01'),
#   ('company', 'company.n.01'),
#   ('give', 'give.n.01'),
#   ('right', 'right.n.01'),
#   ('eminent_domain', 'eminent_domain.n.01'),
#   ('bill', 'bill.n.01'),
#   ('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('acquire', 'get.v.01'),
#   ('site', 'site.n.01'),
#   ('underground', 'underground.n.01'),
#   ('storage', 'storage.n.01'),
#   ('reservoir', 'reservoir.n.01'),
#   ('gas', 'gas.n.01')],
#  [('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('former', 'former.n.01'),
#   ('chairman', 'president.n.04'),
#   ('group', 'group.n.01'),
#   ('suggest', 'propose.v.01'),
#   ('plan', 'plan.n.01'),
#   ('fill', 'fill.n.01'),
#   ('appointment', 'appointment.n.01'),
#   ('future', 'future.n.01'),
#   ('vacancy', 'vacancy.n.01'),
#   ('group', 'group.n.01'),
#   ('group', 'group.n.01'),
#   ('eliminate', 'extinguish.v.04'),
#   ('need', 'need.n.01'),
#   ('costly', 'dearly-won.s.01'),
#   ('special', 'special.n.01'),
#   ('election', 'election.n.01')],
#  [('person', 'person.n.01'),
#   ('plan', 'plan.n.01'),
#   ('appointee', 'appointee.n.01'),
#   ('select', 'choose.v.01'),
#   ('board', 'board.n.01'),
#   ('compose', 'compose.v.01'),
#   ('governor', 'governor.n.01'),
#   ('lieutenant_governor', 'lieutenant_governor.n.01'),
#   ('Speaker', 'speaker.n.01'),
#   ('house', 'house.n.01'),
#   ('attorney_general', 'attorney_general.n.01'),
#   ('chief_justice', 'chief_justice.n.01'),
#   ('group', 'group.n.01')],
#  [('state', 'state.n.01'),
#   ('representative', 'representative.n.01'),
#   ('decide', 'decide.v.01'),
#   ('Thursday', 'thursday.n.01'),
#   ('kind', 'kind.n.01'),
#   ('tax', 'tax.n.01'),
#   ('Texan', 'texan.n.01'),
#   ('prefer', 'prefer.v.01'),
#   ('pay', 'wage.n.01')],
#  [('adverse', 'adverse.s.01'),
#   ('vote', 'vote.n.01'),
#   ('keep', 'support.n.06'),
#   ('group', 'group.n.01'),
#   ('bill', 'bill.n.01'),
#   ('order', 'order.n.01'),
#   ('referendum', 'referendum.n.01'),
#   ('April', 'april.n.01'),
#   ('4', 'four.n.01'),
#   ('ballot', 'ballot.n.01'),
#   ('Texas', 'texas.n.01'),
#   ('vote', 'vote.n.01'),
#   ('U.S.', 'united_states_government.n.01'),
#   ('senator', 'senator.n.01')],
#  [('person', 'person.n.01'),
#   ('location', 'location.n.01'),
#   ('sponsor', 'patron.n.03'),
#   ('poll', 'poll.n.01'),
#   ('idea', 'idea.n.01'),
#   ('say', 'say.n.01'),
#   ('delay', 'delay.n.01'),
#   ('committee', 'committee.n.01'),
#   ('kill', 'killing.n.02'),
#   ('bill', 'bill.n.01')],
#  [('person', 'person.n.01'),
#   ('report', 'report.n.01'),
#   ('finally', 'finally.r.01'),
#   ('person', 'person.n.01'),
#   ('committee', 'committee.n.01'),
#   ('set', 'set.n.01'),
#   ('public', 'populace.n.01'),
#   ('hearing', 'hearing.n.01'),
#   ('Feb', 'february.n.01'),
#   ('22', 'twenty-two.n.01')],
#  [('proposal', 'proposal.n.01'),
#   ('receive', 'receive.v.01'),
#   ('final', 'final.n.01'),
#   ('legislative', 'legislative.a.01'),
#   ('approval', 'blessing.n.01'),
#   ('two-thirds', 'two-thirds.n.01'),
#   ('majority', 'majority.n.01'),
#   ('March', 'march.n.01'),
#   ('1', 'one.n.01'),
#   ('print', 'print.n.01'),
#   ('April', 'april.n.01'),
#   ('4', 'four.n.01'),
#   ('ballot', 'ballot.n.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01')],
#  [('opponent', 'opposition.n.04'),
#   ('generally', 'by_and_large.r.01'),
#   ('argue', 'argue.v.01'),
#   ('ballot', 'ballot.n.01'),
#   ('give', 'give.n.01'),
#   ('enough', 'enough.n.01'),
#   ('information', 'information.n.01'),
#   ('tax', 'tax.n.01'),
#   ('proposal', 'proposal.n.01'),
#   ('voter', 'voter.n.01'),
#   ('make', 'brand.n.02'),
#   ('intelligent', 'intelligent.a.01'),
#   ('choice', 'choice.n.01')],
#  [('Dallas', 'dallas.n.01'),
#   ('member', 'member.n.01'),
#   ('vote', 'vote.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('absent', 'absent.v.01')],
# ...
#   ('tie', 'necktie.n.01'),
#   ('score', 'mark.n.01'),
#   ('person', 'person.n.01'),
#   ('first', 'first.n.01'),
#   ('major_league', 'major_league.n.01'),
#   ('home_run', 'homer.n.01'),
#   ('fifth', 'fifth.n.01'),
#   ('put', 'put_option.n.02'),
#   ('group', 'group.n.01'),
#   ('back', 'back.n.01'),
#   ('in_front', 'ahead.r.01')],
#  [('double', 'double.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('run', 'run.n.01'),
#   ('score', 'mark.n.01'),
#   ('two-baser', 'double.n.01'),
#   ('infield', 'baseball_diamond.n.01'),
#   ('single', 'single.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('solid', 'solid.n.01'),
#   ('single', 'single.n.01'),
#   ('center', 'center.n.01'),
#   ('put', 'put_option.n.02'),
#   ('group', 'group.n.01'),
#   ('back', 'back.n.01'),
#   ('in_front', 'ahead.r.01'),
#   ('last', 'stopping_point.n.01'),
#   ('fifth', 'fifth.n.01')],
#  [('group', 'group.n.01'),
#   ('outfielder', 'outfielder.n.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('Monday', 'monday.n.01'),
#   ('night', 'night.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('play', 'play.n.01'),
#   ('baseball', 'baseball.n.01')],
#  [('tell', 'tell.n.01'), ('newsman', 'reporter.n.01')],
#  [('know', 'know.n.01'),
#   ('reflex', 'reflex.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('gone', 'travel.v.01'),
#   ('not', 'not.r.01'),
#   ('be', 'beryllium.n.01'),
#   ('25th', 'twenty-fifth.s.01'),
#   ('man', 'man.n.01'),
#   ('ball_club', 'baseball_club.n.01')],
#  [('first', 'first.n.01'),
#   ('word', 'word.n.01'),
#   ('person', 'person.n.01'),
#   ('sudden', 'sudden.a.01'),
#   ('walkout', 'walkout.n.01')],
#  [('person', 'person.n.01'),
#   ('get', 'get.n.01'),
#   ('only', 'lone.s.03'),
#   ('six', 'six.n.01'),
#   ('hit', 'hit.n.01'),
#   ('at-bat', 'bat.n.02'),
#   ('batting', 'batting.n.01'),
#   ('average', 'average.n.01'),
#   ('first', 'first.n.01'),
#   ('12', 'twelve.n.01'),
#   ('game', 'game.n.01')],
#  [('take', 'return.n.06'),
#   ('midnight', 'midnight.n.01'),
#   ('train', 'train.n.01'),
#   ('Cleveland', 'cleveland.n.01'),
#   ('Saturday', 'saturday.n.01'),
#   ('official', 'official.n.01'),
#   ('word', 'word.n.01'),
#   ('stay', 'stay.n.01'),
#   ('away', 'away.s.01'),
#   ('newsman', 'reporter.n.01'),
#   ('train', 'train.n.01'),
#   ('trip', 'trip.n.01'),
#   ('across_the_nation', 'nationally.r.02'),
#   ('location', 'location.n.01'),
#   ('location', 'location.n.01'),
#   ('wife', 'wife.n.01'),
#   ('former', 'former.n.01'),
#   ('Olympic', 'olympic.a.01'),
#   ('diving', 'diving.n.01'),
#   ('champion', 'champion.n.01'),
#   ('person', 'person.n.01'),
#   ('await', 'expect.v.03')],
#  [('say', 'say.n.01'),
#   ('learn', 'learn.v.01'),
#   ('person', 'person.n.01'),
#   ('head_home', 'go_home.v.01')],
#  [('just', 'just.a.01'),
#   ('speculate', 'speculate.v.01'),
#   ('think', 'think.n.01'),
#   ('person', 'person.n.01'),
#   ('feel', 'feel.n.01'),
#   ('hurt', 'injury.n.01'),
#   ('group', 'group.n.01'),
#   ('chance', 'opportunity.n.01')],
#  [('group', 'group.n.01'),
#   ('streamliner', 'streamliner.n.01'),
#   ('stop', 'stop.n.01'),
#   ('location', 'location.n.01'),
#   ('location', 'location.n.01'),
#   ('a_few', 'a_few.s.01'),
#   ('minute', 'minute.n.01')],
#  [('sports_writer', 'sports_writer.n.01'),
#   ('person', 'person.n.01'),
#   ('compartment', 'compartment.n.01'),
#   ('talk', 'talk.n.01')],
#  [('conductor', 'conductor.n.01'),
#   ('say', 'say.n.01'),
#   ('person', 'person.n.01'),
#   ('think', 'think.n.01'),
#   ('want', 'privation.n.01'),
#   ('talk', 'talk.n.01')],
#  [('probably', 'probably.r.01'),
#   ('get', 'get.n.01'),
#   ('ball', 'ball.n.01'),
#   ('bat', 'bat.n.01'),
#   ('head', 'head.n.01')],
#  [('mad', 'huffy.s.02'), ('world', 'universe.n.01')],
#  [('person', 'person.n.01'),
#   ('go_into', 'enter.v.01'),
#   ('station', 'station.n.01')],
#  [('person', 'person.n.01'),
#   ('walk', 'walk.n.01'),
#   ('magazine', 'magazine.n.01'),
#   ('stand', 'base.n.08')],
#  [('tell', 'tell.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('quite', 'quite.r.01'),
#   ('cold', 'cold.n.01')],
#  [('warm_up', 'warm_up.v.01'), ('while', 'while.n.01')],
#  [('tell', 'tell.n.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01'),
#   ('say', 'say.n.01'),
#   ('person', 'person.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('double-crosser', 'double-crosser.n.01'),
#   ('say', 'say.n.01'),
#   ('person', 'person.n.01'),
#   ('get', 'get.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('keyhole', 'keyhole.n.01')],
#  [('say', 'say.n.01'),
#   ('never', 'never.r.01'),
#   ('talk', 'talk.n.01'),
#   ('person', 'person.n.01')],
#  [('person', 'person.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('person', 'person.n.01'),
#   ('baseball', 'baseball.n.01'),
#   ('writer', 'writer.n.01'),
#   ('group', 'group.n.01'),
#   ('quote', 'quotation_mark.n.01'),
#   ('person', 'person.n.01'),
#   ('say', 'say.n.01')],
#  [('hit', 'hit.n.01'), ('anymore', 'anymore.r.01')],
#  [('run', 'run.n.01')],
#  [('throw', 'throw.n.01')],
#  [('suddenly', 'suddenly.r.01'),
#   ('reflex', 'reflex.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('gone', 'travel.v.01')],
#  [('just', 'just.a.01'),
#   ('seem', 'look.v.02'),
#   ('baseball', 'baseball.n.01'),
#   ('lose', 'lose.v.01'),
#   ('grip', 'clasp.n.02'),
#   ('masses', 'multitude.n.03'),
#   ('pop_up', 'crop_up.v.01'),
#   ('pop', 'dad.n.01'),
#   ('heroics', 'heroics.n.01'),
#   ('start', 'start.n.01'),
#   ('tongue', 'tongue.n.01'),
#   ('wag', 'wag.n.01')],
#  [('so', 'sol.n.03'),
#   ('be', 'beryllium.n.01'),
#   ('weekend', 'weekend.n.01'),
#   ('40', 'forty.n.01'),
#   ('year', 'year.n.01'),
#   ('old', 'old.n.01'),
#   ('person', 'person.n.01'),
#   ('pitch', 'pitch.n.01'),
#   ('no-hit', 'no-hit.s.01'),
#   ('masterpiece', 'masterpiece.n.01'),
#   ('group', 'group.n.01'),
#   ('group', 'group.n.01'),
#   ('person', 'person.n.01'),
#   ('retaliate', 'revenge.v.01'),
#   ('record', 'record.n.01'),
#   ('tie', 'necktie.n.01'),
#   ('4', 'four.n.01'),
#   ('homer', 'homer.n.01'),
#   ('spree', 'spree.n.01'),
#   ('Sunday', 'sunday.n.01')],
#  [('of_course', 'naturally.r.01'),
#   ('be', 'beryllium.n.01'),
#   ('remarkable', 'remarkable.s.01'),
#   ('feat', 'feat.n.01'),
#   ('further', 'foster.v.01'),
#   ('emboss', 'emboss.v.01'),
#   ('fact', 'fact.n.01'),
#   ('baseball', 'baseball.n.01'),
#   ('rightfully', 'rightfully.r.01'),
#   ('be', 'beryllium.n.01'),
#   ('national', 'national.n.01'),
#   ('pastime', 'pastime.n.01')],
#  [('two', 'two.n.01'),
#   ('cherished', 'care_for.v.02'),
#   ('achievement', 'accomplishment.n.01'),
#   ('elderly', 'aged.n.01'),
#   ('person', 'person.n.01'),
#   ('hitless', 'hitless.s.01'),
#   ('pitching', 'pitching.n.01'),
#   ('probably', 'probably.r.01'),
#   ('reach', 'range.n.02'),
#   ('most', 'most.a.01'),
#   ('heart', 'heart.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('real', 'real_number.n.01'),
#   ('stimulant', 'stimulation.n.02'),
#   ('guy', 'guy.n.01'),
#   ('know', 'know.n.01'),
#   ('move', 'move.n.01'),
#   ('2', 'two.n.01'),
#   ('score', 'mark.n.01'),
#   ('year', 'year.n.01'),
#   ('milestone', 'milestone.n.01')],
#  [('group', 'group.n.01'),
#   ('rookie', 'cub.n.01'),
#   ('sigh', 'sigh.n.01'),
#   ('remark', 'remark.n.01'),
#   ('wish', 'wish.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('40', 'forty.n.01'),
#   ('top', 'top.n.01'),
#   ('grade', 'class.n.02'),
#   ('big_leaguer', 'major_leaguer.n.01')],
#  [('modest', 'modest.a.01'),
#   ('person', 'person.n.01'),
#   ('wave_off', 'wave_off.v.01'),
#   ('new', 'new.a.01'),
#   ('laurels', 'award.n.02'),
#   ('good', 'good.n.01'),
#   ('day', 'day.n.01')],
#  [('surely', 'surely.r.01'),
#   ('be', 'beryllium.n.01'),
#   ('no_doubt', 'to_be_sure.r.01'),
#   ('slender', 'slender.s.01'),
#   ('southpaw', 'left-handed_pitcher.n.01'),
#   ('all-time', 'all-time.s.01'),
#   ('great', 'great.n.01'),
#   ('left-hander', 'left-handed_pitcher.n.01'),
#   ('game', 'game.n.01'),
#   ('history', 'history.n.01')],
#  [('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01')],
#  [('person', 'person.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('superior', 'superior.n.01'),
#   ('pitcher', 'pitcher.n.01'),
#   ('gentlemanly', 'gentlemanlike.s.01'),
#   ('fellow', 'chap.n.01'),
#   ('ballplayer', 'ballplayer.n.01'),
#   ('ballplayer', 'ballplayer.n.01'),
#   ('say', 'say.n.01'),
#   ('trade', 'trade.n.01')],
#  [('remember', 'remember.v.01'),
#   ('beardown', 'beardown.s.01'),
#   ('performance', 'performance.n.01'),
#   ('meaningless', 'meaningless.a.01'),
#   ('exhibition_game', 'exhibition_game.n.01'),
#   ('location', 'location.n.01'),
#   ('Oct', 'october.n.01'),
#   ('new', 'new.a.01'),
#   ('crowd', 'crowd.n.01'),
#   ('period', 'time_period.n.01')],
#  [('person', 'person.n.01'),
#   ('know', 'know.n.01'),
#   ('merely', 'merely.r.01'),
#   ('remark', 'remark.n.01'),
#   ('person', 'person.n.01'),
#   ('all-out', 'all-out.s.01'),
#   ('guy', 'guy.n.01'),
#   ('play', 'play.n.01'),
#   ('rightfield', 'right_field.n.01'),
#   ('day', 'day.n.01'),
#   ('pop', 'dad.n.01'),
#   ('clubhouse', 'clubhouse.n.01')],
#  [('spectacular', 'spectacular.n.01'),
#   ('person', 'person.n.01'),
#   ('reach', 'range.n.02'),
#   ('decade', 'decade.n.01'),
#   ('big_league', 'major_league.n.01'),
#   ('May', 'may.n.01'),
#   ('join', 'articulation.n.02'),
#   ('six', 'six.n.01'),
#   ('other', 'other.a.01'),
#   ('slugger', 'batter.n.01'),
#   ('wallop', 'impact.n.02'),
#   ('four', 'four.n.01'),
#   ('home_run', 'homer.n.01'),
#   ('span', 'span.n.01'),
#   ('nine', 'nine.n.01'),
#   ('inning', 'inning.n.01')],
#  [('incidentally', 'by_the_way.r.01'),
#   ('only', 'lone.s.03'),
#   ('two', 'two.n.01'),
#   ('home', 'home.n.01'),
#   ('audience', 'audience.n.01')],
#  [('person', 'person.n.01'),
#   ('Boston', 'boston.n.01'),
#   ('first', 'first.n.01'),
#   ('hit', 'hit.n.01'),
#   ('four', 'four.n.01'),
#   ('home', 'home.n.01'),
#   ('person', 'person.n.01'),
#   ('Brooklyn', 'brooklyn.n.01'),
#   ('location', 'location.n.01')],
#  [('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('group', 'group.n.01'),
#   ('group', 'group.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('group', 'group.n.01'),
#   ('person', 'person.n.01'),
#   ('group', 'group.n.01'),
#   ('person', 'person.n.01'),
#   ('then', 'then.n.01'),
#   ('group', 'group.n.01'),
#   ('make', 'brand.n.02'),
#   ('history', 'history.n.01'),
#   ('on_the_road', 'on_the_road.n.01')],
#  [('person', 'person.n.01'),
#   ('big', 'large.a.01'),
#   ('day', 'day.n.01'),
#   ('revive', 'resuscitate.v.01'),
#   ('running', 'run.n.05'),
#   ('argument', 'argument.n.01'),
#   ('relative', 'relative.n.01'),
#   ('merit', 'merit.n.01'),
#   ('person', 'person.n.01'),
#   ('person', 'person.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('issue', 'issue.n.01'),
#   ('boil_down', 'reduce.v.06'),
#   ('matter', 'matter.n.01'),
#   ('opinion', 'opinion.n.01'),
#   ('depending_on', 'contingent.s.02'),
#   ('group', 'group.n.01'),
#   ('group', 'group.n.01'),
#   ('fan', 'fan.n.01'),
#   ('anti', 'anti.n.01'),
#   ('pro', 'professional.n.02'),
#   ('group', 'group.n.01')],
#  [('however', 'however.r.01'),
#   ('favor', 'favor.n.01'),
#   ('group', 'group.n.01'),
#   ('ace', 'one.n.01')],
#  [('four', 'four.n.01'),
#   ('nine', 'nine.n.01'),
#   ('previous', 'previous.s.01'),
#   ('season', 'season.n.01'),
#   ('person', 'person.n.01'),
#   ('hit', 'hit.n.01'),
#   ('25', 'twenty-five.n.01'),
#   ('home_run', 'homer.n.01'),
#   ('steal', 'bargain.n.02'),
#   ('25', 'twenty-five.n.01'),
#   ('base', 'base.n.01')],
#  [('once', 'once.r.01'), ('figure', 'figure.n.01'), ('be', 'beryllium.n.01')],
#  [('person', 'person.n.01'),
#   ('lifetime', 'life.n.05'),
#   ('batting', 'batting.n.01'),
#   ('average', 'average.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('point', 'point.n.01'),
#   ('person', 'person.n.01')],
#  [('group', 'group.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('anemic', 'anemic.s.01'),
#   ('windy', 'blowy.s.01'),
#   ('location', 'location.n.01'),
#   ('suddenly', 'suddenly.r.01'),
#   ('find', 'discovery.n.03'),
#   ('formula', 'formula.n.01'),
#   ('Milwaukee', 'milwaukee.n.01'),
#   ('park', 'park.n.01')],
#  [('forever', 'everlastingly.r.01'),
#   ('be', 'beryllium.n.01'),
#   ('baseball', 'baseball.n.01'),
#   ('mystery', 'mystery.n.01'),
#   ('team', 'team.n.01'),
#   ('suddenly', 'suddenly.r.01'),
#   ('start', 'start.n.01'),
#   ('hit', 'hit.n.01'),
#   ('distressing', 'straiten.v.01'),
#   ('slump', 'slump.n.01')],
#  [('TV_audience', 'viewing_audience.n.01'),
#   ('be', 'beryllium.n.01'),
#   ('privileged', 'privilege.v.01'),
#   ('person', 'person.n.01'),
#   ('four', 'four.n.01'),
#   ('home_run', 'homer.n.01'),
#   ('thank', 'thank.v.01'),
#   ('new', 'new.a.01'),
#   ('arrangement', 'agreement.n.04'),
#   ('make', 'brand.n.02'),
#   ('person', 'person.n.01'),
#   ('game', 'game.n.01'),
#   ('not', 'not.r.01'),
#   ('be', 'beryllium.n.01'),
#   ('black_out', 'black_out.v.01'),
#   ('group', 'group.n.01'),
#   ('play', 'play.n.01'),
#   ('at_home', 'at_home.n.01')],
#  [('rule', 'rule.n.01'),
#   ('blackout', 'blackout.n.01'),
#   ('televise', 'telecast.v.01'),
#   ('baseball', 'baseball.n.01'),
#   ('30_minutes', 'half-hour.n.01'),
#   ('start', 'start.n.01'),
#   ('major_league', 'major_league.n.01'),
#   ('minor_league', 'minor_league.n.01'),
#   ('game', 'game.n.01'),
#   ('area', 'area.n.01'),
#   ('come', 'semen.n.01'),
#   ('game', 'game.n.01'),
#   ('ruler', 'ruler.n.01')],
#  [('last', 'stopping_point.n.01'),
#   ('couple', 'couple.n.01'),
#   ('year', 'year.n.01'),
#   ('group', 'group.n.01'),
#   ('management', 'management.n.01'),
#   ('group', 'group.n.01'),
#   ('game', 'game.n.01'),
#   ('cut_off', 'interrupt.v.01')],
#  [('actually', 'actually.r.01'),
#   ('be', 'beryllium.n.01'),
#   ('helpless', 'helpless.s.01'),
#   ('policy', 'policy.n.01')],
#  [('year', 'year.n.01'),
#   ('tell', 'tell.n.01'),
#   ('group', 'group.n.01'),
#   ('network', 'network.n.01'),
#   ('continue', 'continue.v.01'),
#   ('abide_by', 'comply.v.01'),
#   ('rule', 'rule.n.01'),
#   ('but', 'merely.r.01'),
#   ('group', 'group.n.01'),
#   ('play', 'play.n.01'),
#   ('conclusion', 'decision.n.02'),
#   ('here', 'here.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('two', 'two.n.01'),
#   ('more', 'more.n.01'),
#   ('Sunday', 'sunday.n.01'),
#   ('afternoon', 'afternoon.n.01'),
#   ('situation', 'situation.n.01'),
#   ('arise', 'originate.v.01')],
#  [('be', 'beryllium.n.01'),
#   ('irritable', 'cranky.s.02'),
#   ('rule', 'rule.n.01'),
#   ('baseball', 'baseball.n.01'),
#   ('more', 'more.n.01'),
#   ('harm', 'injury.n.01'),
#   ('good', 'good.n.01'),
#   ('especially', 'particularly.r.01'),
#   ('minor_league', 'minor_league.n.01'),
#   ('level', 'degree.n.01')],
#  [('be', 'beryllium.n.01'),
#   ('surprised', 'surprise.v.01'),
#   ('many', 'many.a.01'),
#   ('fan', 'fan.n.01'),
#   ('purposely', 'intentionally.r.01'),
#   ('stay', 'stay.n.01'),
#   ('away', 'away.s.01'),
#   ('location', 'location.n.01'),
#   ('last', 'stopping_point.n.01'),
#   ('year', 'year.n.01'),
#   ('television', 'television.n.01'),
#   ('policy', 'policy.n.01')],
#  [('dissatisfaction', 'dissatisfaction.n.01'),
#   ('lead', 'lead.n.01'),
#   ('person', 'person.n.01'),
#   ('request', 'request.n.01'),
#   ('video', 'video.n.01'),
#   ('not', 'not.r.01'),
#   ('terminate', 'end.v.02'),
#   ('end', 'end.n.01'),
#   ('game', 'game.n.01')],
#  [('powerful', 'powerful.a.01'),
#   ('New_York', 'new_york.n.01'),
#   ('group', 'group.n.01'),
#   ('win', 'win.n.01'),
#   ('19th', 'nineteenth.s.01'),
#   ('World_Series', 'world_series.n.01'),
#   ('5', 'five.n.01'),
#   ('game', 'game.n.01'),
#   ('romp', 'runaway.n.01'),
#   ('outclassed', 'outclass.v.01'),
#   ('group', 'group.n.01'),
#   ('crush', 'crushed_leather.n.01'),
#   ('group', 'group.n.01'),
#   ('humiliating', 'humiliate.v.01'),
#   ('barrage', 'barrage.n.01'),
#   ('Monday', 'monday.n.01'),
#   ('loosely', 'loosely.r.01'),
#   ('played', 'play.v.01')],
#  [('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('injury', 'injury.n.01'),
#   ('group', 'group.n.01'),
#   ('champ', 'champion.n.01'),
#   ('still', 'still.n.01'),
#   ('mount', 'saddle_horse.n.01'),
#   ('15', 'fifteen.n.01'),
#   ('hit', 'hit.n.01'),
#   ('attack', 'attack.n.01'),
#   ('parade', 'parade.n.01'),
#   ('eight', 'eight.n.01'),
#   ('group', 'group.n.01'),
#   ('pitcher', 'pitcher.n.01'),
#   ('most', 'most.a.01'),
#   ('ever', 'ever.r.01'),
#   ('use', 'use.n.01'),
#   ('one', 'one.n.01'),
#   ('team', 'team.n.01'),
#   ('series', 'series.n.01'),
#   ('game', 'game.n.01')],
#  [('person', 'person.n.01'),
#   ('person', 'person.n.01'),
#   ('replacement', 'replacement.n.01'),
#   ('slam', 'slam.n.01'),
#   ('2', 'two.n.01')]]

# %%
total_count=0
correct_count=0
current_sent=0
for sent in synCorpus:
    current_word=0
    for (word,tag) in sent:
        if tag==overlapCorpus[current_sent][current_word][1]:
            correct_count+=1
#         else:
#              print("Sentenceno: ",current_sent," Word: ",word," Actual Tag:",tag," Predicted Tag:", overlapCorpus[current_sent][current_word][1])
        total_count+=1
        current_word+=1
    current_sent+=1    
print("Overlapping Accuracy: ",correct_count*100/total_count,'%')
# Out:
# Overlapping Accuracy:  34.609462610584025 %

# %%
total_count=0
correct_count=0
current_sent=0
for sent in synCorpus:
    current_word=0
    for (word,tag) in sent:
        if tag==overlapCorpus[current_sent][current_word][1]:
            correct_count+=1
#         else:
#             print("Sentenceno: ",current_sent," Word: ",word," Actual Tag:",tag," Predicted Tag:", overlapCorpus[current_sent][current_word][1])
        total_count+=1
        current_word+=1
    current_sent+=1    
print("Overlapping Accuracy: ",correct_count*100/total_count,'%')
# Out:
# Overlapping Accuracy:  34.609462610584025 %

# %%
semcor.tagged_sents(tag='sem')[2438]
# Out:
# [['If'],
#  [','],
#  ['as'],
#  ['a'],
#  Tree(Lemma('home_movie.n.01.home_movie'), ['home', 'movie']),
#  Tree(Lemma('maker.n.01.maker'), ['maker']),
#  [','],
#  ['you'],
#  Tree(Lemma('film.v.01.shoot'), ['shoot']),
#  ['the'],
#  Tree(Lemma('inevitable.s.02.inevitable'), ['inevitable']),
#  Tree(Lemma('footage.n.01.footage'), ['footage']),
#  ['of'],
#  ['your'],
#  Tree(Lemma('child.n.02.child'), ['child']),
#  Tree(Lemma('take.v.01.take'), ['taking']),
#  ['its'],
#  Tree(Lemma('first.a.01.first'), ['first']),
#  Tree(Lemma('steps.n.02.steps'), ['steps']),
#  [','],
#  ['you'],
#  ['have'],
#  Tree(Lemma('merely.r.01.merely'), ['merely']),
#  Tree(Lemma('record.v.01.record'), ['recorded']),
#  ['an'],
#  Tree(Lemma('historic.s.01.historical'), ['historical']),
#  Tree(Lemma('event.n.01.event'), ['event']),
#  ['.']]

# %%
        
#             try:
#                 amb_list+=model_w2v[splits]
#                 amb_count+=1
#             except:
#                 pass
#             if amb_count!=0:
#                 amb_vec=(amb_list/amb_count)
#             else:
#                 amv_vec=amb_list
#                 test+=1
#             print(model_w2v.cosine_similarities(context_bag_vector[0],[amb_list/amb_count]))
# Out:
# 'order.v.01'

# %%
wn.synset('record.v.01').definition()
# Out:
# 'make a record of; set down in permanent form'

# %%
length_of_wordvec=len(model_w2v["the"])
predictions = []
for sent in synCorpus:
    context_list=np.zeros((length_of_wordvec,))
    for word_context,tag_context in sent:
        word_without_underscore=word_context.split('_')
        word_without_underscore_stopwords=[word for word in word_without_underscore if not word in stopwords.words()]
        try:
            context_list+=np.sum(model_w2v[word_without_underscore_stopwords],axis=0)
        except:
            pass
    context_list/=length_of_wordvec
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4795/1642623761.py in <module>
#       5     for word_context,tag_context in sent:
#       6         word_without_underscore=word_context.split('_')
# ----> 7         word_without_underscore_stopwords=[word for word in word_without_underscore if not word in stopwords.words()]
#       8         try:
#       9             context_list+=np.sum(model_w2v[word_without_underscore_stopwords],axis=0)
#
# /tmp/ipykernel_4795/1642623761.py in <listcomp>(.0)
#       5     for word_context,tag_context in sent:
#       6         word_without_underscore=word_context.split('_')
# ----> 7         word_without_underscore_stopwords=[word for word in word_without_underscore if not word in stopwords.words()]
#       8         try:
#       9             context_list+=np.sum(model_w2v[word_without_underscore_stopwords],axis=0)
#
# ~/.local/lib/python3.8/site-packages/nltk/corpus/reader/wordlist.py in words(self, fileids, ignore_lines_startswith)
#      19
#      20     def words(self, fileids=None, ignore_lines_startswith="\n"):
# ---> 21         return [
#      22             line
#      23             for line in line_tokenize(self.raw(fileids))
#
# ~/.local/lib/python3.8/site-packages/nltk/corpus/reader/wordlist.py in <listcomp>(.0)
#      22             line
#      23             for line in line_tokenize(self.raw(fileids))
# ---> 24             if not line.startswith(ignore_lines_startswith)
#      25         ]
#      26
#
# KeyboardInterrupt:

# %%
for word_amb,tag_amb in sent:
        senses_list_amb=wn.synsets(word_amb)
        for sense in senses_list:
            sense.definition()

# %%
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

# %%
predictions = []

for sent in corpus:
	test_sentence = []
	sentence_predictions = []
	
	for wd in sent:
		test_sentence.append(wd[0])
	
	for wd in sent:
		tag_pred_sim = dict()
		# test_word = 'play'
		# test_tag = 'play.v.01'
		test_word = wd[0]
		test_tag = wd[1]

		test_sentence_set = {word for word in test_sentence if not word in stopwords}
		test_sentence_set = test_sentence_set - set([wd])

		test_pred_similarity = []
		for item in test_sentence_set:
			v_wd = word_vectors[wd]
			v_item = word_vectors[item]
			cos_sim = cosine_similarity([v_wd],[v_item])
			test_pred_similarity.append(cos_sim)
		test_max_similarity = max(test_pred_similarity)

		tag_pred_sim.update({test_tag:test_max_similarity})

		test_sentence_set = {word for word in test_sentence if not word in stopwords}
		test_sentence_set = test_sentence_set - set([wd])

		word_synsets = wordnet.synsets(test_word)

		tag_list = []
		definition_list = []

		for i in range(len(word_synsets)):
			tag_list.append(wordnet.synsets(test_word)[i].name())

		if len(tag_list) == 1:
			sentence_predictions.append((test_word,test_tag))
		else:
			for i in range(len(tag_list)):
				definition_list.append(wordnet.synset(tag_list[i]).definition())
				current_definition = word_tokenize(definition)
				current_definition_set = {word for word in current_definition if not word in stopwords}
				temp_similarity = []
				for item in current_definition_set:
					v_wd = word_vectors[wd]
					v_item = word_vectors[item]
					cos_sim = cosine_similarity([v_wd],[v_item])
					temp_similarity.append(cos_sim)
				temp_max_similarity = max(temp_similarity) 
				if test_tag == tag_list[i]:
					if tag_pred_sim[test_tag] < temp_max_similarity:
						tag_pred_sim.update({test_tag:temp_max_similarity})
				else:
					tag_pred_sim.update({tag_list[i]:temp_max_similarity})
		keymax = max(zip(tag_pred_sim.values(), tag_pred_sim.keys()))[1]
		sentence_predictions.append((test_word,keymax))

	predictions.append(sentence_predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4795/3055703764.py in <module>
#      15                 test_tag = wd[1]
#      16
# ---> 17                 test_sentence_set = {word for word in test_sentence if not word in stopwords}
#      18                 test_sentence_set = test_sentence_set - set([wd])
#      19
#
# /tmp/ipykernel_4795/3055703764.py in <setcomp>(.0)
#      15                 test_tag = wd[1]
#      16
# ---> 17                 test_sentence_set = {word for word in test_sentence if not word in stopwords}
#      18                 test_sentence_set = test_sentence_set - set([wd])
#      19
#
# TypeError: argument of type 'WordListCorpusReader' is not iterable
